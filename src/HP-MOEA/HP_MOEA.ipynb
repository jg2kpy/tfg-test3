# %% [markdown]
# # A Hybrid Probabilistic Multiobjective Evolutionary Algorithm for Commercial Recommendation Systems
#
# Este archivo contiene una implementación del algoritmo HP-MOEA (Hybrid Probabilistic Multiobjective Evolutionary Algorithm), el cual integra técnicas de sistemas de recomendación con algoritmos evolutivos de optimización multiobjetivo. La descripción detallada del enfoque original se encuentra en este [paper](https://ieeexplore.ieee.org/abstract/document/9363322).

# %% [markdown]
# ## Requerimientos
#
# Para este proyecto se utilizan las siguientes bibliotecas: NumPy, Pandas, Pymoo y Matplotlib.
#
# Asegúrese de instalar las dependencias ejecutando el siguiente comando:

# %%
# %pip install numpy pandas pymoo matplotlib
# Out:
# Requirement already satisfied: numpy in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (1.26.4)
# Requirement already satisfied: pandas in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (2.2.3)
# Requirement already satisfied: pymoo in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (0.6.1.3)
# Requirement already satisfied: matplotlib in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (3.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: scipy>=1.1 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from pymoo) (1.14.1)
# Requirement already satisfied: autograd>=1.4 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from pymoo) (1.7.0)
# Requirement already satisfied: cma==3.2.2 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from pymoo) (3.2.2)
# Requirement already satisfied: alive-progress in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from pymoo) (3.2.0)
# Requirement already satisfied: dill in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from pymoo) (0.3.8)
# Requirement already satisfied: Deprecated in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from pymoo) (1.2.18)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: about-time==4.2.1 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from alive-progress->pymoo) (4.2.1)
# Requirement already satisfied: grapheme==0.6.0 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from alive-progress->pymoo) (0.6.0)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from Deprecated->pymoo) (1.17.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Preprocesamiento de datos
#
# Iniciaremos con el preprocesamiento de los datos utilizando el dataset MovieLens, desarrollado por la Universidad de Minnesota, el cual está disponible para uso libre con fines de investigación. Este dataset contiene calificaciones asignadas por usuarios a diversas películas. En esta implementación se utilizará la versión de 100,000 calificaciones, que abarca el período comprendido entre 1996 y 2018.
#
# Para más información sobre el dataset, puede consultarse el siguiente [enlace oficial](https://grouplens.org/datasets/movielens/).
#
# Para ver detalles de la implemetación del preprocesamiento, vea el archivo `preprocess.py`.

# %%
dataset_latest_small_path = '../../datasets/ml-latest-small/ratings.csv'
dataset_100k_path = '../../datasets/ml-100k/ratings.csv'
dataset_20m_path = '../../datasets/movielens-20m-dataset/rating.csv'
data_path = './data'
top_usuarios = 10000
newcomer_filter = 5

# %%
import preprocess

preprocess.main(dataset_100k_path, data_path, top_usuarios, newcomer_filter)
# Out:
# Leyendo el dataset desde: ../../datasets/ml-100k/ratings.csv
#
# Tamaño del dataframe original: 100000
# Eliminando la columna 'timestamp'
# Ordenando el dataset por la primera columna...
# Seleccionando los 10000 usuarios películas más comunes...
# Filtrando el dataframe para que solo contenga los usuarios seleccionados...
# Películas que aparecen más de 5 veces: 1298
# Películas que aparecen menos o igual a 5 veces (Newcomers): 384
#
# Cantidad total de usuarios: 943
# Cantidad total de peliculas: 1682
# Tamaño del dataframe actual: 100000
#
# Generando users2movie_ratings...
# [2025-07-23 21:11:18] [INFO] [update_users2movie_ratings] [0.07 segundos] 5.0%
# [2025-07-23 21:11:18] [INFO] [update_users2movie_ratings] [0.25 segundos] 15.0%
# [2025-07-23 21:11:18] [INFO] [update_users2movie_ratings] [0.44 segundos] 25.0%
# [2025-07-23 21:11:19] [INFO] [update_users2movie_ratings] [0.65 segundos] 35.0%
# [2025-07-23 21:11:19] [INFO] [update_users2movie_ratings] [0.88 segundos] 45.0%
# [2025-07-23 21:11:19] [INFO] [update_users2movie_ratings] [1.13 segundos] 55.0%
# [2025-07-23 21:11:19] [INFO] [update_users2movie_ratings] [1.39 segundos] 65.0%
# [2025-07-23 21:11:20] [INFO] [update_users2movie_ratings] [1.69 segundos] 75.0%
# [2025-07-23 21:11:20] [INFO] [update_users2movie_ratings] [2.01 segundos] 85.0%
# [2025-07-23 21:11:20] [INFO] [update_users2movie_ratings] [2.36 segundos] 95.0%
#
# Generando movies_info...
# [2025-07-23 21:11:21] [INFO] [Movies_info] [0.00 segundos] 4.99%
# [2025-07-23 21:11:21] [INFO] [Movies_info] [0.00 segundos] 9.99%
# [2025-07-23 21:11:21] [INFO] [Movies_info] [0.00 segundos] 14.98%
# [2025-07-23 21:11:21] [INFO] [Movies_info] [0.00 segundos] 19.98%
# [2025-07-23 21:11:21] [INFO] [Movies_info] [0.01 segundos] 24.97%
# [2025-07-23 21:11:21] [INFO] [Movies_info] [0.01 segundos] 29.96%
# [2025-07-23 21:11:21] [INFO] [Movies_info] [0.01 segundos] 34.96%
# [2025-07-23 21:11:21] [INFO] [Movies_info] [0.01 segundos] 39.95%
# [2025-07-23 21:11:21] [INFO] [Movies_info] [0.01 segundos] 44.95%
# [2025-07-23 21:11:21] [INFO] [Movies_info] [0.01 segundos] 49.94%
# [2025-07-23 21:11:21] [INFO] [Movies_info] [0.01 segundos] 54.93%
# [2025-07-23 21:11:21] [INFO] [Movies_info] [0.01 segundos] 59.93%
# [2025-07-23 21:11:21] [INFO] [Movies_info] [0.01 segundos] 64.92%
# [2025-07-23 21:11:21] [INFO] [Movies_info] [0.01 segundos] 69.92%
# [2025-07-23 21:11:21] [INFO] [Movies_info] [0.02 segundos] 74.91%
# [2025-07-23 21:11:21] [INFO] [Movies_info] [0.02 segundos] 79.9%
# [2025-07-23 21:11:21] [INFO] [Movies_info] [0.02 segundos] 84.9%
# [2025-07-23 21:11:21] [INFO] [Movies_info] [0.02 segundos] 89.89%
# [2025-07-23 21:11:21] [INFO] [Movies_info] [0.02 segundos] 94.89%
# [2025-07-23 21:11:21] [INFO] [Movies_info] [0.02 segundos] 99.88%
#
# Eliminando usuarios que solo tienen películas newcomers...
# Cantidad de usuarios eliminados por solo tener newcomers: 0
#
# Guardando los datos procesados en formato JSON...
# [2025-07-23 21:11:22] [SUCCESS] [PREPROCESS] [3.58 segundos] Datos de usuarios guardados en: ./data/users2movie_ratings.json
# [2025-07-23 21:11:22] [SUCCESS] [PREPROCESS] [3.58 segundos] Datos de películas guardados en: ./data/movies_info.json

# %% [markdown]
# ## Filtrado colaborativo basado en usuarios
#
# El siguente paso luego del preprocesamiento de los datos para HP-MOEA, es calcular la puntuación esperada de los ítems que los usuarios aun no han calificado, para ello se emplea el filtrado colaborativo basado en usuarios, la cual es la tecnica mas sencilla de los S.R.
#
# Para ver mas detalles de como se implemento el filtrado colaborativo basado en usuarios, ver el archivo `User_based_CF.py`.

# %%
import User_based_CF

K = 20
limit = 5
eliminar_newcomers = True
calcular_pesos = False # Debe estar True la primera vez que se ejecuta
hacer_test = False

usermovie2predict_rating = User_based_CF.main(data_path, K, limit, eliminar_newcomers, calcular_pesos, hacer_test)
# Out:
# Cargamos los datos preprocesados...
#
# Longitud de los datos preprocesados:
# users2movie_ratings:  1097886
# movies_info:  255146
# Eliminando newcomers...
# [2025-07-23 21:11:22] [INFO] [DELETING_NEWCOMERS] [0.00 segundos] 0.0%
# [2025-07-23 21:11:22] [INFO] [DELETING_NEWCOMERS] [0.02 segundos] 4.95%
# [2025-07-23 21:11:22] [INFO] [DELETING_NEWCOMERS] [0.03 segundos] 9.9%
# [2025-07-23 21:11:22] [INFO] [DELETING_NEWCOMERS] [0.05 segundos] 14.84%
# [2025-07-23 21:11:22] [INFO] [DELETING_NEWCOMERS] [0.07 segundos] 19.79%
# [2025-07-23 21:11:22] [INFO] [DELETING_NEWCOMERS] [0.09 segundos] 24.74%
# [2025-07-23 21:11:22] [INFO] [DELETING_NEWCOMERS] [0.10 segundos] 29.69%
# [2025-07-23 21:11:22] [INFO] [DELETING_NEWCOMERS] [0.12 segundos] 34.64%
# [2025-07-23 21:11:22] [INFO] [DELETING_NEWCOMERS] [0.14 segundos] 39.58%
# [2025-07-23 21:11:22] [INFO] [DELETING_NEWCOMERS] [0.15 segundos] 44.53%
# [2025-07-23 21:11:22] [INFO] [DELETING_NEWCOMERS] [0.17 segundos] 49.48%
# [2025-07-23 21:11:22] [INFO] [DELETING_NEWCOMERS] [0.19 segundos] 54.43%
# [2025-07-23 21:11:22] [INFO] [DELETING_NEWCOMERS] [0.20 segundos] 59.38%
# [2025-07-23 21:11:22] [INFO] [DELETING_NEWCOMERS] [0.22 segundos] 64.32%
# [2025-07-23 21:11:22] [INFO] [DELETING_NEWCOMERS] [0.24 segundos] 69.27%
# [2025-07-23 21:11:22] [INFO] [DELETING_NEWCOMERS] [0.25 segundos] 74.22%
# [2025-07-23 21:11:22] [INFO] [DELETING_NEWCOMERS] [0.27 segundos] 79.17%
# [2025-07-23 21:11:22] [INFO] [DELETING_NEWCOMERS] [0.29 segundos] 84.11%
# [2025-07-23 21:11:22] [INFO] [DELETING_NEWCOMERS] [0.30 segundos] 89.06%
# [2025-07-23 21:11:22] [INFO] [DELETING_NEWCOMERS] [0.32 segundos] 94.01%
# [2025-07-23 21:11:22] [INFO] [DELETING_NEWCOMERS] [0.34 segundos] 98.96%
# [2025-07-23 21:11:22] [SUCCESS] [DELETING_NEWCOMERS] [0.34 segundos] Se eliminaron 968 calificaciones por ser de newcomers
#
# Cantidad de usuarios: 943
# Cantidad de peliculas: 1298
#
# Iniciamos las predicciones con User Based Collaborative Filtering...
# [2025-07-23 21:11:22] [INFO] [PREDICCIÓN] [0.01 segundos] 0.0%
# [2025-07-23 21:11:23] [INFO] [PREDICCIÓN] [0.51 segundos] 4.98%
# [2025-07-23 21:11:23] [INFO] [PREDICCIÓN] [1.02 segundos] 9.97%
# [2025-07-23 21:11:24] [INFO] [PREDICCIÓN] [1.54 segundos] 14.95%
# [2025-07-23 21:11:24] [INFO] [PREDICCIÓN] [2.04 segundos] 19.94%
# [2025-07-23 21:11:25] [INFO] [PREDICCIÓN] [2.55 segundos] 24.92%
# [2025-07-23 21:11:25] [INFO] [PREDICCIÓN] [3.05 segundos] 29.9%
# [2025-07-23 21:11:26] [INFO] [PREDICCIÓN] [3.52 segundos] 34.89%
# [2025-07-23 21:11:26] [INFO] [PREDICCIÓN] [4.01 segundos] 39.87%
# [2025-07-23 21:11:26] [INFO] [PREDICCIÓN] [4.48 segundos] 44.86%
# [2025-07-23 21:11:27] [INFO] [PREDICCIÓN] [4.96 segundos] 49.84%
# [2025-07-23 21:11:27] [INFO] [PREDICCIÓN] [5.44 segundos] 54.83%
# [2025-07-23 21:11:28] [INFO] [PREDICCIÓN] [5.97 segundos] 59.81%
# [2025-07-23 21:11:28] [INFO] [PREDICCIÓN] [6.46 segundos] 64.79%
# [2025-07-23 21:11:29] [INFO] [PREDICCIÓN] [6.94 segundos] 69.78%
# [2025-07-23 21:11:29] [INFO] [PREDICCIÓN] [7.43 segundos] 74.76%
# [2025-07-23 21:11:30] [INFO] [PREDICCIÓN] [7.91 segundos] 79.75%
# [2025-07-23 21:11:30] [INFO] [PREDICCIÓN] [8.39 segundos] 84.73%
# [2025-07-23 21:11:31] [INFO] [PREDICCIÓN] [8.88 segundos] 89.71%
# [2025-07-23 21:11:31] [INFO] [PREDICCIÓN] [9.35 segundos] 94.7%
# [2025-07-23 21:11:32] [INFO] [PREDICCIÓN] [9.85 segundos] 99.68%
# [2025-07-23 21:11:32] [SUCCESS] [PREDICCIÓN] [9.88 segundos] Termino la predicción
#
# Termino la ejecución del filtrado colaborativo basado en usuarios, los datos se guardaron en ./data/usermovie2predict_rating.json

# %% [markdown]
# ## Carga de datos preprocesados y definición de parámetros del algoritmo

# %% [markdown]
# Se cargan los datos limpios y se definen como constantes globales los parámetros clave del algoritmo.

# %%
import numpy as np
import random

#np.set_printoptions(threshold=np.inf)

data_path = './data'

#Configuración del paper
u_turning_point = 500
L_tamano_lista = 10
N_tamano_poblacion = 100
T_iteraciones = 3000
Pm_probabilidad_mutacion = 1/L_tamano_lista
r_max_calificacion_maxima = 5
max_profit = 1
max_novelty = 1
n_obj = 2

# Generar una semilla aleatoria para reproducibilidad
nice_seed = random.randint(0, 100000) #69
print(f"Semilla aleatoria generada: {nice_seed}")

poblacion_global = []

historial_fitness = []

use_precalculated_CF = True
CF_config = {
    "K": 25,
    "limit": 5,
    "calcular_pesos": False,
    "hacer_test": False,
}

algorithms = [
    'NSGA-II', #0
    'SMS-EMOA', #1
    'NSGA-III', #2
    'MOEA/D' #3
]

algorithm_name = algorithms[0]

carpeta_resultados = 'original'

test_mode = True
if test_mode:
    T_iteraciones = 50 #50
    L_tamano_lista = 10 #10
    N_tamano_poblacion = 100 #100
    Pm_probabilidad_mutacion = 1/10

iteracion = 0
# Out:
# Semilla aleatoria generada: 76618

# %%
import os
import logger

from classes.Movies_info import Movies_info
from classes.Users import Users

log = logger.logger_class('LOAD_DATASET')

log.info('Cargamos los datos preprocesados')

if  os.path.exists(f'{data_path}/users2movie_ratings.json') and \
    os.path.exists(f'{data_path}/movies_info.json') and \
    os.path.exists(f'{data_path}/users2predict_movie_ratings.json')   :

    with open(f'{data_path}/users2movie_ratings.json', 'r') as f:
        users2movie_ratings_json = f.read()

    with open(f'{data_path}/movies_info.json', 'r') as f:
        movies_info_json = f.read()

    with open(f'{data_path}/users2predict_movie_ratings.json', 'r') as f:
        users2predict_movie_ratings_json = f.read()

    print('\nLongitud de los datos preprocesados:')
    print("users2movie_ratings: ", len(users2movie_ratings_json))
    print("users2predict_movie_ratings: ", len(users2predict_movie_ratings_json))
    print("movies_info: ", len(movies_info_json))

    # Estas estructuras serian similares a los Repository en Spring Boot
    users2movie_ratings = Users(fromJson=users2movie_ratings_json)
    users = users2movie_ratings.get_all_users()
    U_cant_usuarios = users2movie_ratings.get_len_users()
    users_ratings_data = {user.get_id(): user for user in users2movie_ratings.get_all_users()}
    #users_profile = users2movie_ratings.get_all_users_profile()

    users2predict_movie_ratings = Users(fromJson=users2predict_movie_ratings_json)
    users_predicted_ratings = users2predict_movie_ratings.get_all_users()
    user_movie_predict_ratings = users2predict_movie_ratings.get_user_movie_ratings()

    movies_info = Movies_info(fromJson=movies_info_json)
    movies_ids = movies_info.get_all_movie_ids()
    movies_ids_set = set(movies_ids)
    new_comers_ids = movies_info.get_all_newcomers_ids()
    newcomers_id_set = set(new_comers_ids)
    movies2profit = movies_info.get_movies_with_profits()
    #movies_content = movies_info.get_all_movies_content()

    ID_MIN = min(movies_ids)
    ID_MAX = max(movies_ids)

    print("\nU_cant_usuarios:", U_cant_usuarios)
    print("Cantidad de peliculas:", len(movies_ids_set))
    print("ID_MIN (movies):", ID_MIN)
    print("ID_MAX (movies):", ID_MAX)
    print("Cantidad de newcomers:", len(new_comers_ids))
    log.success('Datos preprocesados cargados correctamente')
# Out:
# [2025-07-23 21:11:33] [INFO] [LOAD_DATASET] [0.00 segundos] Cargamos los datos preprocesados
#
# Longitud de los datos preprocesados:
# users2movie_ratings:  1097886
# users2predict_movie_ratings:  34569109
# movies_info:  255146
#
# U_cant_usuarios: 943
# Cantidad de peliculas: 1682
# ID_MIN (movies): 1
# ID_MAX (movies): 1682
# Cantidad de newcomers: 384
# [2025-07-23 21:11:34] [SUCCESS] [LOAD_DATASET] [0.90 segundos] Datos preprocesados cargados correctamente

# %% [markdown]
# ## Definición de clases y funciones auxiliares
# Esta sección contiene clases y funciones auxiliares utilizadas para la ejecución de la clase principal y el ciclo de procesamiento.

# %%
import hashlib

def hash_matrix_func(matrix):
    matrix_str = ''.join(map(str, matrix.flatten()))
    return hashlib.sha256(matrix_str.encode()).hexdigest()

# %%
np.random.seed(nice_seed)

class Individuo():
    def __init__(self, new_matrix=None):
        global max_profit, max_novelty
        if isinstance(new_matrix, (np.ndarray, list)):
            self.matrix = np.array(new_matrix)
        else:
            matrix_aux = []
            for user in users:
                movies_ids_user_rated = set(user.get_movie_ids())
                posibles_ids = list(movies_ids_set - movies_ids_user_rated)
                matrix_aux.append(np.random.choice(posibles_ids, L_tamano_lista, replace=False))
            self.matrix = np.array(matrix_aux)

        self.profit = None
        self.novelty = None

        self.rank = None
        self.crowding_distance = None
        self.hv_contribution = None

        self.hash = hash_matrix_func(self.matrix)

    def get_profit(self):
        if self.profit == None:
            self.profit = self._calculate_profit()
        return self.profit

    def get_novelty(self):
        if self.novelty == None:
            self.novelty = self._calculate_novelty()
        return self.novelty

    def get_fitness(self):
        self.fitness = [-self.get_profit() / max_profit, -self.get_novelty() / max_novelty]
        return self.fitness

    def _calculate_profit(self):
        profit_total = 0

        for user_id, lista_recomendacion in enumerate(self.matrix, start=1):
            for movie_id in lista_recomendacion:
                if movie_id in newcomers_id_set:
                    profit = 1
                else:
                    r_calificacion = user_movie_predict_ratings[(user_id, movie_id)]
                    profit_i = movies_info.get_profit_by_movie_id(movie_id)
                    profit = (r_calificacion / r_max_calificacion_maxima) * profit_i
                profit_total += profit

        return profit_total

    def _calculate_novelty(self):
        novelty = 0
        for _, lista_recomendacion in enumerate(self.matrix, start=1):
            for movie_id in lista_recomendacion:
                if movie_id in newcomers_id_set:
                    novelty += 1
        return novelty

    def get_matrix(self):
        return self.matrix

    def get_hash(self):
        return self.hash

    def get_matrix_flatten(self):
        return self.matrix.flatten()

    def get_rank(self):
        return self.rank

    def set_rank(self, new_rank):
        self.rank = new_rank

    def get_crowding_distance(self):
        return self.crowding_distance

    def set_crowding_distance(self, new_crowding_distance):
        self.crowding_distance = new_crowding_distance

    def get_hv_contribution(self):
        return self.hv_contribution

    def set_hv_contribution(self, new_hv_contribution):
        self.hv_contribution = new_hv_contribution

    def get_row(self, index):
        return self.matrix[index]

    def recalcular(self):
        self.profit = self._calculate_profit()
        self.novelty = self._calculate_novelty()
        self.fitness = self.get_fitness()
        self.hash = hash_matrix_func(self.matrix)

        self.rank = None
        self.crowding_distance = None
        self.hv_contribution = None

    def replace_element_in_matrix(self, user, position, new_value):
        self.matrix[user, position] = new_value
        self.recalcular()

# %%
class Poblacion():

    def __init__(self, individuos, initial_population = False):
        if initial_population:
            self.poblacion = {individuo.get_hash(): individuo for individuo in individuos}
            self.fitnessF = None
        elif individuos != []:
            self.poblacion = {}
            for individuo_matrix in individuos.X:
                individuo_obj = poblacion_global.get_by_matrix_flatted(individuo_matrix)
                self.poblacion[individuo_obj.get_hash()] = individuo_obj
            self.poblacionX = individuos.X
            self.fitnessF = individuos.F

    def get_by_matrix_flatted(self, matrix_flatted):
        matrix = self.reshape_matrix(matrix_flatted)
        hash_matrix = hash_matrix_func(matrix)
        return self.poblacion[hash_matrix]

    def get_or_create_by_matrix_flatted(self, matrix_flatted):
        matrix = self.reshape_matrix(matrix_flatted)
        hash_matrix = hash_matrix_func(matrix)
        if hash_matrix not in self.poblacion:
            new_individual = Individuo(matrix)
            self.add_individual(new_individual)
        return self.poblacion[hash_matrix]

    def get_all_matrix(self):
        return [individuo.get_matrix() for individuo in self.poblacion.values()]

    def get_all_matrix_flatten(self):
        return [individuo.get_matrix_flatten() for individuo in self.poblacion.values()]

    def reshape_matrix(self, matrix):
        return matrix.reshape(U_cant_usuarios, L_tamano_lista)

    def add_individual(self, individual):
        if individual.get_hash() not in self.poblacion:
            self.poblacion[individual.get_hash()] = individual

    def replace_individual(self, old_individual, new_individual):
        old_hash = old_individual.get_hash()
        new_hash = new_individual.get_hash()
        if old_hash in self.poblacion:
            del self.poblacion[old_hash]
        self.poblacion[new_hash] = new_individual

    def get_total_fitness(self):
        total_fitness = []
        for individuo in self.poblacion.values():
            total_fitness.append(individuo.get_fitness())
        return total_fitness

    def get_all_individual_as_array(self):
        return list(self.poblacion.values())

    def get_fitness_F(self):
        return self.fitnessF

    def get_poblacion_X(self):
        return self.poblacionX

    def get_history(self):
        return self.history

    def get_all_individuals(self):
        return list(self.poblacion.values())

# %% [markdown]
# ### Obtener los individuos maximos

# %%
np.random.seed(nice_seed)

def get_individual_max_profit():
    global max_profit
    matrix_max_profit = []

    for user in users:
        user_id = user.get_id()
        movies_predict = users2predict_movie_ratings.get_movies_and_ratings_by_user_id(user_id)

        movies_predict = [(movie_id, rating) for movie_id, rating in movies_predict if movie_id not in newcomers_id_set]
        sorted_movies = sorted(movies_predict, key=lambda x: (movies2profit.get(x[0]), x[1]), reverse=True)

        matrix_max_profit.append([movie for movie, _ in sorted_movies[:L_tamano_lista]])

    individual_max_profit = Individuo(matrix_max_profit)
    max_profit = individual_max_profit.get_profit()

    return individual_max_profit


def get_individual_max_novelty():
    global max_novelty
    matrix_max_novelty = []

    for user in users:
        movies_ids_user_rated = set(user.get_movie_ids())
        posibles_ids = list(newcomers_id_set - movies_ids_user_rated)
        matrix_max_novelty.append(np.random.choice(posibles_ids, L_tamano_lista, replace=False))

    individual_max_novelty = Individuo(matrix_max_novelty)
    max_novelty = individual_max_novelty.get_novelty()

    return individual_max_novelty

# %% [markdown]
# ## Problema multiobjetivo y operadores geneticos

# %% [markdown]
# Calculo de metricas de la población para el cruce

# %%
from pymoo.indicators.hv import Hypervolume
from pymoo.util.nds.non_dominated_sorting import NonDominatedSorting
from pymoo.operators.survival.rank_and_crowding.metrics import get_crowding_function

def calculate_population_metrics(population, log):

    log.info('Calculando metricas de la población...')
    fitness_of_population = np.array([individuo.get_fitness() for individuo in population])
    reference_point = np.max(fitness_of_population, axis=0) + 1
    hv = Hypervolume(ref_point=reference_point)
    total_hv = hv.do(fitness_of_population)
    nds = NonDominatedSorting()
    fronts = nds.do(fitness_of_population, only_non_dominated_front=False)
    crowding_function = get_crowding_function("cd")

    for rank, front in enumerate(fronts):
        if len(front) == 0:
            continue

        front_fitness = fitness_of_population[front]
        crowding = crowding_function.do(front_fitness)

        for idx_in_front, idx_population in enumerate(front):
            individuo = population[idx_population]

            individuo.set_rank(rank)

            individuo.set_crowding_distance(crowding[idx_in_front])

            reduced_fitness = np.delete(fitness_of_population, idx_population, axis=0)
            reduced_hv = Hypervolume(ref_point=reference_point).do(reduced_fitness)
            hv_contrib = total_hv - reduced_hv

            individuo.set_hv_contribution(hv_contrib)
        #log.percentage(rank, len(fronts), mensaje='Metricas de la población: ')
    log.success('El calculo de metricas de población ha finalizado correctamente')

# %% [markdown]
# ### Definición del problema

# %%
from pymoo.core.problem import Problem

class HP_MOEA_Problem(Problem):

    def __init__(self, log, *args, **kwargs):
        n_var = U_cant_usuarios * L_tamano_lista
        xl = [ID_MIN for _ in range(n_var)]
        xu = [ID_MAX for _ in range(n_var)]
        self.log = log

        super().__init__(n_var = n_var, n_obj = n_obj, xl = xl, xu = xu, *args, **kwargs)

    def _evaluate(self, x, out, *args, **kwargs):
        global iteracion
        self.log.info('Iniciando evaluación con los valores del fitness...')
        res = []
        poblacion_aux = []
        lenX = len(x)
        for i, matrix in enumerate(x):
            individuo = poblacion_global.get_or_create_by_matrix_flatted(matrix)
            poblacion_aux.append(individuo)
            res.append(individuo.get_fitness())
            #self.log.percentage(i, lenX, mensaje='Evaluación: ')

        calculate_population_metrics(poblacion_aux, self.log)

        out["F"] = np.array(res)
        self.log.success('Termino la evaluación')
        self.log.percentage(iteracion, T_iteraciones, "Porcentaje de ejecución: ")
        self.log.success(f'Iteración del algoritmo: {iteracion}/{T_iteraciones}')
        iteracion+=1
        super()._evaluate(x, out, *args, **kwargs)

# %%
from pymoo.core.sampling import Sampling

class HP_MOEA_Sampling(Sampling):

    def __init__(self, initial_population):
        self.initial_population = initial_population
        super().__init__()

    def _do(self, problem, n_samples, **kwargs):
        return self.initial_population

# %% [markdown]
# ### Definición del operador genetico de mutación

# %%
from pymoo.core.mutation import Mutation
from pymoo.core.population import Population

np.random.seed(nice_seed)

def get_random_id_not_in(ban_list):
    posibles_ids = [movie_id for movie_id in movies_ids_set if movie_id not in ban_list]
    return np.random.choice(posibles_ids)

class HP_MOEA_SP_Mutation(Mutation):

    def __init__(self, Pm_probabilidad_mutacion, log):
        super().__init__()
        self.Pm_probabilidad_mutacion = Pm_probabilidad_mutacion
        self.log = log

    def _do(self, problem, X, **kwargs):
        global poblacion_global
        self.log.info("Iniciando operador de mutación...")

        X_mut = X.copy()

        for matrix_i, matrix in enumerate(X):
            if np.random.random() < self.Pm_probabilidad_mutacion:
                individuo = poblacion_global.get_by_matrix_flatted(matrix)

                user_i = np.random.randint(U_cant_usuarios)
                position = np.random.randint(L_tamano_lista)

                lista_recomendacion = individuo.get_row(user_i)
                user = users2movie_ratings.get_user_by_id(user_i + 1)
                movies_ids_user_rated = user.get_movie_ids()
                ban_list = set(movies_ids_user_rated + list(lista_recomendacion))
                nueva_pelicula = get_random_id_not_in(ban_list)

                #self.log.info(f"Individuo {matrix_i}, mutando en posición ({user_i}, {position}) reemplazando película {lista_recomendacion[position]} con {nueva_pelicula}")
                individuo.replace_element_in_matrix(user_i, position, nueva_pelicula)
                X_mut[matrix_i] = individuo.get_matrix_flatten()
                poblacion_global.add_individual(individuo)
            #self.log.percentage(matrix_i, len(X), mensaje='Operador de mutación: ')

        self.log.success('Operador de mutación finalizado correctamente')
        return X_mut


def test_HP_MOEA_SP_Mutation():
    poblacion_array = []
    for user in users_predicted_ratings[:5]:
        movies_ids_user_rated = user.get_movie_ids()
        posibles_ids = list(movies_ids_set - set(movies_ids_user_rated))
        lista_recomendacion = np.random.choice(posibles_ids, L_tamano_lista, replace=False)
        poblacion_array.append(lista_recomendacion)

    poblacion_array = np.array(poblacion_array)

    print("Población original:")
    print(poblacion_array)

    log = logger.logger_class('MUTACION_TEST')

    mutation = HP_MOEA_SP_Mutation(Pm_probabilidad_mutacion, log)

    # Create a Population object with the original population array
    pop = Population.new("X", poblacion_array.copy())

    # Apply the mutation operator
    mutated_pop = mutation._do(None, pop.get("X"))

    print("\nPoblación mutada:")
    print(mutated_pop)

    print("\nCambios detectados:")
    for i in range(len(poblacion_array)):
        original = poblacion_array[i]
        mutado = mutated_pop[i].reshape(L_tamano_lista)
        cambios = [(o, m) for o, m in zip(original, mutado) if o != m]
        if cambios:
            print(f"Usuario {i + 1}: {cambios}")

#test_HP_MOEA_SP_Mutation()

# %% [markdown]
# ### Definición del operador genetico de cruce

# %% [markdown]
# Probabilidad genetica para NSGA-II
#
# ![image.png](attachment:image.png)

# %%
import warnings
warnings.filterwarnings('ignore', category=RuntimeWarning)

def lambda_NSGA2(A, B):
    rank_A = A.get_rank()
    rank_B = B.get_rank()

    if rank_A != rank_B and (rank_A + rank_B) != 0:
        return rank_B / (rank_A + rank_B)

    dist_A = A.get_crowding_distance()
    dist_B = B.get_crowding_distance()
    if (dist_A + dist_B) != 0:
        return dist_A / (dist_A + dist_B)

    return float('inf')

# %% [markdown]
# Probabilidad genetica para SMS-EMOA
#
# ![image.png](attachment:image.png)

# %%
import warnings
warnings.filterwarnings('ignore', category=RuntimeWarning)

def lambda_SMS_EMOA(A, B):
    rank_A = A.get_rank()
    rank_B = B.get_rank()

    if rank_A != rank_B and (rank_A + rank_B) != 0:
        return rank_B / (rank_A + rank_B)

    contrib_A = A.get_hv_contribution()
    contrib_B = B.get_hv_contribution()

    if contrib_A is not None and contrib_B is not None and (contrib_A + contrib_B) != 0:
        return contrib_A / (contrib_A + contrib_B)

    dist_A = A.get_crowding_distance()
    dist_B = B.get_crowding_distance()
    if (dist_A + dist_B) != 0:
        return dist_A / (dist_A + dist_B)

    return float('inf')

# %% [markdown]
# Funcion del operador genetico de cruce entre individuos.
#
# ![image.png](attachment:image.png)

# %%
from pymoo.core.crossover import Crossover

np.random.seed(nice_seed)

class HP_MOEA_Crossover(Crossover):

    def __init__(self, log):
        # número de padres y número de hijos
        self.parents = 2
        self.offsprings = 1
        self.log = log
        super().__init__(n_parents=self.parents, n_offsprings=self.offsprings)

    def pass_same_genes(self, S_child, A_parent, B_parent):
        A_distinctive_genes = []
        B_distinctive_genes = []
        S_genes_size = 0

        for gene in A_parent:
            if gene in B_parent:
                S_child[S_genes_size] = gene
                S_genes_size += 1
            else:
                A_distinctive_genes.append(gene)

        for gene in B_parent:
            if gene not in A_parent:
                B_distinctive_genes.append(gene)

        return A_distinctive_genes, B_distinctive_genes, S_genes_size

    def crossover(self, A_parent, B_parent, algorithm_name):
        global poblacion_global
        S_child = np.zeros((U_cant_usuarios, L_tamano_lista), dtype=int)
        lambda_genetic_probability = lambda_NSGA2(A_parent, B_parent) if algorithm_name == 'NSGA2' else lambda_SMS_EMOA(A_parent, B_parent)
        for i in range(U_cant_usuarios):
            A_distinctive_genes, B_distinctive_genes, S_genes_size = self.pass_same_genes(S_child[i], A_parent.get_row(i), B_parent.get_row(i))
            A_index = 0
            B_index = 0

            for j in range(S_genes_size, L_tamano_lista):
                if np.random.random() < lambda_genetic_probability:
                    S_child[i][j] = A_distinctive_genes[A_index]
                    A_index+=1
                else:
                    S_child[i][j] = B_distinctive_genes[B_index]
                    B_index+=1

        new_child = Individuo(S_child)
        poblacion_global.add_individual(new_child)
        return new_child

    def _do(self, problem, X, **kwargs):
        global poblacion_global
        self.log.info("Iniciando operador de cruce...")

        n_parents, n_matings, n_var = X.shape

        algorithm = kwargs.get('algorithm')
        algorithm_name = algorithm.__class__.__name__

        Y_children = np.full((self.n_offsprings, n_matings, problem.n_var), None, dtype=object)

        for i in range(n_matings):
            A_parent = poblacion_global.get_by_matrix_flatted(X[0, i])
            B_parent = poblacion_global.get_by_matrix_flatted(X[1, i])
            S_child = self.crossover(A_parent, B_parent, algorithm_name)

            Y_children[0, i, :] = S_child.get_matrix_flatten()
            #self.log.percentage(i, n_matings, mensaje='Operador de cruce: ')

        self.log.success("Operador de cruce finalizado correctamente")
        return Y_children

# %% [markdown]
# ### Selector de algortimos evolutivos

# %%
from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.algorithms.moo.sms import SMSEMOA
from pymoo.algorithms.moo.nsga3 import NSGA3
from pymoo.algorithms.moo.moead import MOEAD

def select_algorithm(algorithm_name, population, log):
    if algorithm_name == 'NSGA-II':
        return NSGA2(
            pop_size = N_tamano_poblacion,
            eliminate_duplicates = False,
            sampling = HP_MOEA_Sampling(population.get_all_matrix_flatten()),
            mutation = HP_MOEA_SP_Mutation(Pm_probabilidad_mutacion, log),
            crossover = HP_MOEA_Crossover(log)
        )

    elif algorithm_name == 'SMS-EMOA':
        return SMSEMOA(
            pop_size = N_tamano_poblacion,
            eliminate_duplicates = False,
            sampling = HP_MOEA_Sampling(population.get_all_matrix_flatten()),
            mutation = HP_MOEA_SP_Mutation(Pm_probabilidad_mutacion, log),
            crossover = HP_MOEA_Crossover(log),
            n_offsprings = N_tamano_poblacion
        )
    else:
        raise ValueError(f"Algoritmo '{algorithm_name}' no reconocido.")

# %% [markdown]
# ## Definición de la clase HP_MOEA_Class
# Esta sección define la clase principal HP_MOEA_Class, encargada de gestionar la lógica central del algoritmo.

# %%
import copy
import logger
import User_based_CF as UBCF

from pymoo.optimize import minimize
from pymoo.indicators.hv import Hypervolume
from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.algorithms.moo.sms import SMSEMOA


class HP_MOEA_Class():

    def __init__(self, algorithm_name):
        self.log = logger.logger_class('HP_MOEA_CLASS')
        self.iteracion_actual = 0
        self.population = []
        self.algorithm_name = algorithm_name
        self.log.info('Se inicializo una instancia de la clase HP_MOEA_CLASS, la configuración es:')
        self.log.info(f'test_mode = {test_mode}')
        self.log.info(f'u_turning_point = {u_turning_point}')
        self.log.info(f'L_tamano_lista = {L_tamano_lista}')
        self.log.info(f'N_tamano_poblacion = {N_tamano_poblacion}')
        self.log.info(f'T_iteraciones = {T_iteraciones}')
        self.log.info(f'Pm_probabilidad_mutacion = {Pm_probabilidad_mutacion}')
        self.log.info(f'r_max_calificacion_maxima = {r_max_calificacion_maxima}')
        self.log.info(f'algorithm_name = {algorithm_name}')


    def generate_initial_population(self):
        self.log.info('Inicializando población...')
        initial_population = []

        self.log.percentage(0, N_tamano_poblacion, mensaje='Población inicial: ')
        individual_max_profit = get_individual_max_profit()
        self.log.percentage(1, N_tamano_poblacion, mensaje='Población inicial: ')
        individual_max_novelty = get_individual_max_novelty()
        self.log.percentage(2, N_tamano_poblacion, mensaje='Población inicial: ')

        initial_population.append(individual_max_profit)
        initial_population.append(individual_max_novelty)

        for i in range(n_obj, N_tamano_poblacion):
            initial_population.append(Individuo())
            self.log.percentage(i, N_tamano_poblacion, mensaje='Población inicial: ')

        self.set_population(initial_population, initial_population = True)

        self.log.success('Población inicializada correctamente')
        return self.population

    def termination_condition(self):
        self.log.success(f'Iteración del algoritmo: {self.iteracion_actual}/{T_iteraciones}')
        self.log.percentage(self.iteracion_actual, T_iteraciones, 'Porcentaje total del algoritmo: ')
        if self.iteracion_actual >= T_iteraciones:
            return True
        self.iteracion_actual+=1
        return False

    def set_population(self, new_population, initial_population=False):
        global poblacion_global

        if self.population == new_population:
            poblacion_global = copy.deepcopy(new_population)
            return

        if initial_population:
            new_population = Poblacion(new_population, initial_population=True)

        calculate_population_metrics(new_population.get_all_individual_as_array(), self.log)
        self.population = new_population
        poblacion_global = copy.deepcopy(new_population)
        historial_fitness.append(self.population.get_fitness_F())

    def generate_new_population_NSGAII(self): #Legacy code
        self.log.info('Generando población con NSGA-II...')

        algorithm = NSGA2(
            pop_size = N_tamano_poblacion,
            eliminate_duplicates = False,
            sampling = HP_MOEA_Sampling(self.population.get_all_matrix_flatten()),
            mutation = HP_MOEA_SP_Mutation(Pm_probabilidad_mutacion, self.log),
            crossover = HP_MOEA_Crossover(self.log)
        )

        new_population = minimize(
            problem = HP_MOEA_Problem(self.log),
            algorithm = algorithm,
            termination = ('n_gen', 2),
            seed = nice_seed,
            verbose = False,
            save_history = False
        )

        self.log.success('Población con NSGA-II generada correctamente')
        return Poblacion(new_population)

    def get_hypervolume_from_population(self, population): #Legacy code
        if population == []:
            return 0
        F = population.get_fitness_F()
        ref_point = np.zeros(n_obj)

        hv = Hypervolume(ref_point=ref_point)
        return hv.do(F)

    def generate_new_population_SMS_EMOA(self): #Legacy code
        self.log.info('Generando población con SMS-EMOA...')
        algorithm = SMSEMOA(
            pop_size = N_tamano_poblacion,
            eliminate_duplicates = False,
            sampling = HP_MOEA_Sampling(self.population.get_all_matrix_flatten()),
            mutation = HP_MOEA_SP_Mutation(Pm_probabilidad_mutacion, self.log),
            crossover = HP_MOEA_Crossover(self.log),
            n_offsprings = 1
        )

        new_population = minimize(
            problem = HP_MOEA_Problem(self.log),
            algorithm = algorithm,
            termination = ('n_gen', 2),
            seed = nice_seed,
            verbose = False,
            save_history = False
        )

        self.log.success('Población con SMS-EMOA generada correctamente')
        return Poblacion(new_population)

    def solve_problem(self):
        self.log.info(f'Resolviendo problema con {self.algorithm_name}...')

        algorithm = select_algorithm(self.algorithm_name, self.population, self.log)

        new_population = minimize(
            problem = HP_MOEA_Problem(self.log),
            algorithm = algorithm,
            termination = ('n_gen', T_iteraciones),
            seed = nice_seed,
            verbose = False,
            save_history = False
        )

        self.log.success(f'Población con {algorithm.__class__.__name__} generada correctamente')
        return Poblacion(new_population)

    def User_based_CF(self):
        global users2predict_movie_ratings_json, users2predict_movie_ratings, users_predicted_ratings
        self.log.info(f'Inicia el filtrado colaborativo...')
        if use_precalculated_CF:
            self.log.info(f'La configuración es: Usar datos precalculados = {use_precalculated_CF}')
            with open(f'{data_path}/users2predict_movie_ratings.json', 'r') as f:
                users2predict_movie_ratings_json = f.read()
        else:
            self.log.info(f'La configuración es: Usar datos precalculados = {use_precalculated_CF}')
            users2predict_movie_ratings_json = UBCF.main(data_path, CF_config["K"], CF_config["limit"],
                                                      CF_config["calcular_pesos"], CF_config["hacer_test"])

        users2predict_movie_ratings = Users(fromJson=users2predict_movie_ratings_json)
        users_predicted_ratings = users2predict_movie_ratings.get_all_users()

        self.log.success('Termino el filtrado colaborativo basado en usuarios')

# %% [markdown]
# ## Bucle principal de ejecución del algoritmo HP-MOEA
# Esta sección implementa el bucle principal del algoritmo HP-MOEA, donde se lleva a cabo el proceso evolutivo iterativo.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import logger

def HP_MOEA_LOOP():
    log = logger.logger_class('HP_MOEA_LOOP')
    hp_moea = HP_MOEA_Class(algorithm_name)

    log.info('Llamamos al filtrado colaborativo')
    hp_moea.User_based_CF()

    log.info('Inicializamos la población inicial')
    hp_moea.generate_initial_population()

    log.info('Ejecutamos el algortimo')
    R_population = hp_moea.solve_problem()

    log.success('Finalizado el algoritmo HP-MOEA correctamente')
    return R_population

poblacion_final = HP_MOEA_LOOP()
# Out:
# [2025-07-23 21:11:34] [INFO] [HP_MOEA_CLASS] [0.00 segundos] Se inicializo una instancia de la clase HP_MOEA_CLASS, la configuración es:
# [2025-07-23 21:11:34] [INFO] [HP_MOEA_CLASS] [0.00 segundos] test_mode = True
# [2025-07-23 21:11:34] [INFO] [HP_MOEA_CLASS] [0.00 segundos] u_turning_point = 500
# [2025-07-23 21:11:34] [INFO] [HP_MOEA_CLASS] [0.00 segundos] L_tamano_lista = 10
# [2025-07-23 21:11:34] [INFO] [HP_MOEA_CLASS] [0.00 segundos] N_tamano_poblacion = 100
# [2025-07-23 21:11:34] [INFO] [HP_MOEA_CLASS] [0.00 segundos] T_iteraciones = 50
# [2025-07-23 21:11:34] [INFO] [HP_MOEA_CLASS] [0.00 segundos] Pm_probabilidad_mutacion = 0.1
# [2025-07-23 21:11:34] [INFO] [HP_MOEA_CLASS] [0.00 segundos] r_max_calificacion_maxima = 5
# [2025-07-23 21:11:34] [INFO] [HP_MOEA_CLASS] [0.00 segundos] algorithm_name = NSGA-II
# [2025-07-23 21:11:34] [INFO] [HP_MOEA_LOOP] [0.00 segundos] Llamamos al filtrado colaborativo
# [2025-07-23 21:11:34] [INFO] [HP_MOEA_CLASS] [0.00 segundos] Inicia el filtrado colaborativo...
# [2025-07-23 21:11:34] [INFO] [HP_MOEA_CLASS] [0.00 segundos] La configuración es: Usar datos precalculados = True
# [2025-07-23 21:11:35] [SUCCESS] [HP_MOEA_CLASS] [0.55 segundos] Termino el filtrado colaborativo basado en usuarios
# [2025-07-23 21:11:35] [INFO] [HP_MOEA_LOOP] [0.55 segundos] Inicializamos la población inicial
# [2025-07-23 21:11:35] [INFO] [HP_MOEA_CLASS] [0.55 segundos] Inicializando población...
# [2025-07-23 21:11:35] [INFO] [HP_MOEA_CLASS] [0.55 segundos] Población inicial: 0.0%
# [2025-07-23 21:11:36] [INFO] [HP_MOEA_CLASS] [1.93 segundos] Población inicial: 5.0%
# [2025-07-23 21:11:37] [INFO] [HP_MOEA_CLASS] [2.56 segundos] Población inicial: 10.0%
# [2025-07-23 21:11:37] [INFO] [HP_MOEA_CLASS] [3.19 segundos] Población inicial: 15.0%
# [2025-07-23 21:11:38] [INFO] [HP_MOEA_CLASS] [3.82 segundos] Población inicial: 20.0%
# [2025-07-23 21:11:39] [INFO] [HP_MOEA_CLASS] [4.44 segundos] Población inicial: 25.0%
# [2025-07-23 21:11:39] [INFO] [HP_MOEA_CLASS] [5.05 segundos] Población inicial: 30.0%
# [2025-07-23 21:11:40] [INFO] [HP_MOEA_CLASS] [5.68 segundos] Población inicial: 35.0%
# [2025-07-23 21:11:40] [INFO] [HP_MOEA_CLASS] [6.30 segundos] Población inicial: 40.0%
# [2025-07-23 21:11:41] [INFO] [HP_MOEA_CLASS] [6.92 segundos] Población inicial: 45.0%
# [2025-07-23 21:11:42] [INFO] [HP_MOEA_CLASS] [7.55 segundos] Población inicial: 50.0%
# [2025-07-23 21:11:42] [INFO] [HP_MOEA_CLASS] [8.18 segundos] Población inicial: 55.0%
# [2025-07-23 21:11:43] [INFO] [HP_MOEA_CLASS] [8.81 segundos] Población inicial: 60.0%
# [2025-07-23 21:11:44] [INFO] [HP_MOEA_CLASS] [9.42 segundos] Población inicial: 65.0%
# [2025-07-23 21:11:44] [INFO] [HP_MOEA_CLASS] [10.06 segundos] Población inicial: 70.0%
# [2025-07-23 21:11:45] [INFO] [HP_MOEA_CLASS] [10.70 segundos] Población inicial: 75.0%
# [2025-07-23 21:11:45] [INFO] [HP_MOEA_CLASS] [11.32 segundos] Población inicial: 80.0%
# [2025-07-23 21:11:46] [INFO] [HP_MOEA_CLASS] [11.94 segundos] Población inicial: 85.0%
# [2025-07-23 21:11:47] [INFO] [HP_MOEA_CLASS] [12.58 segundos] Población inicial: 90.0%
# [2025-07-23 21:11:47] [INFO] [HP_MOEA_CLASS] [13.20 segundos] Población inicial: 95.0%
# [2025-07-23 21:11:48] [INFO] [HP_MOEA_CLASS] [13.71 segundos] Calculando metricas de la población...
# [2025-07-23 21:12:07] [SUCCESS] [HP_MOEA_CLASS] [33.13 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:12:07] [SUCCESS] [HP_MOEA_CLASS] [33.13 segundos] Población inicializada correctamente
# [2025-07-23 21:12:07] [INFO] [HP_MOEA_LOOP] [33.13 segundos] Ejecutamos el algortimo
# [2025-07-23 21:12:07] [INFO] [HP_MOEA_CLASS] [33.13 segundos] Resolviendo problema con NSGA-II...
# [2025-07-23 21:12:07] [INFO] [HP_MOEA_CLASS] [33.14 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:12:07] [INFO] [HP_MOEA_CLASS] [33.28 segundos] Calculando metricas de la población...
# [2025-07-23 21:12:07] [SUCCESS] [HP_MOEA_CLASS] [33.29 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:12:07] [SUCCESS] [HP_MOEA_CLASS] [33.29 segundos] Termino la evaluación
# [2025-07-23 21:12:07] [INFO] [HP_MOEA_CLASS] [33.29 segundos] Porcentaje de ejecución: 0.0%
# [2025-07-23 21:12:07] [SUCCESS] [HP_MOEA_CLASS] [33.29 segundos] Iteración del algoritmo: 0/50
# [2025-07-23 21:12:07] [INFO] [HP_MOEA_CLASS] [33.30 segundos] Iniciando operador de cruce...
# [2025-07-23 21:12:13] [SUCCESS] [HP_MOEA_CLASS] [39.33 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:12:13] [INFO] [HP_MOEA_CLASS] [39.36 segundos] Iniciando operador de mutación...
# [2025-07-23 21:12:14] [SUCCESS] [HP_MOEA_CLASS] [40.39 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:12:14] [INFO] [HP_MOEA_CLASS] [40.39 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:12:32] [INFO] [HP_MOEA_CLASS] [57.56 segundos] Calculando metricas de la población...
# [2025-07-23 21:12:32] [SUCCESS] [HP_MOEA_CLASS] [57.58 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:12:32] [SUCCESS] [HP_MOEA_CLASS] [57.58 segundos] Termino la evaluación
# [2025-07-23 21:12:32] [INFO] [HP_MOEA_CLASS] [57.58 segundos] Porcentaje de ejecución: 2.0%
# [2025-07-23 21:12:32] [SUCCESS] [HP_MOEA_CLASS] [57.58 segundos] Iteración del algoritmo: 1/50
# [2025-07-23 21:12:32] [INFO] [HP_MOEA_CLASS] [57.59 segundos] Iniciando operador de cruce...
# [2025-07-23 21:12:38] [SUCCESS] [HP_MOEA_CLASS] [63.89 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:12:38] [INFO] [HP_MOEA_CLASS] [63.92 segundos] Iniciando operador de mutación...
# [2025-07-23 21:12:41] [SUCCESS] [HP_MOEA_CLASS] [66.72 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:12:41] [INFO] [HP_MOEA_CLASS] [66.72 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:12:56] [INFO] [HP_MOEA_CLASS] [82.19 segundos] Calculando metricas de la población...
# [2025-07-23 21:12:56] [SUCCESS] [HP_MOEA_CLASS] [82.22 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:12:56] [SUCCESS] [HP_MOEA_CLASS] [82.22 segundos] Termino la evaluación
# [2025-07-23 21:12:56] [INFO] [HP_MOEA_CLASS] [82.22 segundos] Porcentaje de ejecución: 4.0%
# [2025-07-23 21:12:56] [SUCCESS] [HP_MOEA_CLASS] [82.22 segundos] Iteración del algoritmo: 2/50
# [2025-07-23 21:12:56] [INFO] [HP_MOEA_CLASS] [82.22 segundos] Iniciando operador de cruce...
# [2025-07-23 21:13:03] [SUCCESS] [HP_MOEA_CLASS] [88.57 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:13:03] [INFO] [HP_MOEA_CLASS] [88.60 segundos] Iniciando operador de mutación...
# [2025-07-23 21:13:04] [SUCCESS] [HP_MOEA_CLASS] [89.65 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:13:04] [INFO] [HP_MOEA_CLASS] [89.66 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:13:20] [INFO] [HP_MOEA_CLASS] [106.00 segundos] Calculando metricas de la población...
# [2025-07-23 21:13:20] [SUCCESS] [HP_MOEA_CLASS] [106.03 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:13:20] [SUCCESS] [HP_MOEA_CLASS] [106.03 segundos] Termino la evaluación
# [2025-07-23 21:13:20] [INFO] [HP_MOEA_CLASS] [106.03 segundos] Porcentaje de ejecución: 6.0%
# [2025-07-23 21:13:20] [SUCCESS] [HP_MOEA_CLASS] [106.03 segundos] Iteración del algoritmo: 3/50
# [2025-07-23 21:13:20] [INFO] [HP_MOEA_CLASS] [106.04 segundos] Iniciando operador de cruce...
# [2025-07-23 21:13:26] [SUCCESS] [HP_MOEA_CLASS] [112.08 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:13:26] [INFO] [HP_MOEA_CLASS] [112.11 segundos] Iniciando operador de mutación...
# [2025-07-23 21:13:28] [SUCCESS] [HP_MOEA_CLASS] [114.20 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:13:28] [INFO] [HP_MOEA_CLASS] [114.21 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:13:41] [INFO] [HP_MOEA_CLASS] [126.59 segundos] Calculando metricas de la población...
# [2025-07-23 21:13:41] [SUCCESS] [HP_MOEA_CLASS] [126.62 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:13:41] [SUCCESS] [HP_MOEA_CLASS] [126.62 segundos] Termino la evaluación
# [2025-07-23 21:13:41] [INFO] [HP_MOEA_CLASS] [126.62 segundos] Porcentaje de ejecución: 8.0%
# [2025-07-23 21:13:41] [SUCCESS] [HP_MOEA_CLASS] [126.62 segundos] Iteración del algoritmo: 4/50
# [2025-07-23 21:13:41] [INFO] [HP_MOEA_CLASS] [126.62 segundos] Iniciando operador de cruce...
# [2025-07-23 21:13:47] [SUCCESS] [HP_MOEA_CLASS] [132.75 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:13:47] [INFO] [HP_MOEA_CLASS] [132.78 segundos] Iniciando operador de mutación...
# [2025-07-23 21:13:48] [SUCCESS] [HP_MOEA_CLASS] [133.68 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:13:48] [INFO] [HP_MOEA_CLASS] [133.68 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:13:59] [INFO] [HP_MOEA_CLASS] [145.28 segundos] Calculando metricas de la población...
# [2025-07-23 21:13:59] [SUCCESS] [HP_MOEA_CLASS] [145.31 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:13:59] [SUCCESS] [HP_MOEA_CLASS] [145.31 segundos] Termino la evaluación
# [2025-07-23 21:13:59] [INFO] [HP_MOEA_CLASS] [145.31 segundos] Porcentaje de ejecución: 10.0%
# [2025-07-23 21:13:59] [SUCCESS] [HP_MOEA_CLASS] [145.31 segundos] Iteración del algoritmo: 5/50
# [2025-07-23 21:13:59] [INFO] [HP_MOEA_CLASS] [145.32 segundos] Iniciando operador de cruce...
# [2025-07-23 21:14:06] [SUCCESS] [HP_MOEA_CLASS] [151.49 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:14:06] [INFO] [HP_MOEA_CLASS] [151.52 segundos] Iniciando operador de mutación...
# [2025-07-23 21:14:07] [SUCCESS] [HP_MOEA_CLASS] [152.73 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:14:07] [INFO] [HP_MOEA_CLASS] [152.73 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:14:16] [INFO] [HP_MOEA_CLASS] [161.76 segundos] Calculando metricas de la población...
# [2025-07-23 21:14:16] [SUCCESS] [HP_MOEA_CLASS] [161.87 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:14:16] [SUCCESS] [HP_MOEA_CLASS] [161.87 segundos] Termino la evaluación
# [2025-07-23 21:14:16] [INFO] [HP_MOEA_CLASS] [161.87 segundos] Porcentaje de ejecución: 12.0%
# [2025-07-23 21:14:16] [SUCCESS] [HP_MOEA_CLASS] [161.87 segundos] Iteración del algoritmo: 6/50
# [2025-07-23 21:14:16] [INFO] [HP_MOEA_CLASS] [161.88 segundos] Iniciando operador de cruce...
# [2025-07-23 21:14:22] [SUCCESS] [HP_MOEA_CLASS] [168.00 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:14:22] [INFO] [HP_MOEA_CLASS] [168.03 segundos] Iniciando operador de mutación...
# [2025-07-23 21:14:24] [SUCCESS] [HP_MOEA_CLASS] [170.21 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:14:24] [INFO] [HP_MOEA_CLASS] [170.21 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:14:32] [INFO] [HP_MOEA_CLASS] [178.21 segundos] Calculando metricas de la población...
# [2025-07-23 21:14:32] [SUCCESS] [HP_MOEA_CLASS] [178.25 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:14:32] [SUCCESS] [HP_MOEA_CLASS] [178.25 segundos] Termino la evaluación
# [2025-07-23 21:14:32] [INFO] [HP_MOEA_CLASS] [178.25 segundos] Porcentaje de ejecución: 14.0%
# [2025-07-23 21:14:32] [SUCCESS] [HP_MOEA_CLASS] [178.25 segundos] Iteración del algoritmo: 7/50
# [2025-07-23 21:14:32] [INFO] [HP_MOEA_CLASS] [178.25 segundos] Iniciando operador de cruce...
# [2025-07-23 21:14:38] [SUCCESS] [HP_MOEA_CLASS] [184.32 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:14:38] [INFO] [HP_MOEA_CLASS] [184.35 segundos] Iniciando operador de mutación...
# [2025-07-23 21:14:39] [SUCCESS] [HP_MOEA_CLASS] [184.95 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:14:39] [INFO] [HP_MOEA_CLASS] [184.95 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:14:48] [INFO] [HP_MOEA_CLASS] [194.18 segundos] Calculando metricas de la población...
# [2025-07-23 21:14:48] [SUCCESS] [HP_MOEA_CLASS] [194.21 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:14:48] [SUCCESS] [HP_MOEA_CLASS] [194.21 segundos] Termino la evaluación
# [2025-07-23 21:14:48] [INFO] [HP_MOEA_CLASS] [194.21 segundos] Porcentaje de ejecución: 16.0%
# [2025-07-23 21:14:48] [SUCCESS] [HP_MOEA_CLASS] [194.21 segundos] Iteración del algoritmo: 8/50
# [2025-07-23 21:14:48] [INFO] [HP_MOEA_CLASS] [194.22 segundos] Iniciando operador de cruce...
# [2025-07-23 21:14:54] [SUCCESS] [HP_MOEA_CLASS] [200.24 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:14:54] [INFO] [HP_MOEA_CLASS] [200.28 segundos] Iniciando operador de mutación...
# [2025-07-23 21:14:56] [SUCCESS] [HP_MOEA_CLASS] [201.73 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:14:56] [INFO] [HP_MOEA_CLASS] [201.74 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:15:03] [INFO] [HP_MOEA_CLASS] [209.10 segundos] Calculando metricas de la población...
# [2025-07-23 21:15:03] [SUCCESS] [HP_MOEA_CLASS] [209.14 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:15:03] [SUCCESS] [HP_MOEA_CLASS] [209.14 segundos] Termino la evaluación
# [2025-07-23 21:15:03] [INFO] [HP_MOEA_CLASS] [209.14 segundos] Porcentaje de ejecución: 18.0%
# [2025-07-23 21:15:03] [SUCCESS] [HP_MOEA_CLASS] [209.14 segundos] Iteración del algoritmo: 9/50
# [2025-07-23 21:15:03] [INFO] [HP_MOEA_CLASS] [209.14 segundos] Iniciando operador de cruce...
# [2025-07-23 21:15:09] [SUCCESS] [HP_MOEA_CLASS] [215.17 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:15:09] [INFO] [HP_MOEA_CLASS] [215.20 segundos] Iniciando operador de mutación...
# [2025-07-23 21:15:10] [SUCCESS] [HP_MOEA_CLASS] [216.15 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:15:10] [INFO] [HP_MOEA_CLASS] [216.15 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:15:19] [INFO] [HP_MOEA_CLASS] [224.82 segundos] Calculando metricas de la población...
# [2025-07-23 21:15:19] [SUCCESS] [HP_MOEA_CLASS] [224.85 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:15:19] [SUCCESS] [HP_MOEA_CLASS] [224.85 segundos] Termino la evaluación
# [2025-07-23 21:15:19] [INFO] [HP_MOEA_CLASS] [224.85 segundos] Porcentaje de ejecución: 20.0%
# [2025-07-23 21:15:19] [SUCCESS] [HP_MOEA_CLASS] [224.85 segundos] Iteración del algoritmo: 10/50
# [2025-07-23 21:15:19] [INFO] [HP_MOEA_CLASS] [224.86 segundos] Iniciando operador de cruce...
# [2025-07-23 21:15:25] [SUCCESS] [HP_MOEA_CLASS] [230.82 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:15:25] [INFO] [HP_MOEA_CLASS] [230.85 segundos] Iniciando operador de mutación...
# [2025-07-23 21:15:27] [SUCCESS] [HP_MOEA_CLASS] [232.47 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:15:27] [INFO] [HP_MOEA_CLASS] [232.48 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:15:35] [INFO] [HP_MOEA_CLASS] [240.72 segundos] Calculando metricas de la población...
# [2025-07-23 21:15:35] [SUCCESS] [HP_MOEA_CLASS] [240.77 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:15:35] [SUCCESS] [HP_MOEA_CLASS] [240.77 segundos] Termino la evaluación
# [2025-07-23 21:15:35] [INFO] [HP_MOEA_CLASS] [240.77 segundos] Porcentaje de ejecución: 22.0%
# [2025-07-23 21:15:35] [SUCCESS] [HP_MOEA_CLASS] [240.77 segundos] Iteración del algoritmo: 11/50
# [2025-07-23 21:15:35] [INFO] [HP_MOEA_CLASS] [240.77 segundos] Iniciando operador de cruce...
# [2025-07-23 21:15:41] [SUCCESS] [HP_MOEA_CLASS] [247.01 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:15:41] [INFO] [HP_MOEA_CLASS] [247.04 segundos] Iniciando operador de mutación...
# [2025-07-23 21:15:42] [SUCCESS] [HP_MOEA_CLASS] [248.34 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:15:42] [INFO] [HP_MOEA_CLASS] [248.34 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:15:53] [INFO] [HP_MOEA_CLASS] [258.53 segundos] Calculando metricas de la población...
# [2025-07-23 21:15:53] [SUCCESS] [HP_MOEA_CLASS] [258.57 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:15:53] [SUCCESS] [HP_MOEA_CLASS] [258.57 segundos] Termino la evaluación
# [2025-07-23 21:15:53] [INFO] [HP_MOEA_CLASS] [258.57 segundos] Porcentaje de ejecución: 24.0%
# [2025-07-23 21:15:53] [SUCCESS] [HP_MOEA_CLASS] [258.57 segundos] Iteración del algoritmo: 12/50
# [2025-07-23 21:15:53] [INFO] [HP_MOEA_CLASS] [258.58 segundos] Iniciando operador de cruce...
# [2025-07-23 21:16:00] [SUCCESS] [HP_MOEA_CLASS] [265.58 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:16:00] [INFO] [HP_MOEA_CLASS] [265.61 segundos] Iniciando operador de mutación...
# [2025-07-23 21:16:01] [SUCCESS] [HP_MOEA_CLASS] [266.95 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:16:01] [INFO] [HP_MOEA_CLASS] [266.96 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:16:09] [INFO] [HP_MOEA_CLASS] [275.31 segundos] Calculando metricas de la población...
# [2025-07-23 21:16:09] [SUCCESS] [HP_MOEA_CLASS] [275.34 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:16:09] [SUCCESS] [HP_MOEA_CLASS] [275.34 segundos] Termino la evaluación
# [2025-07-23 21:16:09] [INFO] [HP_MOEA_CLASS] [275.34 segundos] Porcentaje de ejecución: 26.0%
# [2025-07-23 21:16:09] [SUCCESS] [HP_MOEA_CLASS] [275.34 segundos] Iteración del algoritmo: 13/50
# [2025-07-23 21:16:09] [INFO] [HP_MOEA_CLASS] [275.35 segundos] Iniciando operador de cruce...
# [2025-07-23 21:16:16] [SUCCESS] [HP_MOEA_CLASS] [281.67 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:16:16] [INFO] [HP_MOEA_CLASS] [281.71 segundos] Iniciando operador de mutación...
# [2025-07-23 21:16:17] [SUCCESS] [HP_MOEA_CLASS] [283.27 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:16:17] [INFO] [HP_MOEA_CLASS] [283.27 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:16:26] [INFO] [HP_MOEA_CLASS] [292.29 segundos] Calculando metricas de la población...
# [2025-07-23 21:16:26] [SUCCESS] [HP_MOEA_CLASS] [292.33 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:16:26] [SUCCESS] [HP_MOEA_CLASS] [292.33 segundos] Termino la evaluación
# [2025-07-23 21:16:26] [INFO] [HP_MOEA_CLASS] [292.33 segundos] Porcentaje de ejecución: 28.0%
# [2025-07-23 21:16:26] [SUCCESS] [HP_MOEA_CLASS] [292.33 segundos] Iteración del algoritmo: 14/50
# [2025-07-23 21:16:26] [INFO] [HP_MOEA_CLASS] [292.33 segundos] Iniciando operador de cruce...
# [2025-07-23 21:16:33] [SUCCESS] [HP_MOEA_CLASS] [298.69 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:16:33] [INFO] [HP_MOEA_CLASS] [298.72 segundos] Iniciando operador de mutación...
# [2025-07-23 21:16:33] [SUCCESS] [HP_MOEA_CLASS] [299.31 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:16:33] [INFO] [HP_MOEA_CLASS] [299.32 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:16:43] [INFO] [HP_MOEA_CLASS] [308.83 segundos] Calculando metricas de la población...
# [2025-07-23 21:16:43] [SUCCESS] [HP_MOEA_CLASS] [308.87 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:16:43] [SUCCESS] [HP_MOEA_CLASS] [308.87 segundos] Termino la evaluación
# [2025-07-23 21:16:43] [INFO] [HP_MOEA_CLASS] [308.87 segundos] Porcentaje de ejecución: 30.0%
# [2025-07-23 21:16:43] [SUCCESS] [HP_MOEA_CLASS] [308.87 segundos] Iteración del algoritmo: 15/50
# [2025-07-23 21:16:43] [INFO] [HP_MOEA_CLASS] [308.87 segundos] Iniciando operador de cruce...
# [2025-07-23 21:16:49] [SUCCESS] [HP_MOEA_CLASS] [315.09 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:16:49] [INFO] [HP_MOEA_CLASS] [315.13 segundos] Iniciando operador de mutación...
# [2025-07-23 21:16:51] [SUCCESS] [HP_MOEA_CLASS] [316.78 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:16:51] [INFO] [HP_MOEA_CLASS] [316.78 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:17:00] [INFO] [HP_MOEA_CLASS] [325.43 segundos] Calculando metricas de la población...
# [2025-07-23 21:17:00] [SUCCESS] [HP_MOEA_CLASS] [325.47 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:17:00] [SUCCESS] [HP_MOEA_CLASS] [325.47 segundos] Termino la evaluación
# [2025-07-23 21:17:00] [INFO] [HP_MOEA_CLASS] [325.47 segundos] Porcentaje de ejecución: 32.0%
# [2025-07-23 21:17:00] [SUCCESS] [HP_MOEA_CLASS] [325.47 segundos] Iteración del algoritmo: 16/50
# [2025-07-23 21:17:00] [INFO] [HP_MOEA_CLASS] [325.48 segundos] Iniciando operador de cruce...
# [2025-07-23 21:17:06] [SUCCESS] [HP_MOEA_CLASS] [331.77 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:17:06] [INFO] [HP_MOEA_CLASS] [331.80 segundos] Iniciando operador de mutación...
# [2025-07-23 21:17:07] [SUCCESS] [HP_MOEA_CLASS] [332.83 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:17:07] [INFO] [HP_MOEA_CLASS] [332.84 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:17:16] [INFO] [HP_MOEA_CLASS] [342.24 segundos] Calculando metricas de la población...
# [2025-07-23 21:17:16] [SUCCESS] [HP_MOEA_CLASS] [342.34 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:17:16] [SUCCESS] [HP_MOEA_CLASS] [342.34 segundos] Termino la evaluación
# [2025-07-23 21:17:16] [INFO] [HP_MOEA_CLASS] [342.34 segundos] Porcentaje de ejecución: 34.0%
# [2025-07-23 21:17:16] [SUCCESS] [HP_MOEA_CLASS] [342.34 segundos] Iteración del algoritmo: 17/50
# [2025-07-23 21:17:16] [INFO] [HP_MOEA_CLASS] [342.35 segundos] Iniciando operador de cruce...
# [2025-07-23 21:17:23] [SUCCESS] [HP_MOEA_CLASS] [348.64 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:17:23] [INFO] [HP_MOEA_CLASS] [348.67 segundos] Iniciando operador de mutación...
# [2025-07-23 21:17:23] [SUCCESS] [HP_MOEA_CLASS] [349.36 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:17:23] [INFO] [HP_MOEA_CLASS] [349.36 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:17:34] [INFO] [HP_MOEA_CLASS] [359.63 segundos] Calculando metricas de la población...
# [2025-07-23 21:17:34] [SUCCESS] [HP_MOEA_CLASS] [359.67 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:17:34] [SUCCESS] [HP_MOEA_CLASS] [359.67 segundos] Termino la evaluación
# [2025-07-23 21:17:34] [INFO] [HP_MOEA_CLASS] [359.67 segundos] Porcentaje de ejecución: 36.0%
# [2025-07-23 21:17:34] [SUCCESS] [HP_MOEA_CLASS] [359.67 segundos] Iteración del algoritmo: 18/50
# [2025-07-23 21:17:34] [INFO] [HP_MOEA_CLASS] [359.68 segundos] Iniciando operador de cruce...
# [2025-07-23 21:17:40] [SUCCESS] [HP_MOEA_CLASS] [365.82 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:17:40] [INFO] [HP_MOEA_CLASS] [365.85 segundos] Iniciando operador de mutación...
# [2025-07-23 21:17:41] [SUCCESS] [HP_MOEA_CLASS] [367.17 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:17:41] [INFO] [HP_MOEA_CLASS] [367.18 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:17:50] [INFO] [HP_MOEA_CLASS] [375.58 segundos] Calculando metricas de la población...
# [2025-07-23 21:17:50] [SUCCESS] [HP_MOEA_CLASS] [375.62 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:17:50] [SUCCESS] [HP_MOEA_CLASS] [375.62 segundos] Termino la evaluación
# [2025-07-23 21:17:50] [INFO] [HP_MOEA_CLASS] [375.62 segundos] Porcentaje de ejecución: 38.0%
# [2025-07-23 21:17:50] [SUCCESS] [HP_MOEA_CLASS] [375.62 segundos] Iteración del algoritmo: 19/50
# [2025-07-23 21:17:50] [INFO] [HP_MOEA_CLASS] [375.62 segundos] Iniciando operador de cruce...
# [2025-07-23 21:17:56] [SUCCESS] [HP_MOEA_CLASS] [381.82 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:17:56] [INFO] [HP_MOEA_CLASS] [381.85 segundos] Iniciando operador de mutación...
# [2025-07-23 21:17:57] [SUCCESS] [HP_MOEA_CLASS] [383.19 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:17:57] [INFO] [HP_MOEA_CLASS] [383.19 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:18:07] [INFO] [HP_MOEA_CLASS] [392.85 segundos] Calculando metricas de la población...
# [2025-07-23 21:18:07] [SUCCESS] [HP_MOEA_CLASS] [392.89 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:18:07] [SUCCESS] [HP_MOEA_CLASS] [392.89 segundos] Termino la evaluación
# [2025-07-23 21:18:07] [INFO] [HP_MOEA_CLASS] [392.89 segundos] Porcentaje de ejecución: 40.0%
# [2025-07-23 21:18:07] [SUCCESS] [HP_MOEA_CLASS] [392.89 segundos] Iteración del algoritmo: 20/50
# [2025-07-23 21:18:07] [INFO] [HP_MOEA_CLASS] [392.90 segundos] Iniciando operador de cruce...
# [2025-07-23 21:18:13] [SUCCESS] [HP_MOEA_CLASS] [399.27 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:18:13] [INFO] [HP_MOEA_CLASS] [399.30 segundos] Iniciando operador de mutación...
# [2025-07-23 21:18:15] [SUCCESS] [HP_MOEA_CLASS] [400.76 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:18:15] [INFO] [HP_MOEA_CLASS] [400.76 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:18:24] [INFO] [HP_MOEA_CLASS] [410.24 segundos] Calculando metricas de la población...
# [2025-07-23 21:18:24] [SUCCESS] [HP_MOEA_CLASS] [410.28 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:18:24] [SUCCESS] [HP_MOEA_CLASS] [410.28 segundos] Termino la evaluación
# [2025-07-23 21:18:24] [INFO] [HP_MOEA_CLASS] [410.28 segundos] Porcentaje de ejecución: 42.0%
# [2025-07-23 21:18:24] [SUCCESS] [HP_MOEA_CLASS] [410.28 segundos] Iteración del algoritmo: 21/50
# [2025-07-23 21:18:24] [INFO] [HP_MOEA_CLASS] [410.28 segundos] Iniciando operador de cruce...
# [2025-07-23 21:18:31] [SUCCESS] [HP_MOEA_CLASS] [417.03 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:18:31] [INFO] [HP_MOEA_CLASS] [417.06 segundos] Iniciando operador de mutación...
# [2025-07-23 21:18:33] [SUCCESS] [HP_MOEA_CLASS] [418.58 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:18:33] [INFO] [HP_MOEA_CLASS] [418.58 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:18:42] [INFO] [HP_MOEA_CLASS] [427.44 segundos] Calculando metricas de la población...
# [2025-07-23 21:18:42] [SUCCESS] [HP_MOEA_CLASS] [427.48 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:18:42] [SUCCESS] [HP_MOEA_CLASS] [427.48 segundos] Termino la evaluación
# [2025-07-23 21:18:42] [INFO] [HP_MOEA_CLASS] [427.48 segundos] Porcentaje de ejecución: 44.0%
# [2025-07-23 21:18:42] [SUCCESS] [HP_MOEA_CLASS] [427.48 segundos] Iteración del algoritmo: 22/50
# [2025-07-23 21:18:42] [INFO] [HP_MOEA_CLASS] [427.49 segundos] Iniciando operador de cruce...
# [2025-07-23 21:18:48] [SUCCESS] [HP_MOEA_CLASS] [433.87 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:18:48] [INFO] [HP_MOEA_CLASS] [433.90 segundos] Iniciando operador de mutación...
# [2025-07-23 21:18:49] [SUCCESS] [HP_MOEA_CLASS] [435.16 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:18:49] [INFO] [HP_MOEA_CLASS] [435.17 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:18:59] [INFO] [HP_MOEA_CLASS] [444.81 segundos] Calculando metricas de la población...
# [2025-07-23 21:18:59] [SUCCESS] [HP_MOEA_CLASS] [444.85 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:18:59] [SUCCESS] [HP_MOEA_CLASS] [444.85 segundos] Termino la evaluación
# [2025-07-23 21:18:59] [INFO] [HP_MOEA_CLASS] [444.85 segundos] Porcentaje de ejecución: 46.0%
# [2025-07-23 21:18:59] [SUCCESS] [HP_MOEA_CLASS] [444.85 segundos] Iteración del algoritmo: 23/50
# [2025-07-23 21:18:59] [INFO] [HP_MOEA_CLASS] [444.86 segundos] Iniciando operador de cruce...
# [2025-07-23 21:19:05] [SUCCESS] [HP_MOEA_CLASS] [451.00 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:19:05] [INFO] [HP_MOEA_CLASS] [451.03 segundos] Iniciando operador de mutación...
# [2025-07-23 21:19:06] [SUCCESS] [HP_MOEA_CLASS] [452.39 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:19:06] [INFO] [HP_MOEA_CLASS] [452.39 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:19:15] [INFO] [HP_MOEA_CLASS] [461.24 segundos] Calculando metricas de la población...
# [2025-07-23 21:19:15] [SUCCESS] [HP_MOEA_CLASS] [461.27 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:19:15] [SUCCESS] [HP_MOEA_CLASS] [461.27 segundos] Termino la evaluación
# [2025-07-23 21:19:15] [INFO] [HP_MOEA_CLASS] [461.27 segundos] Porcentaje de ejecución: 48.0%
# [2025-07-23 21:19:15] [SUCCESS] [HP_MOEA_CLASS] [461.27 segundos] Iteración del algoritmo: 24/50
# [2025-07-23 21:19:15] [INFO] [HP_MOEA_CLASS] [461.28 segundos] Iniciando operador de cruce...
# [2025-07-23 21:19:22] [SUCCESS] [HP_MOEA_CLASS] [467.43 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:19:22] [INFO] [HP_MOEA_CLASS] [467.46 segundos] Iniciando operador de mutación...
# [2025-07-23 21:19:23] [SUCCESS] [HP_MOEA_CLASS] [468.49 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:19:23] [INFO] [HP_MOEA_CLASS] [468.49 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:19:31] [INFO] [HP_MOEA_CLASS] [477.23 segundos] Calculando metricas de la población...
# [2025-07-23 21:19:31] [SUCCESS] [HP_MOEA_CLASS] [477.27 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:19:31] [SUCCESS] [HP_MOEA_CLASS] [477.27 segundos] Termino la evaluación
# [2025-07-23 21:19:31] [INFO] [HP_MOEA_CLASS] [477.27 segundos] Porcentaje de ejecución: 50.0%
# [2025-07-23 21:19:31] [SUCCESS] [HP_MOEA_CLASS] [477.27 segundos] Iteración del algoritmo: 25/50
# [2025-07-23 21:19:31] [INFO] [HP_MOEA_CLASS] [477.28 segundos] Iniciando operador de cruce...
# [2025-07-23 21:19:38] [SUCCESS] [HP_MOEA_CLASS] [483.85 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:19:38] [INFO] [HP_MOEA_CLASS] [483.89 segundos] Iniciando operador de mutación...
# [2025-07-23 21:19:39] [SUCCESS] [HP_MOEA_CLASS] [484.90 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:19:39] [INFO] [HP_MOEA_CLASS] [484.91 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:19:48] [INFO] [HP_MOEA_CLASS] [494.29 segundos] Calculando metricas de la población...
# [2025-07-23 21:19:48] [SUCCESS] [HP_MOEA_CLASS] [494.33 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:19:48] [SUCCESS] [HP_MOEA_CLASS] [494.33 segundos] Termino la evaluación
# [2025-07-23 21:19:48] [INFO] [HP_MOEA_CLASS] [494.33 segundos] Porcentaje de ejecución: 52.0%
# [2025-07-23 21:19:48] [SUCCESS] [HP_MOEA_CLASS] [494.33 segundos] Iteración del algoritmo: 26/50
# [2025-07-23 21:19:48] [INFO] [HP_MOEA_CLASS] [494.33 segundos] Iniciando operador de cruce...
# [2025-07-23 21:19:55] [SUCCESS] [HP_MOEA_CLASS] [500.55 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:19:55] [INFO] [HP_MOEA_CLASS] [500.58 segundos] Iniciando operador de mutación...
# [2025-07-23 21:19:56] [SUCCESS] [HP_MOEA_CLASS] [501.87 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:19:56] [INFO] [HP_MOEA_CLASS] [501.88 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:20:04] [INFO] [HP_MOEA_CLASS] [509.97 segundos] Calculando metricas de la población...
# [2025-07-23 21:20:04] [SUCCESS] [HP_MOEA_CLASS] [510.01 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:20:04] [SUCCESS] [HP_MOEA_CLASS] [510.01 segundos] Termino la evaluación
# [2025-07-23 21:20:04] [INFO] [HP_MOEA_CLASS] [510.01 segundos] Porcentaje de ejecución: 54.0%
# [2025-07-23 21:20:04] [SUCCESS] [HP_MOEA_CLASS] [510.01 segundos] Iteración del algoritmo: 27/50
# [2025-07-23 21:20:04] [INFO] [HP_MOEA_CLASS] [510.02 segundos] Iniciando operador de cruce...
# [2025-07-23 21:20:10] [SUCCESS] [HP_MOEA_CLASS] [516.22 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:20:10] [INFO] [HP_MOEA_CLASS] [516.26 segundos] Iniciando operador de mutación...
# [2025-07-23 21:20:12] [SUCCESS] [HP_MOEA_CLASS] [517.90 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:20:12] [INFO] [HP_MOEA_CLASS] [517.90 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:20:20] [INFO] [HP_MOEA_CLASS] [526.33 segundos] Calculando metricas de la población...
# [2025-07-23 21:20:20] [SUCCESS] [HP_MOEA_CLASS] [526.37 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:20:20] [SUCCESS] [HP_MOEA_CLASS] [526.37 segundos] Termino la evaluación
# [2025-07-23 21:20:20] [INFO] [HP_MOEA_CLASS] [526.37 segundos] Porcentaje de ejecución: 56.0%
# [2025-07-23 21:20:20] [SUCCESS] [HP_MOEA_CLASS] [526.37 segundos] Iteración del algoritmo: 28/50
# [2025-07-23 21:20:20] [INFO] [HP_MOEA_CLASS] [526.38 segundos] Iniciando operador de cruce...
# [2025-07-23 21:20:27] [SUCCESS] [HP_MOEA_CLASS] [532.47 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:20:27] [INFO] [HP_MOEA_CLASS] [532.50 segundos] Iniciando operador de mutación...
# [2025-07-23 21:20:28] [SUCCESS] [HP_MOEA_CLASS] [533.88 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:20:28] [INFO] [HP_MOEA_CLASS] [533.88 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:20:36] [INFO] [HP_MOEA_CLASS] [541.82 segundos] Calculando metricas de la población...
# [2025-07-23 21:20:36] [SUCCESS] [HP_MOEA_CLASS] [541.86 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:20:36] [SUCCESS] [HP_MOEA_CLASS] [541.86 segundos] Termino la evaluación
# [2025-07-23 21:20:36] [INFO] [HP_MOEA_CLASS] [541.86 segundos] Porcentaje de ejecución: 58.0%
# [2025-07-23 21:20:36] [SUCCESS] [HP_MOEA_CLASS] [541.86 segundos] Iteración del algoritmo: 29/50
# [2025-07-23 21:20:36] [INFO] [HP_MOEA_CLASS] [541.86 segundos] Iniciando operador de cruce...
# [2025-07-23 21:20:42] [SUCCESS] [HP_MOEA_CLASS] [548.08 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:20:42] [INFO] [HP_MOEA_CLASS] [548.11 segundos] Iniciando operador de mutación...
# [2025-07-23 21:20:43] [SUCCESS] [HP_MOEA_CLASS] [549.21 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:20:43] [INFO] [HP_MOEA_CLASS] [549.21 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:20:53] [INFO] [HP_MOEA_CLASS] [558.54 segundos] Calculando metricas de la población...
# [2025-07-23 21:20:53] [SUCCESS] [HP_MOEA_CLASS] [558.64 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:20:53] [SUCCESS] [HP_MOEA_CLASS] [558.64 segundos] Termino la evaluación
# [2025-07-23 21:20:53] [INFO] [HP_MOEA_CLASS] [558.64 segundos] Porcentaje de ejecución: 60.0%
# [2025-07-23 21:20:53] [SUCCESS] [HP_MOEA_CLASS] [558.64 segundos] Iteración del algoritmo: 30/50
# [2025-07-23 21:20:53] [INFO] [HP_MOEA_CLASS] [558.64 segundos] Iniciando operador de cruce...
# [2025-07-23 21:20:59] [SUCCESS] [HP_MOEA_CLASS] [564.73 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:20:59] [INFO] [HP_MOEA_CLASS] [564.76 segundos] Iniciando operador de mutación...
# [2025-07-23 21:21:01] [SUCCESS] [HP_MOEA_CLASS] [566.62 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:21:01] [INFO] [HP_MOEA_CLASS] [566.62 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:21:09] [INFO] [HP_MOEA_CLASS] [574.69 segundos] Calculando metricas de la población...
# [2025-07-23 21:21:09] [SUCCESS] [HP_MOEA_CLASS] [574.73 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:21:09] [SUCCESS] [HP_MOEA_CLASS] [574.73 segundos] Termino la evaluación
# [2025-07-23 21:21:09] [INFO] [HP_MOEA_CLASS] [574.73 segundos] Porcentaje de ejecución: 62.0%
# [2025-07-23 21:21:09] [SUCCESS] [HP_MOEA_CLASS] [574.73 segundos] Iteración del algoritmo: 31/50
# [2025-07-23 21:21:09] [INFO] [HP_MOEA_CLASS] [574.73 segundos] Iniciando operador de cruce...
# [2025-07-23 21:21:15] [SUCCESS] [HP_MOEA_CLASS] [580.98 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:21:15] [INFO] [HP_MOEA_CLASS] [581.01 segundos] Iniciando operador de mutación...
# [2025-07-23 21:21:17] [SUCCESS] [HP_MOEA_CLASS] [582.70 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:21:17] [INFO] [HP_MOEA_CLASS] [582.70 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:21:28] [INFO] [HP_MOEA_CLASS] [594.05 segundos] Calculando metricas de la población...
# [2025-07-23 21:21:28] [SUCCESS] [HP_MOEA_CLASS] [594.09 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:21:28] [SUCCESS] [HP_MOEA_CLASS] [594.09 segundos] Termino la evaluación
# [2025-07-23 21:21:28] [INFO] [HP_MOEA_CLASS] [594.09 segundos] Porcentaje de ejecución: 64.0%
# [2025-07-23 21:21:28] [SUCCESS] [HP_MOEA_CLASS] [594.09 segundos] Iteración del algoritmo: 32/50
# [2025-07-23 21:21:28] [INFO] [HP_MOEA_CLASS] [594.09 segundos] Iniciando operador de cruce...
# [2025-07-23 21:21:35] [SUCCESS] [HP_MOEA_CLASS] [600.55 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:21:35] [INFO] [HP_MOEA_CLASS] [600.58 segundos] Iniciando operador de mutación...
# [2025-07-23 21:21:36] [SUCCESS] [HP_MOEA_CLASS] [601.50 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:21:36] [INFO] [HP_MOEA_CLASS] [601.51 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:21:49] [INFO] [HP_MOEA_CLASS] [614.59 segundos] Calculando metricas de la población...
# [2025-07-23 21:21:49] [SUCCESS] [HP_MOEA_CLASS] [614.64 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:21:49] [SUCCESS] [HP_MOEA_CLASS] [614.64 segundos] Termino la evaluación
# [2025-07-23 21:21:49] [INFO] [HP_MOEA_CLASS] [614.64 segundos] Porcentaje de ejecución: 66.0%
# [2025-07-23 21:21:49] [SUCCESS] [HP_MOEA_CLASS] [614.64 segundos] Iteración del algoritmo: 33/50
# [2025-07-23 21:21:49] [INFO] [HP_MOEA_CLASS] [614.64 segundos] Iniciando operador de cruce...
# [2025-07-23 21:21:55] [SUCCESS] [HP_MOEA_CLASS] [620.74 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:21:55] [INFO] [HP_MOEA_CLASS] [620.77 segundos] Iniciando operador de mutación...
# [2025-07-23 21:21:56] [SUCCESS] [HP_MOEA_CLASS] [622.14 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:21:56] [INFO] [HP_MOEA_CLASS] [622.14 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:22:07] [INFO] [HP_MOEA_CLASS] [632.92 segundos] Calculando metricas de la población...
# [2025-07-23 21:22:07] [SUCCESS] [HP_MOEA_CLASS] [632.95 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:22:07] [SUCCESS] [HP_MOEA_CLASS] [632.95 segundos] Termino la evaluación
# [2025-07-23 21:22:07] [INFO] [HP_MOEA_CLASS] [632.95 segundos] Porcentaje de ejecución: 68.0%
# [2025-07-23 21:22:07] [SUCCESS] [HP_MOEA_CLASS] [632.95 segundos] Iteración del algoritmo: 34/50
# [2025-07-23 21:22:07] [INFO] [HP_MOEA_CLASS] [632.95 segundos] Iniciando operador de cruce...
# [2025-07-23 21:22:13] [SUCCESS] [HP_MOEA_CLASS] [638.81 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:22:13] [INFO] [HP_MOEA_CLASS] [638.84 segundos] Iniciando operador de mutación...
# [2025-07-23 21:22:15] [SUCCESS] [HP_MOEA_CLASS] [640.44 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:22:15] [INFO] [HP_MOEA_CLASS] [640.44 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:22:25] [INFO] [HP_MOEA_CLASS] [650.85 segundos] Calculando metricas de la población...
# [2025-07-23 21:22:25] [SUCCESS] [HP_MOEA_CLASS] [650.89 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:22:25] [SUCCESS] [HP_MOEA_CLASS] [650.89 segundos] Termino la evaluación
# [2025-07-23 21:22:25] [INFO] [HP_MOEA_CLASS] [650.89 segundos] Porcentaje de ejecución: 70.0%
# [2025-07-23 21:22:25] [SUCCESS] [HP_MOEA_CLASS] [650.89 segundos] Iteración del algoritmo: 35/50
# [2025-07-23 21:22:25] [INFO] [HP_MOEA_CLASS] [650.89 segundos] Iniciando operador de cruce...
# [2025-07-23 21:22:31] [SUCCESS] [HP_MOEA_CLASS] [656.79 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:22:31] [INFO] [HP_MOEA_CLASS] [656.82 segundos] Iniciando operador de mutación...
# [2025-07-23 21:22:32] [SUCCESS] [HP_MOEA_CLASS] [657.91 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:22:32] [INFO] [HP_MOEA_CLASS] [657.91 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:22:43] [INFO] [HP_MOEA_CLASS] [668.73 segundos] Calculando metricas de la población...
# [2025-07-23 21:22:43] [SUCCESS] [HP_MOEA_CLASS] [668.76 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:22:43] [SUCCESS] [HP_MOEA_CLASS] [668.76 segundos] Termino la evaluación
# [2025-07-23 21:22:43] [INFO] [HP_MOEA_CLASS] [668.76 segundos] Porcentaje de ejecución: 72.0%
# [2025-07-23 21:22:43] [SUCCESS] [HP_MOEA_CLASS] [668.76 segundos] Iteración del algoritmo: 36/50
# [2025-07-23 21:22:43] [INFO] [HP_MOEA_CLASS] [668.77 segundos] Iniciando operador de cruce...
# [2025-07-23 21:22:49] [SUCCESS] [HP_MOEA_CLASS] [674.71 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:22:49] [INFO] [HP_MOEA_CLASS] [674.74 segundos] Iniciando operador de mutación...
# [2025-07-23 21:22:49] [SUCCESS] [HP_MOEA_CLASS] [675.17 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:22:49] [INFO] [HP_MOEA_CLASS] [675.18 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:22:58] [INFO] [HP_MOEA_CLASS] [684.18 segundos] Calculando metricas de la población...
# [2025-07-23 21:22:58] [SUCCESS] [HP_MOEA_CLASS] [684.22 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:22:58] [SUCCESS] [HP_MOEA_CLASS] [684.22 segundos] Termino la evaluación
# [2025-07-23 21:22:58] [INFO] [HP_MOEA_CLASS] [684.22 segundos] Porcentaje de ejecución: 74.0%
# [2025-07-23 21:22:58] [SUCCESS] [HP_MOEA_CLASS] [684.22 segundos] Iteración del algoritmo: 37/50
# [2025-07-23 21:22:58] [INFO] [HP_MOEA_CLASS] [684.22 segundos] Iniciando operador de cruce...
# [2025-07-23 21:23:04] [SUCCESS] [HP_MOEA_CLASS] [690.06 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:23:04] [INFO] [HP_MOEA_CLASS] [690.09 segundos] Iniciando operador de mutación...
# [2025-07-23 21:23:05] [SUCCESS] [HP_MOEA_CLASS] [690.82 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:23:05] [INFO] [HP_MOEA_CLASS] [690.82 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:23:14] [INFO] [HP_MOEA_CLASS] [700.28 segundos] Calculando metricas de la población...
# [2025-07-23 21:23:14] [SUCCESS] [HP_MOEA_CLASS] [700.31 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:23:14] [SUCCESS] [HP_MOEA_CLASS] [700.31 segundos] Termino la evaluación
# [2025-07-23 21:23:14] [INFO] [HP_MOEA_CLASS] [700.31 segundos] Porcentaje de ejecución: 76.0%
# [2025-07-23 21:23:14] [SUCCESS] [HP_MOEA_CLASS] [700.31 segundos] Iteración del algoritmo: 38/50
# [2025-07-23 21:23:14] [INFO] [HP_MOEA_CLASS] [700.32 segundos] Iniciando operador de cruce...
# [2025-07-23 21:23:20] [SUCCESS] [HP_MOEA_CLASS] [706.17 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:23:20] [INFO] [HP_MOEA_CLASS] [706.20 segundos] Iniciando operador de mutación...
# [2025-07-23 21:23:22] [SUCCESS] [HP_MOEA_CLASS] [707.79 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:23:22] [INFO] [HP_MOEA_CLASS] [707.80 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:23:31] [INFO] [HP_MOEA_CLASS] [717.36 segundos] Calculando metricas de la población...
# [2025-07-23 21:23:31] [SUCCESS] [HP_MOEA_CLASS] [717.40 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:23:31] [SUCCESS] [HP_MOEA_CLASS] [717.40 segundos] Termino la evaluación
# [2025-07-23 21:23:31] [INFO] [HP_MOEA_CLASS] [717.40 segundos] Porcentaje de ejecución: 78.0%
# [2025-07-23 21:23:31] [SUCCESS] [HP_MOEA_CLASS] [717.40 segundos] Iteración del algoritmo: 39/50
# [2025-07-23 21:23:32] [INFO] [HP_MOEA_CLASS] [717.40 segundos] Iniciando operador de cruce...
# [2025-07-23 21:23:37] [SUCCESS] [HP_MOEA_CLASS] [723.26 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:23:37] [INFO] [HP_MOEA_CLASS] [723.29 segundos] Iniciando operador de mutación...
# [2025-07-23 21:23:38] [SUCCESS] [HP_MOEA_CLASS] [724.36 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:23:38] [INFO] [HP_MOEA_CLASS] [724.37 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:23:48] [INFO] [HP_MOEA_CLASS] [734.21 segundos] Calculando metricas de la población...
# [2025-07-23 21:23:48] [SUCCESS] [HP_MOEA_CLASS] [734.26 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:23:48] [SUCCESS] [HP_MOEA_CLASS] [734.26 segundos] Termino la evaluación
# [2025-07-23 21:23:48] [INFO] [HP_MOEA_CLASS] [734.26 segundos] Porcentaje de ejecución: 80.0%
# [2025-07-23 21:23:48] [SUCCESS] [HP_MOEA_CLASS] [734.26 segundos] Iteración del algoritmo: 40/50
# [2025-07-23 21:23:48] [INFO] [HP_MOEA_CLASS] [734.26 segundos] Iniciando operador de cruce...
# [2025-07-23 21:23:55] [SUCCESS] [HP_MOEA_CLASS] [740.52 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:23:55] [INFO] [HP_MOEA_CLASS] [740.54 segundos] Iniciando operador de mutación...
# [2025-07-23 21:23:55] [SUCCESS] [HP_MOEA_CLASS] [741.01 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:23:55] [INFO] [HP_MOEA_CLASS] [741.01 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:24:05] [INFO] [HP_MOEA_CLASS] [750.69 segundos] Calculando metricas de la población...
# [2025-07-23 21:24:05] [SUCCESS] [HP_MOEA_CLASS] [750.73 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:24:05] [SUCCESS] [HP_MOEA_CLASS] [750.73 segundos] Termino la evaluación
# [2025-07-23 21:24:05] [INFO] [HP_MOEA_CLASS] [750.73 segundos] Porcentaje de ejecución: 82.0%
# [2025-07-23 21:24:05] [SUCCESS] [HP_MOEA_CLASS] [750.73 segundos] Iteración del algoritmo: 41/50
# [2025-07-23 21:24:05] [INFO] [HP_MOEA_CLASS] [750.73 segundos] Iniciando operador de cruce...
# [2025-07-23 21:24:11] [SUCCESS] [HP_MOEA_CLASS] [756.82 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:24:11] [INFO] [HP_MOEA_CLASS] [756.85 segundos] Iniciando operador de mutación...
# [2025-07-23 21:24:12] [SUCCESS] [HP_MOEA_CLASS] [757.77 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:24:12] [INFO] [HP_MOEA_CLASS] [757.77 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:24:22] [INFO] [HP_MOEA_CLASS] [768.37 segundos] Calculando metricas de la población...
# [2025-07-23 21:24:23] [SUCCESS] [HP_MOEA_CLASS] [768.41 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:24:23] [SUCCESS] [HP_MOEA_CLASS] [768.41 segundos] Termino la evaluación
# [2025-07-23 21:24:23] [INFO] [HP_MOEA_CLASS] [768.41 segundos] Porcentaje de ejecución: 84.0%
# [2025-07-23 21:24:23] [SUCCESS] [HP_MOEA_CLASS] [768.41 segundos] Iteración del algoritmo: 42/50
# [2025-07-23 21:24:23] [INFO] [HP_MOEA_CLASS] [768.42 segundos] Iniciando operador de cruce...
# [2025-07-23 21:24:29] [SUCCESS] [HP_MOEA_CLASS] [774.61 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:24:29] [INFO] [HP_MOEA_CLASS] [774.64 segundos] Iniciando operador de mutación...
# [2025-07-23 21:24:30] [SUCCESS] [HP_MOEA_CLASS] [776.13 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:24:30] [INFO] [HP_MOEA_CLASS] [776.14 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:24:40] [INFO] [HP_MOEA_CLASS] [785.41 segundos] Calculando metricas de la población...
# [2025-07-23 21:24:40] [SUCCESS] [HP_MOEA_CLASS] [785.53 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:24:40] [SUCCESS] [HP_MOEA_CLASS] [785.53 segundos] Termino la evaluación
# [2025-07-23 21:24:40] [INFO] [HP_MOEA_CLASS] [785.53 segundos] Porcentaje de ejecución: 86.0%
# [2025-07-23 21:24:40] [SUCCESS] [HP_MOEA_CLASS] [785.53 segundos] Iteración del algoritmo: 43/50
# [2025-07-23 21:24:40] [INFO] [HP_MOEA_CLASS] [785.53 segundos] Iniciando operador de cruce...
# [2025-07-23 21:24:46] [SUCCESS] [HP_MOEA_CLASS] [791.83 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:24:46] [INFO] [HP_MOEA_CLASS] [791.86 segundos] Iniciando operador de mutación...
# [2025-07-23 21:24:47] [SUCCESS] [HP_MOEA_CLASS] [793.06 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:24:47] [INFO] [HP_MOEA_CLASS] [793.06 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:24:57] [INFO] [HP_MOEA_CLASS] [802.67 segundos] Calculando metricas de la población...
# [2025-07-23 21:24:57] [SUCCESS] [HP_MOEA_CLASS] [802.71 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:24:57] [SUCCESS] [HP_MOEA_CLASS] [802.71 segundos] Termino la evaluación
# [2025-07-23 21:24:57] [INFO] [HP_MOEA_CLASS] [802.71 segundos] Porcentaje de ejecución: 88.0%
# [2025-07-23 21:24:57] [SUCCESS] [HP_MOEA_CLASS] [802.71 segundos] Iteración del algoritmo: 44/50
# [2025-07-23 21:24:57] [INFO] [HP_MOEA_CLASS] [802.71 segundos] Iniciando operador de cruce...
# [2025-07-23 21:25:03] [SUCCESS] [HP_MOEA_CLASS] [808.80 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:25:03] [INFO] [HP_MOEA_CLASS] [808.83 segundos] Iniciando operador de mutación...
# [2025-07-23 21:25:04] [SUCCESS] [HP_MOEA_CLASS] [809.49 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:25:04] [INFO] [HP_MOEA_CLASS] [809.50 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:25:14] [INFO] [HP_MOEA_CLASS] [820.06 segundos] Calculando metricas de la población...
# [2025-07-23 21:25:14] [SUCCESS] [HP_MOEA_CLASS] [820.10 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:25:14] [SUCCESS] [HP_MOEA_CLASS] [820.10 segundos] Termino la evaluación
# [2025-07-23 21:25:14] [INFO] [HP_MOEA_CLASS] [820.10 segundos] Porcentaje de ejecución: 90.0%
# [2025-07-23 21:25:14] [SUCCESS] [HP_MOEA_CLASS] [820.10 segundos] Iteración del algoritmo: 45/50
# [2025-07-23 21:25:14] [INFO] [HP_MOEA_CLASS] [820.11 segundos] Iniciando operador de cruce...
# [2025-07-23 21:25:21] [SUCCESS] [HP_MOEA_CLASS] [826.67 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:25:21] [INFO] [HP_MOEA_CLASS] [826.70 segundos] Iniciando operador de mutación...
# [2025-07-23 21:25:22] [SUCCESS] [HP_MOEA_CLASS] [828.18 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:25:22] [INFO] [HP_MOEA_CLASS] [828.18 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:25:33] [INFO] [HP_MOEA_CLASS] [839.06 segundos] Calculando metricas de la población...
# [2025-07-23 21:25:33] [SUCCESS] [HP_MOEA_CLASS] [839.10 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:25:33] [SUCCESS] [HP_MOEA_CLASS] [839.10 segundos] Termino la evaluación
# [2025-07-23 21:25:33] [INFO] [HP_MOEA_CLASS] [839.10 segundos] Porcentaje de ejecución: 92.0%
# [2025-07-23 21:25:33] [SUCCESS] [HP_MOEA_CLASS] [839.10 segundos] Iteración del algoritmo: 46/50
# [2025-07-23 21:25:33] [INFO] [HP_MOEA_CLASS] [839.11 segundos] Iniciando operador de cruce...
# [2025-07-23 21:25:40] [SUCCESS] [HP_MOEA_CLASS] [845.95 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:25:40] [INFO] [HP_MOEA_CLASS] [845.98 segundos] Iniciando operador de mutación...
# [2025-07-23 21:25:42] [SUCCESS] [HP_MOEA_CLASS] [847.68 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:25:42] [INFO] [HP_MOEA_CLASS] [847.68 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:25:53] [INFO] [HP_MOEA_CLASS] [858.64 segundos] Calculando metricas de la población...
# [2025-07-23 21:25:53] [SUCCESS] [HP_MOEA_CLASS] [858.68 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:25:53] [SUCCESS] [HP_MOEA_CLASS] [858.68 segundos] Termino la evaluación
# [2025-07-23 21:25:53] [INFO] [HP_MOEA_CLASS] [858.68 segundos] Porcentaje de ejecución: 94.0%
# [2025-07-23 21:25:53] [SUCCESS] [HP_MOEA_CLASS] [858.68 segundos] Iteración del algoritmo: 47/50
# [2025-07-23 21:25:53] [INFO] [HP_MOEA_CLASS] [858.68 segundos] Iniciando operador de cruce...
# [2025-07-23 21:25:59] [SUCCESS] [HP_MOEA_CLASS] [864.87 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:25:59] [INFO] [HP_MOEA_CLASS] [864.90 segundos] Iniciando operador de mutación...
# [2025-07-23 21:26:01] [SUCCESS] [HP_MOEA_CLASS] [866.62 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:26:01] [INFO] [HP_MOEA_CLASS] [866.62 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:26:10] [INFO] [HP_MOEA_CLASS] [876.18 segundos] Calculando metricas de la población...
# [2025-07-23 21:26:10] [SUCCESS] [HP_MOEA_CLASS] [876.22 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:26:10] [SUCCESS] [HP_MOEA_CLASS] [876.22 segundos] Termino la evaluación
# [2025-07-23 21:26:10] [INFO] [HP_MOEA_CLASS] [876.22 segundos] Porcentaje de ejecución: 96.0%
# [2025-07-23 21:26:10] [SUCCESS] [HP_MOEA_CLASS] [876.22 segundos] Iteración del algoritmo: 48/50
# [2025-07-23 21:26:10] [INFO] [HP_MOEA_CLASS] [876.22 segundos] Iniciando operador de cruce...
# [2025-07-23 21:26:17] [SUCCESS] [HP_MOEA_CLASS] [882.45 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 21:26:17] [INFO] [HP_MOEA_CLASS] [882.48 segundos] Iniciando operador de mutación...
# [2025-07-23 21:26:18] [SUCCESS] [HP_MOEA_CLASS] [883.42 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 21:26:18] [INFO] [HP_MOEA_CLASS] [883.42 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 21:26:27] [INFO] [HP_MOEA_CLASS] [892.62 segundos] Calculando metricas de la población...
# [2025-07-23 21:26:27] [SUCCESS] [HP_MOEA_CLASS] [892.66 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 21:26:27] [SUCCESS] [HP_MOEA_CLASS] [892.66 segundos] Termino la evaluación
# [2025-07-23 21:26:27] [INFO] [HP_MOEA_CLASS] [892.66 segundos] Porcentaje de ejecución: 98.0%
# [2025-07-23 21:26:27] [SUCCESS] [HP_MOEA_CLASS] [892.66 segundos] Iteración del algoritmo: 49/50
# [2025-07-23 21:26:27] [SUCCESS] [HP_MOEA_CLASS] [892.66 segundos] Población con NSGA2 generada correctamente
# [2025-07-23 21:26:27] [SUCCESS] [HP_MOEA_LOOP] [892.81 segundos] Finalizado el algoritmo HP-MOEA correctamente

# %% [markdown]
# ## Análisis de resultados y visualización
# Esta sección presenta los resultados obtenidos y su visualización para facilitar la interpretación del desempeño del algoritmo.

# %%
from pymoo.indicators.hv import Hypervolume
from pymoo.visualization.scatter import Scatter

import matplotlib.pyplot as plt

log = logger.logger_class('RESULTADOS')
ref_point = np.zeros(n_obj)
hv = Hypervolume(ref_point=ref_point)

### POBLACIÓN FINAL
print(f'FINAL:')
fitnessF = poblacion_final.get_fitness_F()
hv_value = hv.do(fitnessF)

print(f'El hipervolumen de la población final es {hv_value}')
print(f'La población final es de {len(poblacion_final.get_poblacion_X())} individuos')

if fitnessF.shape[1] == 2:
    plot_final = Scatter(
        title="Fitness Distribution (Final Population)",
        labels=["Profit", "Novelty"]
    )
    plot_final.add(fitnessF * -1, s=30, facecolors='none', edgecolors='r', label="Final Population")
    plot_final.show()
elif fitnessF.shape[1] == 3:
    plot_final1 = Scatter(
        title="Fitness Distribution (Final Population - Profit vs Novelty)",
        labels=["Profit", "Novelty"]
    )
    plot_final1.add(fitnessF[:, [0, 1]] * -1, s=30, facecolors='none', edgecolors='r', label="Final Population")
    plot_final1.show()

    plot_final2 = Scatter(
        title="Fitness Distribution (Final Population - Profit vs Third objective)",
        labels=["Profit", "Third objective"]
    )
    plot_final2.add(fitnessF[:, [0, 2]] * -1, s=30, facecolors='none', edgecolors='r', label="Final Population")
    plot_final2.show()

    plot_final3 = Scatter(
        title="Fitness Distribution (Final Population - Novelty vs Third objective)",
        labels=["Novelty", "Third objective"]
    )
    plot_final3.add(fitnessF[:, [1, 2]] * -1, s=30, facecolors='none', edgecolors='r', label="Final Population")
    plot_final3.show()

    fig = plt.figure(figsize=(10, 7))
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(fitnessF[:, 0] * -1, fitnessF[:, 1], fitnessF[:, 2]  * -1, c='r', marker='o', label="Final Population")

    ax.set_title("3D Fitness Distribution (Final Population)")
    ax.set_xlabel("Profit")
    ax.set_ylabel("Novelty")
    ax.set_zlabel("Third objective")
    ax.legend()
    plt.show()
# Out:
# FINAL:
# El hipervolumen de la población final es 0.5731564295551879
# La población final es de 100 individuos

# %%
import pickle as pkl
from datetime import datetime

def guardar_archivo():
    fecha_hora = datetime.now().strftime('%Y%m%d_%H%M%S')
    archivo_guardar = {
        "fitnessF": poblacion_final.fitnessF,
        "poblacionX": poblacion_final.poblacionX
    }

    carpeta_path = f'./comparacion_resultados/{carpeta_resultados}'
    if not os.path.exists(carpeta_path):
        os.makedirs(carpeta_path)

    filename = f'{carpeta_path}/poblacion_final_{algorithm_name}_{N_tamano_poblacion}_{T_iteraciones}_{fecha_hora}.pkl'
    with open(filename, 'wb') as f:
        pkl.dump(archivo_guardar, f)

    print(f'Resultados guardados en: {filename}')

guardar_archivo()
# Out:
# Resultados guardados en: ./comparacion_resultados/original/poblacion_final_NSGA-II_100_50_20250723_212627.pkl

# %%
import matplotlib.pyplot as plt

def calculate_real_total_profit(poblacion):
    real_total_profit = []
    for individuo in poblacion.get_all_individuals():
        matrix = individuo.get_matrix()
        sumatoria = 0
        for user_id, row in enumerate(matrix, start=1):
            for movie in row:
                predict_rating = user_movie_predict_ratings[(user_id, movie)]
                if predict_rating >= 3:
                    sumatoria = sumatoria + movies2profit[movie]
        real_total_profit.append((individuo.get_novelty() / max_novelty, sumatoria))
    # Separate novelty and profit values
    novelty_values, profit_values = zip(*real_total_profit)

    # Plot the real total profit
    plt.figure(figsize=(10, 6))
    plt.scatter(profit_values, novelty_values, color='blue', alpha=0.7)
    plt.title('Novelty vs Real Total Profit')
    plt.xlabel('Real Total Profit')
    plt.ylabel('Novelty')
    plt.grid(True)
    plt.show()
    return real_total_profit

#real_total_profit = calculate_real_total_profit(poblacion_final)

# %% [markdown]
# Para animación

# %%
import os

def animacion():
    if not os.path.exists('./img'):
        os.makedirs('./img')

    for gen, fitness in enumerate(historial_fitness):
        if gen > 2:
            plot_gen = Scatter(
                title=f"Fitness Distribution (Generation {gen})",
                labels=["Profit", "Novelty"]
            )
            plot_gen.add(fitness, s=30, facecolors='none', edgecolors='g', label=f"Generation {gen - 2}")
            plot_gen.save(f'./img/{gen - 2}.png')

#animacion()

# %% [markdown]
# ## Ejemplos

# %%
import pandas as pd

def load_movie_data(latest):
    """
    Carga los datos de las películas desde un archivo CSV.
    """
    csv = '../../datasets/ml-latest-small/ratings.csv' if latest else '../../datasets/ml-100k/u.item.csv'
    movie_data = pd.read_csv(csv, sep=',', header=None, encoding='latin-1', usecols=[0, 1], names=['movieId', 'title'], skiprows=1)
    return dict(zip(movie_data['movieId'], movie_data['title']))

def get_recommendations(individuos, step_individuo, step_usuarios):
    """
    Obtiene las recomendaciones para los usuarios.
    """
    usuario_lista = []
    j_usuario = 1
    for i_individuo, individuo in enumerate(individuos):
        if i_individuo % step_individuo == 0:
            matrix = individuo.get_matrix()
            usuario_lista.append((j_usuario, matrix[j_usuario - 1], i_individuo, individuo.get_fitness()))
            j_usuario += step_usuarios
    return usuario_lista

def process_recommendations(usuario_lista, movie_id_to_name, new_comers_ids, user_movie_predict_ratings, r_max_calificacion_maxima, movies2profit):
    """
    Procesa las recomendaciones y genera datos tabulares.
    """
    table_data = []
    for usuario, lista_recomendacion, individuo, fitness in usuario_lista:
        fitness_str = ', '.join([f'{obj * -N_tamano_poblacion:.2f}' for obj in fitness])
        print(f'\nIndividuo {individuo}:')
        print(f'  Objetivos: {fitness_str}')
        print(f'  Usuario {usuario}: Recomendaciones:')
        for movie_id in lista_recomendacion:
            if movie_id not in new_comers_ids:
                rating = user_movie_predict_ratings[(usuario, movie_id)]
                profit = movies2profit[movie_id]
                profit_usuario = rating / r_max_calificacion_maxima * profit
                print(f'    - {movie_id_to_name[movie_id]}:')
                print(f'      - Posible rating: {rating:.2f}')
                print(f'      - Profit de la película: {profit:.2f}')
                print(f'      - Profit del usuario-pelicula: {profit_usuario:.2f}')
                table_data.append({
                    'Individuo': individuo,
                    **{f'Objetivo {i+1}': abs(obj) * N_tamano_poblacion for i, obj in enumerate(fitness)},
                    'Usuario': usuario,
                    'Movie ID': movie_id,
                    'Movie Title': movie_id_to_name[movie_id],
                    'Predicted Rating': rating,
                    'Movie Profit': profit,
                    'User-Movie Profit': profit_usuario
                })
            else:
                print(f'    - {movie_id_to_name[movie_id]}: New comer')
                table_data.append({
                    'Individuo': individuo,
                    **{f'Objetivo {i+1}': abs(obj) * N_tamano_poblacion for i, obj in enumerate(fitness)},
                    'Usuario': usuario,
                    'Movie ID': movie_id,
                    'Movie Title': movie_id_to_name[movie_id],
                    'Predicted Rating': 'New comer',
                    'Movie Profit': 'New comer',
                    'User-Movie Profit': 'New comer'
                })
    return table_data

def save_to_csv(table_data, output_csv):
    """
    Guarda los datos tabulares en un archivo CSV.
    """
    df = pd.DataFrame(table_data)
    df.to_csv(output_csv, index=False, encoding='utf-8')
    print(f'\nLa información tabular ha sido guardada en el archivo: {output_csv}')

# Main execution
log = logger.logger_class('EJEMPLOS')

# Cargar datos de películas
latest = False
movie_id_to_name = load_movie_data(latest)

# Obtener recomendaciones
individuos = poblacion_final.get_all_individuals()
# Mejor forma de calcular los pasos asegurando que sean al menos 1
step_individuo = max(1, len(individuos) // 10)
step_usuarios = max(1, len(individuos[0].get_matrix()) // 10)
usuario_lista = get_recommendations(individuos, step_individuo, step_usuarios)

# Procesar recomendaciones
table_data = process_recommendations(usuario_lista, movie_id_to_name, new_comers_ids, user_movie_predict_ratings, r_max_calificacion_maxima, movies2profit)

# Guardar resultados en un archivo CSV
output_csv = 'final_recomendations_examples.csv'
save_to_csv(table_data, output_csv)
# Out:
# Individuo 0:
#   Objetivos: 99.99, 0.01
#   Usuario 1: Recomendaciones:
#     - Thirty-Two Short Films About Glenn Gould (1993):
#       - Posible rating: 5.00
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 10.00
#     - Waiting for Guffman (1996):
#       - Posible rating: 4.75
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 9.50
#     - For Whom the Bell Tolls (1943):
#       - Posible rating: 4.48
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 8.96
#     - Ulee's Gold (1997):
#       - Posible rating: 4.40
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 8.81
#     - Whole Wide World, The (1996):
#       - Posible rating: 4.37
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 8.74
#     - His Girl Friday (1940):
#       - Posible rating: 4.22
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 8.45
#     - Spellbound (1945):
#       - Posible rating: 3.62
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 7.25
#     - Wonderful, Horrible Life of Leni Riefenstahl, The (1993):
#       - Posible rating: 3.62
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 7.25
#     - Mark of Zorro, The (1940):
#       - Posible rating: 3.62
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 7.25
#     - Farewell to Arms, A (1932):
#       - Posible rating: 3.62
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 7.25
#
# Individuo 9:
#   Objetivos: 39.36, 71.79
#   Usuario 95: Recomendaciones:
#     - Convent, The (Convento, O) (1995): New comer
#     - Theodore Rex (1995): New comer
#     - Manon of the Spring (Manon des sources) (1986):
#       - Posible rating: 5.00
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 10.00
#     - Waiting for Guffman (1996):
#       - Posible rating: 4.82
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 9.63
#     - Yankee Zulu (1994): New comer
#     - Hostile Intentions (1994): New comer
#     - Spellbound (1945):
#       - Posible rating: 4.26
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 8.52
#     - Boys Life (1995): New comer
#     - Captives (1994): New comer
#     - Walkabout (1971):
#       - Posible rating: 3.58
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 7.17
#
# Individuo 18:
#   Objetivos: 58.83, 49.90
#   Usuario 189: Recomendaciones:
#     - Butcher Boy, The (1998): New comer
#     - Angel on My Shoulder (1946): New comer
#     - Tough and Deadly (1995): New comer
#     - Underneath, The (1995): New comer
#     - Reluctant Debutante, The (1958): New comer
#     - T-Men (1947): New comer
#     - Gay Divorcee, The (1934):
#       - Posible rating: 5.00
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 10.00
#     - Simple Wish, A (1997): New comer
#     - Search for One-eye Jimmy, The (1996): New comer
#     - Foreign Correspondent (1940):
#       - Posible rating: 5.00
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 10.00
#
# Individuo 27:
#   Objetivos: 43.29, 67.80
#   Usuario 283: Recomendaciones:
#     - Fresh (1994):
#       - Posible rating: 4.90
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 9.79
#     - Walkabout (1971):
#       - Posible rating: 4.83
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 9.66
#     - Neon Bible, The (1995): New comer
#     - Simple Wish, A (1997): New comer
#     - Tough and Deadly (1995): New comer
#     - Boys, Les (1997): New comer
#     - Mirage (1995): New comer
#     - Squeeze (1996): New comer
#     - Mamma Roma (1962): New comer
#     - Mark of Zorro, The (1940):
#       - Posible rating: 4.58
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 9.15
#
# Individuo 36:
#   Objetivos: 60.43, 47.96
#   Usuario 377: Recomendaciones:
#     - Ulee's Gold (1997):
#       - Posible rating: 5.00
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 10.00
#     - Waiting for Guffman (1996):
#       - Posible rating: 4.37
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 8.74
#     - Horseman on the Roof, The (Hussard sur le toit, Le) (1995):
#       - Posible rating: 3.91
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 7.82
#     - Hunted, The (1995): New comer
#     - Walking Dead, The (1995): New comer
#     - Manon of the Spring (Manon des sources) (1986):
#       - Posible rating: 3.91
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 7.82
#     - American Strays (1996): New comer
#     - Babysitter, The (1995): New comer
#     - His Girl Friday (1940):
#       - Posible rating: 3.91
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 7.82
#     - Intimate Relations (1996): New comer
#
# Individuo 45:
#   Objetivos: 26.59, 85.79
#   Usuario 471: Recomendaciones:
#     - Even Cowgirls Get the Blues (1993): New comer
#     - Stars Fell on Henrietta, The (1995): New comer
#     - Vermin (1998): New comer
#     - Ed's Next Move (1996): New comer
#     - Men of Means (1998): New comer
#     - Outlaw, The (1943): New comer
#     - Lashou shentan (1992): New comer
#     - I Don't Want to Talk About It (De eso no se habla) (1993): New comer
#     - Turning, The (1992): New comer
#     - Kim (1950):
#       - Posible rating: 3.39
#       - Profit de la película: 8.71
#       - Profit del usuario-pelicula: 5.90
#
# Individuo 54:
#   Objetivos: 42.17, 68.98
#   Usuario 565: Recomendaciones:
#     - Fire on the Mountain (1996): New comer
#     - Good Man in Africa, A (1994): New comer
#     - Brothers in Trouble (1995): New comer
#     - They Made Me a Criminal (1939): New comer
#     - Wonderful, Horrible Life of Leni Riefenstahl, The (1993):
#       - Posible rating: 5.00
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 10.00
#     - Crossfire (1947): New comer
#     - Gay Divorcee, The (1934):
#       - Posible rating: 5.00
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 10.00
#     - Waiting for Guffman (1996):
#       - Posible rating: 5.00
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 10.00
#     - Relative Fear (1994): New comer
#     - Safe (1995):
#       - Posible rating: 5.00
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 10.00
#
# Individuo 63:
#   Objetivos: 53.06, 56.70
#   Usuario 659: Recomendaciones:
#     - Designated Mourner, The (1997): New comer
#     - Gilligan's Island: The Movie (1998): New comer
#     - 8 Heads in a Duffel Bag (1997): New comer
#     - Safe (1995):
#       - Posible rating: 5.00
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 10.00
#     - SubUrbia (1997):
#       - Posible rating: 5.00
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 10.00
#     - Lashou shentan (1992): New comer
#     - MURDER and murder (1996): New comer
#     - Favor, The (1994): New comer
#     - Whole Wide World, The (1996):
#       - Posible rating: 4.88
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 9.77
#     - Waiting for Guffman (1996):
#       - Posible rating: 4.52
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 9.04
#
# Individuo 72:
#   Objetivos: 15.57, 96.85
#   Usuario 753: Recomendaciones:
#     - Journey of August King, The (1995): New comer
#     - Sexual Life of the Belgians, The (1994): New comer
#     - The Innocent (1994): New comer
#     - Death in Brunswick (1991): New comer
#     - Anna (1996): New comer
#     - Stefano Quantestorie (1993): New comer
#     - Panther (1995): New comer
#     - Walk in the Sun, A (1945): New comer
#     - American Strays (1996): New comer
#     - Hotel de Love (1996): New comer
#
# Individuo 81:
#   Objetivos: 45.27, 65.48
#   Usuario 847: Recomendaciones:
#     - Careful (1992): New comer
#     - Fresh (1994):
#       - Posible rating: 3.76
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 7.52
#     - Ulee's Gold (1997):
#       - Posible rating: 3.19
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 6.38
#     - Nightwatch (1997): New comer
#     - Walkabout (1971):
#       - Posible rating: 3.07
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 6.14
#     - Day the Sun Turned Cold, The (Tianguo niezi) (1994): New comer
#     - Nelly & Monsieur Arnaud (1995): New comer
#     - Panther (1995): New comer
#     - Inkwell, The (1994): New comer
#     - Frankie Starlight (1995): New comer
#
# Individuo 90:
#   Objetivos: 41.10, 70.15
#   Usuario 941: Recomendaciones:
#     - Ulee's Gold (1997):
#       - Posible rating: 5.00
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 10.00
#     - Temptress Moon (Feng Yue) (1996): New comer
#     - Woman in Question, The (1950): New comer
#     - Nothing Personal (1995): New comer
#     - Legal Deceit (1997): New comer
#     - Nightwatch (1997): New comer
#     - Walkabout (1971):
#       - Posible rating: 5.00
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 10.00
#     - Romper Stomper (1992): New comer
#     - Etz Hadomim Tafus (Under the Domin Tree) (1994): New comer
#     - Golden Earrings (1947): New comer
#
# La información tabular ha sido guardada en el archivo: final_recomendations_examples.csv
