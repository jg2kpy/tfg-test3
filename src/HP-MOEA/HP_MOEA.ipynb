# %% [markdown]
# # A Hybrid Probabilistic Multiobjective Evolutionary Algorithm for Commercial Recommendation Systems
#
# Este archivo contiene una implementación del algoritmo HP-MOEA (Hybrid Probabilistic Multiobjective Evolutionary Algorithm), el cual integra técnicas de sistemas de recomendación con algoritmos evolutivos de optimización multiobjetivo. La descripción detallada del enfoque original se encuentra en este [paper](https://ieeexplore.ieee.org/abstract/document/9363322).

# %% [markdown]
# ## Requerimientos
#
# Para este proyecto se utilizan las siguientes bibliotecas: NumPy, Pandas, Pymoo y Matplotlib.
#
# Asegúrese de instalar las dependencias ejecutando el siguiente comando:

# %%
# %pip install numpy pandas pymoo matplotlib
# Out:
# Requirement already satisfied: numpy in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (1.26.4)
# Requirement already satisfied: pandas in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (2.2.3)
# Requirement already satisfied: pymoo in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (0.6.1.3)
# Requirement already satisfied: matplotlib in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (3.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: scipy>=1.1 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from pymoo) (1.14.1)
# Requirement already satisfied: autograd>=1.4 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from pymoo) (1.7.0)
# Requirement already satisfied: cma==3.2.2 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from pymoo) (3.2.2)
# Requirement already satisfied: alive-progress in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from pymoo) (3.2.0)
# Requirement already satisfied: dill in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from pymoo) (0.3.8)
# Requirement already satisfied: Deprecated in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from pymoo) (1.2.18)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: about-time==4.2.1 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from alive-progress->pymoo) (4.2.1)
# Requirement already satisfied: grapheme==0.6.0 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from alive-progress->pymoo) (0.6.0)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\jlgut\appdata\local\programs\python\python312\lib\site-packages (from Deprecated->pymoo) (1.17.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Preprocesamiento de datos
#
# Iniciaremos con el preprocesamiento de los datos utilizando el dataset MovieLens, desarrollado por la Universidad de Minnesota, el cual está disponible para uso libre con fines de investigación. Este dataset contiene calificaciones asignadas por usuarios a diversas películas. En esta implementación se utilizará la versión de 100,000 calificaciones, que abarca el período comprendido entre 1996 y 2018.
#
# Para más información sobre el dataset, puede consultarse el siguiente [enlace oficial](https://grouplens.org/datasets/movielens/).
#
# Para ver detalles de la implemetación del preprocesamiento, vea el archivo `preprocess.py`.

# %%
dataset_latest_small_path = '../../datasets/ml-latest-small/ratings.csv'
dataset_100k_path = '../../datasets/ml-100k/ratings.csv'
dataset_20m_path = '../../datasets/movielens-20m-dataset/rating.csv'
data_path = './data'
top_usuarios = 10000
newcomer_filter = 5

# %%
import preprocess

preprocess.main(dataset_100k_path, data_path, top_usuarios, newcomer_filter)
# Out:
# Leyendo el dataset desde: ../../datasets/ml-100k/ratings.csv
#
# Tamaño del dataframe original: 100000
# Eliminando la columna 'timestamp'
# Ordenando el dataset por la primera columna...
# Seleccionando los 10000 usuarios películas más comunes...
# Filtrando el dataframe para que solo contenga los usuarios seleccionados...
# Películas que aparecen más de 5 veces: 1298
# Películas que aparecen menos o igual a 5 veces (Newcomers): 384
#
# Cantidad total de usuarios: 943
# Cantidad total de peliculas: 1682
# Tamaño del dataframe actual: 100000
#
# Generando users2movie_ratings...
# [2025-07-23 22:25:30] [INFO] [update_users2movie_ratings] [0.07 segundos] 5.0%
# [2025-07-23 22:25:30] [INFO] [update_users2movie_ratings] [0.24 segundos] 15.0%
# [2025-07-23 22:25:31] [INFO] [update_users2movie_ratings] [0.43 segundos] 25.0%
# [2025-07-23 22:25:31] [INFO] [update_users2movie_ratings] [0.65 segundos] 35.0%
# [2025-07-23 22:25:31] [INFO] [update_users2movie_ratings] [0.88 segundos] 45.0%
# [2025-07-23 22:25:31] [INFO] [update_users2movie_ratings] [1.13 segundos] 55.0%
# [2025-07-23 22:25:32] [INFO] [update_users2movie_ratings] [1.40 segundos] 65.0%
# [2025-07-23 22:25:32] [INFO] [update_users2movie_ratings] [1.71 segundos] 75.0%
# [2025-07-23 22:25:32] [INFO] [update_users2movie_ratings] [2.03 segundos] 85.0%
# [2025-07-23 22:25:33] [INFO] [update_users2movie_ratings] [2.38 segundos] 95.0%
#
# Generando movies_info...
# [2025-07-23 22:25:33] [INFO] [Movies_info] [0.00 segundos] 4.99%
# [2025-07-23 22:25:33] [INFO] [Movies_info] [0.00 segundos] 9.99%
# [2025-07-23 22:25:33] [INFO] [Movies_info] [0.00 segundos] 14.98%
# [2025-07-23 22:25:33] [INFO] [Movies_info] [0.00 segundos] 19.98%
# [2025-07-23 22:25:33] [INFO] [Movies_info] [0.01 segundos] 24.97%
# [2025-07-23 22:25:33] [INFO] [Movies_info] [0.01 segundos] 29.96%
# [2025-07-23 22:25:33] [INFO] [Movies_info] [0.01 segundos] 34.96%
# [2025-07-23 22:25:33] [INFO] [Movies_info] [0.01 segundos] 39.95%
# [2025-07-23 22:25:33] [INFO] [Movies_info] [0.01 segundos] 44.95%
# [2025-07-23 22:25:33] [INFO] [Movies_info] [0.01 segundos] 49.94%
# [2025-07-23 22:25:33] [INFO] [Movies_info] [0.01 segundos] 54.93%
# [2025-07-23 22:25:33] [INFO] [Movies_info] [0.01 segundos] 59.93%
# [2025-07-23 22:25:33] [INFO] [Movies_info] [0.01 segundos] 64.92%
# [2025-07-23 22:25:33] [INFO] [Movies_info] [0.01 segundos] 69.92%
# [2025-07-23 22:25:33] [INFO] [Movies_info] [0.01 segundos] 74.91%
# [2025-07-23 22:25:33] [INFO] [Movies_info] [0.02 segundos] 79.9%
# [2025-07-23 22:25:33] [INFO] [Movies_info] [0.02 segundos] 84.9%
# [2025-07-23 22:25:33] [INFO] [Movies_info] [0.02 segundos] 89.89%
# [2025-07-23 22:25:33] [INFO] [Movies_info] [0.02 segundos] 94.89%
# [2025-07-23 22:25:33] [INFO] [Movies_info] [0.02 segundos] 99.88%
#
# Eliminando usuarios que solo tienen películas newcomers...
# Cantidad de usuarios eliminados por solo tener newcomers: 0
#
# Guardando los datos procesados en formato JSON...
# [2025-07-23 22:25:34] [SUCCESS] [PREPROCESS] [3.56 segundos] Datos de usuarios guardados en: ./data/users2movie_ratings.json
# [2025-07-23 22:25:34] [SUCCESS] [PREPROCESS] [3.56 segundos] Datos de películas guardados en: ./data/movies_info.json

# %% [markdown]
# ## Filtrado colaborativo basado en usuarios
#
# El siguente paso luego del preprocesamiento de los datos para HP-MOEA, es calcular la puntuación esperada de los ítems que los usuarios aun no han calificado, para ello se emplea el filtrado colaborativo basado en usuarios, la cual es la tecnica mas sencilla de los S.R.
#
# Para ver mas detalles de como se implemento el filtrado colaborativo basado en usuarios, ver el archivo `User_based_CF.py`.

# %%
import User_based_CF

K = 20
limit = 5
eliminar_newcomers = True
calcular_pesos = False # Debe estar True la primera vez que se ejecuta
hacer_test = False

usermovie2predict_rating = User_based_CF.main(data_path, K, limit, eliminar_newcomers, calcular_pesos, hacer_test)
# Out:
# Cargamos los datos preprocesados...
#
# Longitud de los datos preprocesados:
# users2movie_ratings:  1097886
# movies_info:  255146
# Eliminando newcomers...
# [2025-07-23 22:25:34] [INFO] [DELETING_NEWCOMERS] [0.00 segundos] 0.0%
# [2025-07-23 22:25:34] [INFO] [DELETING_NEWCOMERS] [0.02 segundos] 4.95%
# [2025-07-23 22:25:34] [INFO] [DELETING_NEWCOMERS] [0.03 segundos] 9.9%
# [2025-07-23 22:25:34] [INFO] [DELETING_NEWCOMERS] [0.05 segundos] 14.84%
# [2025-07-23 22:25:34] [INFO] [DELETING_NEWCOMERS] [0.07 segundos] 19.79%
# [2025-07-23 22:25:34] [INFO] [DELETING_NEWCOMERS] [0.08 segundos] 24.74%
# [2025-07-23 22:25:34] [INFO] [DELETING_NEWCOMERS] [0.10 segundos] 29.69%
# [2025-07-23 22:25:34] [INFO] [DELETING_NEWCOMERS] [0.12 segundos] 34.64%
# [2025-07-23 22:25:34] [INFO] [DELETING_NEWCOMERS] [0.13 segundos] 39.58%
# [2025-07-23 22:25:34] [INFO] [DELETING_NEWCOMERS] [0.15 segundos] 44.53%
# [2025-07-23 22:25:34] [INFO] [DELETING_NEWCOMERS] [0.17 segundos] 49.48%
# [2025-07-23 22:25:34] [INFO] [DELETING_NEWCOMERS] [0.18 segundos] 54.43%
# [2025-07-23 22:25:34] [INFO] [DELETING_NEWCOMERS] [0.20 segundos] 59.38%
# [2025-07-23 22:25:34] [INFO] [DELETING_NEWCOMERS] [0.22 segundos] 64.32%
# [2025-07-23 22:25:34] [INFO] [DELETING_NEWCOMERS] [0.23 segundos] 69.27%
# [2025-07-23 22:25:34] [INFO] [DELETING_NEWCOMERS] [0.25 segundos] 74.22%
# [2025-07-23 22:25:34] [INFO] [DELETING_NEWCOMERS] [0.27 segundos] 79.17%
# [2025-07-23 22:25:34] [INFO] [DELETING_NEWCOMERS] [0.28 segundos] 84.11%
# [2025-07-23 22:25:34] [INFO] [DELETING_NEWCOMERS] [0.30 segundos] 89.06%
# [2025-07-23 22:25:34] [INFO] [DELETING_NEWCOMERS] [0.32 segundos] 94.01%
# [2025-07-23 22:25:34] [INFO] [DELETING_NEWCOMERS] [0.33 segundos] 98.96%
# [2025-07-23 22:25:34] [SUCCESS] [DELETING_NEWCOMERS] [0.34 segundos] Se eliminaron 968 calificaciones por ser de newcomers
#
# Cantidad de usuarios: 943
# Cantidad de peliculas: 1298
#
# Iniciamos las predicciones con User Based Collaborative Filtering...
# [2025-07-23 22:25:34] [INFO] [PREDICCIÓN] [0.01 segundos] 0.0%
# [2025-07-23 22:25:35] [INFO] [PREDICCIÓN] [0.60 segundos] 4.98%
# [2025-07-23 22:25:35] [INFO] [PREDICCIÓN] [1.16 segundos] 9.97%
# [2025-07-23 22:25:36] [INFO] [PREDICCIÓN] [1.76 segundos] 14.95%
# [2025-07-23 22:25:36] [INFO] [PREDICCIÓN] [2.26 segundos] 19.94%
# [2025-07-23 22:25:37] [INFO] [PREDICCIÓN] [2.78 segundos] 24.92%
# [2025-07-23 22:25:37] [INFO] [PREDICCIÓN] [3.28 segundos] 29.9%
# [2025-07-23 22:25:38] [INFO] [PREDICCIÓN] [3.76 segundos] 34.89%
# [2025-07-23 22:25:38] [INFO] [PREDICCIÓN] [4.25 segundos] 39.87%
# [2025-07-23 22:25:39] [INFO] [PREDICCIÓN] [4.73 segundos] 44.86%
# [2025-07-23 22:25:39] [INFO] [PREDICCIÓN] [5.21 segundos] 49.84%
# [2025-07-23 22:25:40] [INFO] [PREDICCIÓN] [5.69 segundos] 54.83%
# [2025-07-23 22:25:40] [INFO] [PREDICCIÓN] [6.19 segundos] 59.81%
# [2025-07-23 22:25:41] [INFO] [PREDICCIÓN] [6.70 segundos] 64.79%
# [2025-07-23 22:25:41] [INFO] [PREDICCIÓN] [7.19 segundos] 69.78%
# [2025-07-23 22:25:42] [INFO] [PREDICCIÓN] [7.69 segundos] 74.76%
# [2025-07-23 22:25:42] [INFO] [PREDICCIÓN] [8.19 segundos] 79.75%
# [2025-07-23 22:25:43] [INFO] [PREDICCIÓN] [8.70 segundos] 84.73%
# [2025-07-23 22:25:43] [INFO] [PREDICCIÓN] [9.20 segundos] 89.71%
# [2025-07-23 22:25:44] [INFO] [PREDICCIÓN] [9.69 segundos] 94.7%
# [2025-07-23 22:25:44] [INFO] [PREDICCIÓN] [10.18 segundos] 99.68%
# [2025-07-23 22:25:44] [SUCCESS] [PREDICCIÓN] [10.21 segundos] Termino la predicción
#
# Termino la ejecución del filtrado colaborativo basado en usuarios, los datos se guardaron en ./data/usermovie2predict_rating.json

# %% [markdown]
# ## Carga de datos preprocesados y definición de parámetros del algoritmo

# %% [markdown]
# Se cargan los datos limpios y se definen como constantes globales los parámetros clave del algoritmo.

# %%
import numpy as np
import random
from pymoo.util.ref_dirs import get_reference_directions

#np.set_printoptions(threshold=np.inf)

data_path = './data'

#Configuración del paper
u_turning_point = 500
L_tamano_lista = 10
N_tamano_poblacion = 100
T_iteraciones = 3000
Pm_probabilidad_mutacion = 1/L_tamano_lista
r_max_calificacion_maxima = 5
max_profit = 1
max_novelty = 1
n_obj = 3

# Generar una semilla aleatoria para reproducibilidad
nice_seed = random.randint(0, 100000) #69
print(f"Semilla aleatoria generada: {nice_seed}")

poblacion_global = []

historial_fitness = []

use_precalculated_CF = True
CF_config = {
    "K": 25,
    "limit": 5,
    "calcular_pesos": False,
    "hacer_test": False,
}

algorithms = [
    'NSGA-II', #0
    'SMS-EMOA', #1
    'NSGA-III', #2
    'MOEA/D' #3
]

algorithm_name = algorithms[2]

carpeta_resultados = 'modificacion2'

ref_dirs = get_reference_directions("das-dennis", n_obj, n_partitions=12)

test_mode = True
if test_mode:
    T_iteraciones = 50 #50
    L_tamano_lista = 10 #10
    N_tamano_poblacion = 100 #100
    Pm_probabilidad_mutacion = 1/10

iteracion = 0
# Out:
# Semilla aleatoria generada: 21102

# %%
import os
import logger

from classes.Movies_info import Movies_info
from classes.Users import Users

log = logger.logger_class('LOAD_DATASET')

log.info('Cargamos los datos preprocesados')

if  os.path.exists(f'{data_path}/users2movie_ratings.json') and \
    os.path.exists(f'{data_path}/movies_info.json') and \
    os.path.exists(f'{data_path}/users2predict_movie_ratings.json')   :

    with open(f'{data_path}/users2movie_ratings.json', 'r') as f:
        users2movie_ratings_json = f.read()

    with open(f'{data_path}/movies_info.json', 'r') as f:
        movies_info_json = f.read()

    with open(f'{data_path}/users2predict_movie_ratings.json', 'r') as f:
        users2predict_movie_ratings_json = f.read()

    print('\nLongitud de los datos preprocesados:')
    print("users2movie_ratings: ", len(users2movie_ratings_json))
    print("users2predict_movie_ratings: ", len(users2predict_movie_ratings_json))
    print("movies_info: ", len(movies_info_json))

    # Estas estructuras serian similares a los Repository en Spring Boot
    users2movie_ratings = Users(fromJson=users2movie_ratings_json)
    users = users2movie_ratings.get_all_users()
    U_cant_usuarios = users2movie_ratings.get_len_users()
    users_ratings_data = {user.get_id(): user for user in users2movie_ratings.get_all_users()}
    users_profile = users2movie_ratings.get_all_users_profile()

    users2predict_movie_ratings = Users(fromJson=users2predict_movie_ratings_json)
    users_predicted_ratings = users2predict_movie_ratings.get_all_users()
    user_movie_predict_ratings = users2predict_movie_ratings.get_user_movie_ratings()

    movies_info = Movies_info(fromJson=movies_info_json)
    movies_ids = movies_info.get_all_movie_ids()
    movies_ids_set = set(movies_ids)
    new_comers_ids = movies_info.get_all_newcomers_ids()
    newcomers_id_set = set(new_comers_ids)
    movies2profit = movies_info.get_movies_with_profits()
    movies_content = movies_info.get_all_movies_content()

    ID_MIN = min(movies_ids)
    ID_MAX = max(movies_ids)

    print("\nU_cant_usuarios:", U_cant_usuarios)
    print("Cantidad de peliculas:", len(movies_ids_set))
    print("ID_MIN (movies):", ID_MIN)
    print("ID_MAX (movies):", ID_MAX)
    print("Cantidad de newcomers:", len(new_comers_ids))
    log.success('Datos preprocesados cargados correctamente')
# Out:
# [2025-07-23 22:25:45] [INFO] [LOAD_DATASET] [0.00 segundos] Cargamos los datos preprocesados
#
# Longitud de los datos preprocesados:
# users2movie_ratings:  1097886
# users2predict_movie_ratings:  34569109
# movies_info:  255146
#
# U_cant_usuarios: 943
# Cantidad de peliculas: 1682
# ID_MIN (movies): 1
# ID_MAX (movies): 1682
# Cantidad de newcomers: 384
# [2025-07-23 22:25:46] [SUCCESS] [LOAD_DATASET] [0.94 segundos] Datos preprocesados cargados correctamente

# %% [markdown]
# ## Definición de clases y funciones auxiliares
# Esta sección contiene clases y funciones auxiliares utilizadas para la ejecución de la clase principal y el ciclo de procesamiento.

# %%
import hashlib

def hash_matrix_func(matrix):
    matrix_str = ''.join(map(str, matrix.flatten()))
    return hashlib.sha256(matrix_str.encode()).hexdigest()

# %%
np.random.seed(nice_seed)

class Individuo():
    def __init__(self, new_matrix=None):
        global max_profit, max_novelty, max_relevance
        if isinstance(new_matrix, (np.ndarray, list)):
            self.matrix = np.array(new_matrix)
        else:
            matrix_aux = []
            for user in users:
                movies_ids_user_rated = set(user.get_movie_ids())
                posibles_ids = list(movies_ids_set - movies_ids_user_rated)
                matrix_aux.append(np.random.choice(posibles_ids, L_tamano_lista, replace=False))
            self.matrix = np.array(matrix_aux)

        self.profit = None
        self.novelty = None
        self.relevance = None

        self.rank = None
        self.crowding_distance = None
        self.hv_contribution = None

        self.hash = hash_matrix_func(self.matrix)

    def get_profit(self):
        if self.profit == None:
            self.profit = self._calculate_profit()
        return self.profit

    def get_novelty(self):
        if self.novelty == None:
            self.novelty = self._calculate_novelty()
        return self.novelty

    def get_relevance(self):
        if self.relevance == None:
            self.relevance = self._calculate_relevance()
        return self.relevance

    def get_fitness(self):
        self.fitness = [-self.get_profit() / max_profit, -self.get_novelty() / max_novelty, -self.get_relevance() / max_relevance]
        return self.fitness

    def _calculate_profit(self):
        profit_total = 0

        for user_id, lista_recomendacion in enumerate(self.matrix, start=1):
            for movie_id in lista_recomendacion:
                if movie_id in newcomers_id_set:
                    profit = 1
                else:
                    r_calificacion = user_movie_predict_ratings[(user_id, movie_id)]
                    profit_i = movies_info.get_profit_by_movie_id(movie_id)
                    profit = (r_calificacion / r_max_calificacion_maxima) * profit_i
                profit_total += profit

        return profit_total

    def _calculate_novelty(self):
        novelty = 0
        for _, lista_recomendacion in enumerate(self.matrix, start=1):
            for movie_id in lista_recomendacion:
                if movie_id in newcomers_id_set:
                    novelty += 1
        return novelty

    def _calculate_relevance(self):
        relevance = 0
        for user_id, lista_recomendacion in enumerate(self.matrix, start=1):
            for movie_id in lista_recomendacion:
                user_profile = users_profile.get(user_id)
                movie_content = movies_content.get(movie_id)

                resultado = sum(u for u, m in zip(user_profile, movie_content) if m == 1)

                relevance += (resultado / 190) # Top 10 del usuario y hay 19 categorias
        return relevance

    def get_matrix(self):
        return self.matrix

    def get_hash(self):
        return self.hash

    def get_matrix_flatten(self):
        return self.matrix.flatten()

    def get_rank(self):
        return self.rank

    def set_rank(self, new_rank):
        self.rank = new_rank

    def get_crowding_distance(self):
        return self.crowding_distance

    def set_crowding_distance(self, new_crowding_distance):
        self.crowding_distance = new_crowding_distance

    def get_hv_contribution(self):
        return self.hv_contribution

    def set_hv_contribution(self, new_hv_contribution):
        self.hv_contribution = new_hv_contribution

    def get_row(self, index):
        return self.matrix[index]

    def recalcular(self):
        self.profit = self._calculate_profit()
        self.novelty = self._calculate_novelty()
        self.relevance = self._calculate_relevance()
        self.fitness = self.get_fitness()
        self.hash = hash_matrix_func(self.matrix)

        self.rank = None
        self.crowding_distance = None
        self.hv_contribution = None

    def replace_element_in_matrix(self, user, position, new_value):
        self.matrix[user, position] = new_value
        self.recalcular()

# %%
class Poblacion():

    def __init__(self, individuos, initial_population = False):
        if initial_population:
            self.poblacion = {individuo.get_hash(): individuo for individuo in individuos}
            self.fitnessF = None
        elif individuos != []:
            self.poblacion = {}
            for individuo_matrix in individuos.X:
                individuo_obj = poblacion_global.get_by_matrix_flatted(individuo_matrix)
                self.poblacion[individuo_obj.get_hash()] = individuo_obj
            self.poblacionX = individuos.X
            self.fitnessF = individuos.F

    def get_by_matrix_flatted(self, matrix_flatted):
        matrix = self.reshape_matrix(matrix_flatted)
        hash_matrix = hash_matrix_func(matrix)
        return self.poblacion[hash_matrix]

    def get_or_create_by_matrix_flatted(self, matrix_flatted):
        matrix = self.reshape_matrix(matrix_flatted)
        hash_matrix = hash_matrix_func(matrix)
        if hash_matrix not in self.poblacion:
            new_individual = Individuo(matrix)
            self.add_individual(new_individual)
        return self.poblacion[hash_matrix]

    def get_all_matrix(self):
        return [individuo.get_matrix() for individuo in self.poblacion.values()]

    def get_all_matrix_flatten(self):
        return [individuo.get_matrix_flatten() for individuo in self.poblacion.values()]

    def reshape_matrix(self, matrix):
        return matrix.reshape(U_cant_usuarios, L_tamano_lista)

    def add_individual(self, individual):
        if individual.get_hash() not in self.poblacion:
            self.poblacion[individual.get_hash()] = individual

    def replace_individual(self, old_individual, new_individual):
        old_hash = old_individual.get_hash()
        new_hash = new_individual.get_hash()
        if old_hash in self.poblacion:
            del self.poblacion[old_hash]
        self.poblacion[new_hash] = new_individual

    def get_total_fitness(self):
        total_fitness = []
        for individuo in self.poblacion.values():
            total_fitness.append(individuo.get_fitness())
        return total_fitness

    def get_all_individual_as_array(self):
        return list(self.poblacion.values())

    def get_fitness_F(self):
        return self.fitnessF

    def get_poblacion_X(self):
        return self.poblacionX

    def get_history(self):
        return self.history

    def get_all_individuals(self):
        return list(self.poblacion.values())

# %% [markdown]
# ### Obtener los individuos maximos

# %%
np.random.seed(nice_seed)

def get_individual_max_profit():
    global max_profit
    matrix_max_profit = []

    for user in users:
        user_id = user.get_id()
        movies_predict = users2predict_movie_ratings.get_movies_and_ratings_by_user_id(user_id)

        movies_predict = [(movie_id, rating) for movie_id, rating in movies_predict if movie_id not in newcomers_id_set]
        sorted_movies = sorted(movies_predict, key=lambda x: (movies2profit.get(x[0]), x[1]), reverse=True)

        matrix_max_profit.append([movie for movie, _ in sorted_movies[:L_tamano_lista]])

    individual_max_profit = Individuo(matrix_max_profit)
    max_profit = individual_max_profit.get_profit()
    print(f"max_profit: {max_profit}")

    return individual_max_profit


def get_individual_max_novelty():
    global max_novelty
    matrix_max_novelty = []

    for user in users:
        movies_ids_user_rated = set(user.get_movie_ids())
        posibles_ids = list(newcomers_id_set - movies_ids_user_rated)

        user_profile = users_profile.get(user.get_id())

        user_movie_affinity = {
            new_comers_id: sum(u for u, m in zip(user_profile, movies_content.get(new_comers_id)) if m == 1)
            for new_comers_id in posibles_ids
        }

        top_affinity_movies = sorted(user_movie_affinity.items(), key=lambda x: x[1], reverse=True)[:L_tamano_lista]
        matrix_max_novelty.append([movie_id for movie_id, _ in top_affinity_movies])

    individual_max_novelty = Individuo(matrix_max_novelty)
    max_novelty = individual_max_novelty.get_novelty()
    print(f"max_novelty: {max_novelty}")

    return individual_max_novelty

def get_individual_max_relevance():
    global max_relevance
    matrix_max_relevance = []

    for user in users:
        movies_ids_user_rated = set(user.get_movie_ids())
        posibles_ids = list(movies_ids_set - movies_ids_user_rated)

        user_profile = users_profile.get(user.get_id())

        user_movie_affinity = {
            movie_id: sum(u for u, m in zip(user_profile, movies_content.get(movie_id)) if m == 1)
            for movie_id in posibles_ids
        }

        top_affinity_movies = sorted(user_movie_affinity.items(), key=lambda x: x[1], reverse=True)[:L_tamano_lista]
        matrix_max_relevance.append([movie_id for movie_id, _ in top_affinity_movies])

    individual_max_relevance = Individuo(matrix_max_relevance)
    max_relevance = individual_max_relevance.get_relevance()
    print(f"max_relevance: {max_relevance}")

    return individual_max_relevance

# %% [markdown]
# ## Problema multiobjetivo y operadores geneticos

# %% [markdown]
# Calculo de metricas de la población para el cruce

# %%
from pymoo.indicators.hv import Hypervolume
from pymoo.util.nds.non_dominated_sorting import NonDominatedSorting
from pymoo.operators.survival.rank_and_crowding.metrics import get_crowding_function
from sklearn.preprocessing import MinMaxScaler

def calculate_population_metrics(population, log):

    log.info('Calculando metricas de la población...')
    fitness_of_population = np.array([individuo.get_fitness() for individuo in population])
    reference_point = np.max(fitness_of_population, axis=0) + 1
    hv = Hypervolume(ref_point=reference_point)
    total_hv = hv.do(fitness_of_population)
    nds = NonDominatedSorting()
    fronts = nds.do(fitness_of_population, only_non_dominated_front=False)
    crowding_function = get_crowding_function("cd")

    # Normalización para NSGA-III, MOEA/D
    scaler = MinMaxScaler()
    normalized_fitness = scaler.fit_transform(fitness_of_population)

    for rank, front in enumerate(fronts):
        if len(front) == 0:
            continue

        if algorithm_name == "NSGA-II":
            front_fitness = fitness_of_population[front]
            crowding = crowding_function.do(front_fitness)
        elif algorithm_name == "NSGA-III":
            norm_front_fitness = normalized_fitness[front]
            crowding = [np.min(np.linalg.norm(p - ref_dirs, axis=1)) for p in norm_front_fitness]

        for idx_in_front, idx_population in enumerate(front):
            individuo = population[idx_population]

            individuo.set_rank(rank)

            individuo.set_crowding_distance(crowding[idx_in_front])

            reduced_fitness = np.delete(fitness_of_population, idx_population, axis=0)
            reduced_hv = Hypervolume(ref_point=reference_point).do(reduced_fitness)
            hv_contrib = total_hv - reduced_hv

            individuo.set_hv_contribution(hv_contrib)
        #log.percentage(rank, len(fronts), mensaje='Metricas de la población: ')
    log.success('El calculo de metricas de población ha finalizado correctamente')

# %% [markdown]
# ### Definición del problema

# %%
from pymoo.core.problem import Problem

class HP_MOEA_Problem(Problem):

    def __init__(self, log, *args, **kwargs):
        n_var = U_cant_usuarios * L_tamano_lista
        xl = [ID_MIN for _ in range(n_var)]
        xu = [ID_MAX for _ in range(n_var)]
        self.log = log

        super().__init__(n_var = n_var, n_obj = n_obj, xl = xl, xu = xu, *args, **kwargs)

    def _evaluate(self, x, out, *args, **kwargs):
        global iteracion
        self.log.info('Iniciando evaluación con los valores del fitness...')
        res = []
        poblacion_aux = []
        lenX = len(x)
        for i, matrix in enumerate(x):
            individuo = poblacion_global.get_or_create_by_matrix_flatted(matrix)
            poblacion_aux.append(individuo)
            res.append(individuo.get_fitness())
            #self.log.percentage(i, lenX, mensaje='Evaluación: ')

        calculate_population_metrics(poblacion_aux, self.log)

        out["F"] = np.array(res)
        self.log.success('Termino la evaluación')
        self.log.percentage(iteracion, T_iteraciones, "Porcentaje de ejecución: ")
        self.log.success(f'Iteración del algoritmo: {iteracion}/{T_iteraciones}')
        iteracion+=1
        super()._evaluate(x, out, *args, **kwargs)

# %%
from pymoo.core.sampling import Sampling

class HP_MOEA_Sampling(Sampling):

    def __init__(self, initial_population):
        self.initial_population = initial_population
        super().__init__()

    def _do(self, problem, n_samples, **kwargs):
        return self.initial_population

# %% [markdown]
# ### Definición del operador genetico de mutación

# %%
from pymoo.core.mutation import Mutation
from pymoo.core.population import Population

np.random.seed(nice_seed)

def get_random_id_not_in(ban_list):
    posibles_ids = [movie_id for movie_id in movies_ids_set if movie_id not in ban_list]
    return np.random.choice(posibles_ids)

class HP_MOEA_SP_Mutation(Mutation):

    def __init__(self, Pm_probabilidad_mutacion, log):
        super().__init__()
        self.Pm_probabilidad_mutacion = Pm_probabilidad_mutacion
        self.log = log

    def _do(self, problem, X, **kwargs):
        global poblacion_global
        self.log.info("Iniciando operador de mutación...")

        X_mut = X.copy()

        for matrix_i, matrix in enumerate(X):
            if np.random.random() < self.Pm_probabilidad_mutacion:
                individuo = poblacion_global.get_by_matrix_flatted(matrix)

                user_i = np.random.randint(U_cant_usuarios)
                position = np.random.randint(L_tamano_lista)

                lista_recomendacion = individuo.get_row(user_i)
                user = users2movie_ratings.get_user_by_id(user_i + 1)
                movies_ids_user_rated = user.get_movie_ids()
                ban_list = set(movies_ids_user_rated + list(lista_recomendacion))
                nueva_pelicula = get_random_id_not_in(ban_list)

                #self.log.info(f"Individuo {matrix_i}, mutando en posición ({user_i}, {position}) reemplazando película {lista_recomendacion[position]} con {nueva_pelicula}")
                individuo.replace_element_in_matrix(user_i, position, nueva_pelicula)
                X_mut[matrix_i] = individuo.get_matrix_flatten()
                poblacion_global.add_individual(individuo)
            #self.log.percentage(matrix_i, len(X), mensaje='Operador de mutación: ')

        self.log.success('Operador de mutación finalizado correctamente')
        return X_mut


def test_HP_MOEA_SP_Mutation():
    poblacion_array = []
    for user in users_predicted_ratings[:5]:
        movies_ids_user_rated = user.get_movie_ids()
        posibles_ids = list(movies_ids_set - set(movies_ids_user_rated))
        lista_recomendacion = np.random.choice(posibles_ids, L_tamano_lista, replace=False)
        poblacion_array.append(lista_recomendacion)

    poblacion_array = np.array(poblacion_array)

    print("Población original:")
    print(poblacion_array)

    log = logger.logger_class('MUTACION_TEST')

    mutation = HP_MOEA_SP_Mutation(Pm_probabilidad_mutacion, log)

    # Create a Population object with the original population array
    pop = Population.new("X", poblacion_array.copy())

    # Apply the mutation operator
    mutated_pop = mutation._do(None, pop.get("X"))

    print("\nPoblación mutada:")
    print(mutated_pop)

    print("\nCambios detectados:")
    for i in range(len(poblacion_array)):
        original = poblacion_array[i]
        mutado = mutated_pop[i].reshape(L_tamano_lista)
        cambios = [(o, m) for o, m in zip(original, mutado) if o != m]
        if cambios:
            print(f"Usuario {i + 1}: {cambios}")

#test_HP_MOEA_SP_Mutation()

# %% [markdown]
# ### Definición del operador genetico de cruce

# %% [markdown]
# Probabilidad genetica para NSGA-II
#
# ![image.png](attachment:image.png)

# %%
import warnings
warnings.filterwarnings('ignore', category=RuntimeWarning)

def lambda_NSGA2(A, B):
    rank_A = A.get_rank()
    rank_B = B.get_rank()

    if rank_A != rank_B and (rank_A + rank_B) != 0:
        return rank_B / (rank_A + rank_B)

    dist_A = A.get_crowding_distance()
    dist_B = B.get_crowding_distance()
    if (dist_A + dist_B) != 0:
        return dist_A / (dist_A + dist_B)

    return float('inf')

# %% [markdown]
# Probabilidad genetica para NSGA-III

# %%
def lambda_NSGA3(A, B):
    rank_A = A.get_rank()
    rank_B = B.get_rank()

    if rank_A != rank_B and (rank_A + rank_B) != 0:
        return rank_B / (rank_A + rank_B)

    # crowding_distance se interpreta como "distancia al ref_dir más cercano"
    dist_A = A.get_crowding_distance()
    dist_B = B.get_crowding_distance()
    if (dist_A + dist_B) != 0:
        # menor distancia es mejor → invertir proporción
        return dist_B / (dist_A + dist_B)

    return float('inf')

# %% [markdown]
# Probabilidad genetica para SMS-EMOA
#
# ![image.png](attachment:image.png)

# %%
import warnings
warnings.filterwarnings('ignore', category=RuntimeWarning)

def lambda_SMS_EMOA(A, B):
    rank_A = A.get_rank()
    rank_B = B.get_rank()

    if rank_A != rank_B and (rank_A + rank_B) != 0:
        return rank_B / (rank_A + rank_B)

    contrib_A = A.get_hv_contribution()
    contrib_B = B.get_hv_contribution()

    if contrib_A is not None and contrib_B is not None and (contrib_A + contrib_B) != 0:
        return contrib_A / (contrib_A + contrib_B)

    dist_A = A.get_crowding_distance()
    dist_B = B.get_crowding_distance()
    if (dist_A + dist_B) != 0:
        return dist_A / (dist_A + dist_B)

    return float('inf')

# %% [markdown]
# Funcion del operador genetico de cruce entre individuos.
#
# ![image.png](attachment:image.png)

# %%
from pymoo.core.crossover import Crossover

np.random.seed(nice_seed)

class HP_MOEA_Crossover(Crossover):

    def __init__(self, log):
        # número de padres y número de hijos
        self.parents = 2
        self.offsprings = 1
        self.log = log
        super().__init__(n_parents=self.parents, n_offsprings=self.offsprings)

    def pass_same_genes(self, S_child, A_parent, B_parent):
        A_distinctive_genes = []
        B_distinctive_genes = []
        S_genes_size = 0

        for gene in A_parent:
            if gene in B_parent:
                S_child[S_genes_size] = gene
                S_genes_size += 1
            else:
                A_distinctive_genes.append(gene)

        for gene in B_parent:
            if gene not in A_parent:
                B_distinctive_genes.append(gene)

        return A_distinctive_genes, B_distinctive_genes, S_genes_size

    def crossover(self, A_parent, B_parent, algorithm_name):
        global poblacion_global
        S_child = np.zeros((U_cant_usuarios, L_tamano_lista), dtype=int)
        lambda_genetic_probability = lambda_NSGA2(A_parent, B_parent) if algorithm_name == 'NSGA2' else lambda_NSGA3(A_parent, B_parent)
        for i in range(U_cant_usuarios):
            A_distinctive_genes, B_distinctive_genes, S_genes_size = self.pass_same_genes(S_child[i], A_parent.get_row(i), B_parent.get_row(i))
            A_index = 0
            B_index = 0

            for j in range(S_genes_size, L_tamano_lista):
                if np.random.random() < lambda_genetic_probability:
                    S_child[i][j] = A_distinctive_genes[A_index]
                    A_index+=1
                else:
                    S_child[i][j] = B_distinctive_genes[B_index]
                    B_index+=1

        new_child = Individuo(S_child)
        poblacion_global.add_individual(new_child)
        return new_child

    def _do(self, problem, X, **kwargs):
        global poblacion_global
        self.log.info("Iniciando operador de cruce...")

        n_parents, n_matings, n_var = X.shape

        algorithm = kwargs.get('algorithm')
        algorithm_name = algorithm.__class__.__name__

        Y_children = np.full((self.n_offsprings, n_matings, problem.n_var), None, dtype=object)

        for i in range(n_matings):
            A_parent = poblacion_global.get_by_matrix_flatted(X[0, i])
            B_parent = poblacion_global.get_by_matrix_flatted(X[1, i])
            S_child = self.crossover(A_parent, B_parent, algorithm_name)

            Y_children[0, i, :] = S_child.get_matrix_flatten()
            #self.log.percentage(i, n_matings, mensaje='Operador de cruce: ')

        self.log.success("Operador de cruce finalizado correctamente")
        return Y_children

# %% [markdown]
# ### Selector de algortimos evolutivos

# %%
from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.algorithms.moo.sms import SMSEMOA
from pymoo.algorithms.moo.nsga3 import NSGA3
from pymoo.algorithms.moo.moead import MOEAD

def select_algorithm(algorithm_name, population, log):
    if algorithm_name == 'NSGA-II':
        return NSGA2(
            pop_size = N_tamano_poblacion,
            eliminate_duplicates = False,
            sampling = HP_MOEA_Sampling(population.get_all_matrix_flatten()),
            mutation = HP_MOEA_SP_Mutation(Pm_probabilidad_mutacion, log),
            crossover = HP_MOEA_Crossover(log)
        )

    elif algorithm_name == 'SMS-EMOA':
        return SMSEMOA(
            pop_size = N_tamano_poblacion,
            eliminate_duplicates = False,
            sampling = HP_MOEA_Sampling(population.get_all_matrix_flatten()),
            mutation = HP_MOEA_SP_Mutation(Pm_probabilidad_mutacion, log),
            crossover = HP_MOEA_Crossover(log),
            n_offsprings = N_tamano_poblacion
        )
    elif algorithm_name == "NSGA-III":
        return NSGA3(
            pop_size = N_tamano_poblacion,
            ref_dirs = ref_dirs,
            eliminate_duplicates = False,
            sampling = HP_MOEA_Sampling(population.get_all_matrix_flatten()),
            mutation = HP_MOEA_SP_Mutation(Pm_probabilidad_mutacion, log),
            crossover = HP_MOEA_Crossover(log)
        )
    else:
        raise ValueError(f"Algoritmo '{algorithm_name}' no reconocido.")

# %% [markdown]
# ## Definición de la clase HP_MOEA_Class
# Esta sección define la clase principal HP_MOEA_Class, encargada de gestionar la lógica central del algoritmo.

# %%
import copy
import logger
import User_based_CF as UBCF

from pymoo.optimize import minimize
from pymoo.indicators.hv import Hypervolume
from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.algorithms.moo.sms import SMSEMOA


class HP_MOEA_Class():

    def __init__(self, algorithm_name):
        self.log = logger.logger_class('HP_MOEA_CLASS')
        self.iteracion_actual = 0
        self.population = []
        self.algorithm_name = algorithm_name
        self.log.info('Se inicializo una instancia de la clase HP_MOEA_CLASS, la configuración es:')
        self.log.info(f'test_mode = {test_mode}')
        self.log.info(f'u_turning_point = {u_turning_point}')
        self.log.info(f'L_tamano_lista = {L_tamano_lista}')
        self.log.info(f'N_tamano_poblacion = {N_tamano_poblacion}')
        self.log.info(f'T_iteraciones = {T_iteraciones}')
        self.log.info(f'Pm_probabilidad_mutacion = {Pm_probabilidad_mutacion}')
        self.log.info(f'r_max_calificacion_maxima = {r_max_calificacion_maxima}')
        self.log.info(f'algorithm_name = {algorithm_name}')


    def generate_initial_population(self):
        self.log.info('Inicializando población...')
        initial_population = []

        self.log.percentage(0, N_tamano_poblacion, mensaje='Población inicial: ')
        individual_max_profit = get_individual_max_profit()
        self.log.percentage(1, N_tamano_poblacion, mensaje='Población inicial: ')
        individual_max_novelty = get_individual_max_novelty()
        self.log.percentage(2, N_tamano_poblacion, mensaje='Población inicial: ')
        individual_max_relevance = get_individual_max_relevance()
        self.log.percentage(3, N_tamano_poblacion, mensaje='Población inicial: ')

        initial_population.append(individual_max_profit)
        initial_population.append(individual_max_novelty)
        initial_population.append(individual_max_relevance)

        for i in range(n_obj, N_tamano_poblacion):
            initial_population.append(Individuo())
            self.log.percentage(i, N_tamano_poblacion, mensaje='Población inicial: ')

        self.set_population(initial_population, initial_population = True)

        self.log.success('Población inicializada correctamente')
        return self.population

    def termination_condition(self):
        self.log.success(f'Iteración del algoritmo: {self.iteracion_actual}/{T_iteraciones}')
        self.log.percentage(self.iteracion_actual, T_iteraciones, 'Porcentaje total del algoritmo: ')
        if self.iteracion_actual >= T_iteraciones:
            return True
        self.iteracion_actual+=1
        return False

    def set_population(self, new_population, initial_population=False):
        global poblacion_global

        if self.population == new_population:
            poblacion_global = copy.deepcopy(new_population)
            return

        if initial_population:
            new_population = Poblacion(new_population, initial_population=True)

        calculate_population_metrics(new_population.get_all_individual_as_array(), self.log)
        self.population = new_population
        poblacion_global = copy.deepcopy(new_population)
        historial_fitness.append(self.population.get_fitness_F())

    def generate_new_population_NSGAII(self):
        self.log.info('Generando población con NSGA-II...')

        algorithm = NSGA2(
            pop_size = N_tamano_poblacion,
            eliminate_duplicates = False,
            sampling = HP_MOEA_Sampling(self.population.get_all_matrix_flatten()),
            mutation = HP_MOEA_SP_Mutation(Pm_probabilidad_mutacion, self.log),
            crossover = HP_MOEA_Crossover(self.log)
        )

        new_population = minimize(
            problem = HP_MOEA_Problem(self.log),
            algorithm = algorithm,
            termination = ('n_gen', 2),
            seed = nice_seed,
            verbose = False,
            save_history = False
        )

        self.log.success('Población con NSGA-II generada correctamente')
        return Poblacion(new_population)

    def get_hypervolume_from_population(self, population):
        if population == []:
            return 0
        F = population.get_fitness_F()
        ref_point = np.zeros(n_obj)

        hv = Hypervolume(ref_point=ref_point)
        return hv.do(F)

    def generate_new_population_SMS_EMOA(self):
        self.log.info('Generando población con SMS-EMOA...')
        algorithm = SMSEMOA(
            pop_size = N_tamano_poblacion,
            eliminate_duplicates = False,
            sampling = HP_MOEA_Sampling(self.population.get_all_matrix_flatten()),
            mutation = HP_MOEA_SP_Mutation(Pm_probabilidad_mutacion, self.log),
            crossover = HP_MOEA_Crossover(self.log),
            n_offsprings = 1
        )

        new_population = minimize(
            problem = HP_MOEA_Problem(self.log),
            algorithm = algorithm,
            termination = ('n_gen', 2),
            seed = nice_seed,
            verbose = False,
            save_history = False
        )

        self.log.success('Población con SMS-EMOA generada correctamente')
        return Poblacion(new_population)

    def solve_problem(self):
        self.log.info(f'Resolviendo problema con {self.algorithm_name}...')

        algorithm = select_algorithm(self.algorithm_name, self.population, self.log)

        new_population = minimize(
            problem = HP_MOEA_Problem(self.log),
            algorithm = algorithm,
            termination = ('n_gen', T_iteraciones),
            seed = nice_seed,
            verbose = False,
            save_history = False
        )

        self.log.success(f'Población con {algorithm.__class__.__name__} generada correctamente')
        return Poblacion(new_population)

    def User_based_CF(self):
        global users2predict_movie_ratings_json, users2predict_movie_ratings, users_predicted_ratings
        self.log.info(f'Inicia el filtrado colaborativo...')
        if use_precalculated_CF:
            self.log.info(f'La configuración es: Usar datos precalculados = {use_precalculated_CF}')
            with open(f'{data_path}/users2predict_movie_ratings.json', 'r') as f:
                users2predict_movie_ratings_json = f.read()
        else:
            self.log.info(f'La configuración es: Usar datos precalculados = {use_precalculated_CF}')
            users2predict_movie_ratings_json = UBCF.main(data_path, CF_config["K"], CF_config["limit"],
                                                      CF_config["calcular_pesos"], CF_config["hacer_test"])

        users2predict_movie_ratings = Users(fromJson=users2predict_movie_ratings_json)
        users_predicted_ratings = users2predict_movie_ratings.get_all_users()

        self.log.success('Termino el filtrado colaborativo basado en usuarios')

# %% [markdown]
# ## Bucle principal de ejecución del algoritmo HP-MOEA
# Esta sección implementa el bucle principal del algoritmo HP-MOEA, donde se lleva a cabo el proceso evolutivo iterativo.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import logger

def HP_MOEA_LOOP():
    log = logger.logger_class('HP_MOEA_LOOP')
    hp_moea = HP_MOEA_Class(algorithm_name)

    log.info('Llamamos al filtrado colaborativo')
    hp_moea.User_based_CF()

    log.info('Inicializamos la población inicial')
    hp_moea.generate_initial_population()

    log.info('Ejecutamos el algortimo')
    R_population = hp_moea.solve_problem()

    log.success('Finalizado el algoritmo HP-MOEA correctamente')
    return R_population

poblacion_final = HP_MOEA_LOOP()
# Out:
# [2025-07-23 22:25:47] [INFO] [HP_MOEA_CLASS] [0.00 segundos] Se inicializo una instancia de la clase HP_MOEA_CLASS, la configuración es:
# [2025-07-23 22:25:47] [INFO] [HP_MOEA_CLASS] [0.00 segundos] test_mode = True
# [2025-07-23 22:25:47] [INFO] [HP_MOEA_CLASS] [0.00 segundos] u_turning_point = 500
# [2025-07-23 22:25:47] [INFO] [HP_MOEA_CLASS] [0.00 segundos] L_tamano_lista = 10
# [2025-07-23 22:25:47] [INFO] [HP_MOEA_CLASS] [0.00 segundos] N_tamano_poblacion = 100
# [2025-07-23 22:25:47] [INFO] [HP_MOEA_CLASS] [0.00 segundos] T_iteraciones = 50
# [2025-07-23 22:25:47] [INFO] [HP_MOEA_CLASS] [0.00 segundos] Pm_probabilidad_mutacion = 0.1
# [2025-07-23 22:25:47] [INFO] [HP_MOEA_CLASS] [0.00 segundos] r_max_calificacion_maxima = 5
# [2025-07-23 22:25:47] [INFO] [HP_MOEA_CLASS] [0.00 segundos] algorithm_name = NSGA-III
# [2025-07-23 22:25:47] [INFO] [HP_MOEA_LOOP] [0.00 segundos] Llamamos al filtrado colaborativo
# [2025-07-23 22:25:47] [INFO] [HP_MOEA_CLASS] [0.00 segundos] Inicia el filtrado colaborativo...
# [2025-07-23 22:25:47] [INFO] [HP_MOEA_CLASS] [0.00 segundos] La configuración es: Usar datos precalculados = True
# [2025-07-23 22:25:48] [SUCCESS] [HP_MOEA_CLASS] [0.59 segundos] Termino el filtrado colaborativo basado en usuarios
# [2025-07-23 22:25:48] [INFO] [HP_MOEA_LOOP] [0.59 segundos] Inicializamos la población inicial
# [2025-07-23 22:25:48] [INFO] [HP_MOEA_CLASS] [0.59 segundos] Inicializando población...
# [2025-07-23 22:25:48] [INFO] [HP_MOEA_CLASS] [0.59 segundos] Población inicial: 0.0%
# max_profit: 73249.24597008419
# max_novelty: 9430
# max_relevance: 642.5999999999907
# [2025-07-23 22:25:51] [INFO] [HP_MOEA_CLASS] [4.42 segundos] Población inicial: 5.0%
# [2025-07-23 22:25:52] [INFO] [HP_MOEA_CLASS] [5.15 segundos] Población inicial: 10.0%
# [2025-07-23 22:25:53] [INFO] [HP_MOEA_CLASS] [5.95 segundos] Población inicial: 15.0%
# [2025-07-23 22:25:54] [INFO] [HP_MOEA_CLASS] [6.63 segundos] Población inicial: 20.0%
# [2025-07-23 22:25:54] [INFO] [HP_MOEA_CLASS] [7.29 segundos] Población inicial: 25.0%
# [2025-07-23 22:25:55] [INFO] [HP_MOEA_CLASS] [7.96 segundos] Población inicial: 30.0%
# [2025-07-23 22:25:56] [INFO] [HP_MOEA_CLASS] [8.64 segundos] Población inicial: 35.0%
# [2025-07-23 22:25:56] [INFO] [HP_MOEA_CLASS] [9.32 segundos] Población inicial: 40.0%
# [2025-07-23 22:25:57] [INFO] [HP_MOEA_CLASS] [9.98 segundos] Población inicial: 45.0%
# [2025-07-23 22:25:58] [INFO] [HP_MOEA_CLASS] [10.63 segundos] Población inicial: 50.0%
# [2025-07-23 22:25:58] [INFO] [HP_MOEA_CLASS] [11.29 segundos] Población inicial: 55.0%
# [2025-07-23 22:25:59] [INFO] [HP_MOEA_CLASS] [11.94 segundos] Población inicial: 60.0%
# [2025-07-23 22:26:00] [INFO] [HP_MOEA_CLASS] [12.61 segundos] Población inicial: 65.0%
# [2025-07-23 22:26:00] [INFO] [HP_MOEA_CLASS] [13.28 segundos] Población inicial: 70.0%
# [2025-07-23 22:26:01] [INFO] [HP_MOEA_CLASS] [13.94 segundos] Población inicial: 75.0%
# [2025-07-23 22:26:02] [INFO] [HP_MOEA_CLASS] [14.59 segundos] Población inicial: 80.0%
# [2025-07-23 22:26:02] [INFO] [HP_MOEA_CLASS] [15.26 segundos] Población inicial: 85.0%
# [2025-07-23 22:26:03] [INFO] [HP_MOEA_CLASS] [15.93 segundos] Población inicial: 90.0%
# [2025-07-23 22:26:04] [INFO] [HP_MOEA_CLASS] [16.61 segundos] Población inicial: 95.0%
# [2025-07-23 22:26:04] [INFO] [HP_MOEA_CLASS] [17.16 segundos] Calculando metricas de la población...
# [2025-07-23 22:26:26] [SUCCESS] [HP_MOEA_CLASS] [39.21 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:26:26] [SUCCESS] [HP_MOEA_CLASS] [39.21 segundos] Población inicializada correctamente
# [2025-07-23 22:26:26] [INFO] [HP_MOEA_LOOP] [39.21 segundos] Ejecutamos el algortimo
# [2025-07-23 22:26:26] [INFO] [HP_MOEA_CLASS] [39.21 segundos] Resolviendo problema con NSGA-III...
# [2025-07-23 22:26:26] [INFO] [HP_MOEA_CLASS] [39.22 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:26:26] [INFO] [HP_MOEA_CLASS] [39.37 segundos] Calculando metricas de la población...
# [2025-07-23 22:26:26] [SUCCESS] [HP_MOEA_CLASS] [39.41 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:26:26] [SUCCESS] [HP_MOEA_CLASS] [39.41 segundos] Termino la evaluación
# [2025-07-23 22:26:26] [INFO] [HP_MOEA_CLASS] [39.41 segundos] Porcentaje de ejecución: 0.0%
# [2025-07-23 22:26:26] [SUCCESS] [HP_MOEA_CLASS] [39.41 segundos] Iteración del algoritmo: 0/50
# [2025-07-23 22:26:26] [INFO] [HP_MOEA_CLASS] [39.46 segundos] Iniciando operador de cruce...
# [2025-07-23 22:26:33] [SUCCESS] [HP_MOEA_CLASS] [46.24 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:26:33] [INFO] [HP_MOEA_CLASS] [46.27 segundos] Iniciando operador de mutación...
# [2025-07-23 22:26:35] [SUCCESS] [HP_MOEA_CLASS] [48.40 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:26:35] [INFO] [HP_MOEA_CLASS] [48.41 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:26:53] [INFO] [HP_MOEA_CLASS] [66.41 segundos] Calculando metricas de la población...
# [2025-07-23 22:26:53] [SUCCESS] [HP_MOEA_CLASS] [66.46 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:26:53] [SUCCESS] [HP_MOEA_CLASS] [66.46 segundos] Termino la evaluación
# [2025-07-23 22:26:53] [INFO] [HP_MOEA_CLASS] [66.46 segundos] Porcentaje de ejecución: 2.0%
# [2025-07-23 22:26:53] [SUCCESS] [HP_MOEA_CLASS] [66.46 segundos] Iteración del algoritmo: 1/50
# [2025-07-23 22:26:54] [INFO] [HP_MOEA_CLASS] [66.47 segundos] Iniciando operador de cruce...
# [2025-07-23 22:27:00] [SUCCESS] [HP_MOEA_CLASS] [72.97 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:27:00] [INFO] [HP_MOEA_CLASS] [73.01 segundos] Iniciando operador de mutación...
# [2025-07-23 22:27:01] [SUCCESS] [HP_MOEA_CLASS] [73.69 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:27:01] [INFO] [HP_MOEA_CLASS] [73.70 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:27:21] [INFO] [HP_MOEA_CLASS] [93.85 segundos] Calculando metricas de la población...
# [2025-07-23 22:27:21] [SUCCESS] [HP_MOEA_CLASS] [93.93 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:27:21] [SUCCESS] [HP_MOEA_CLASS] [93.93 segundos] Termino la evaluación
# [2025-07-23 22:27:21] [INFO] [HP_MOEA_CLASS] [93.93 segundos] Porcentaje de ejecución: 4.0%
# [2025-07-23 22:27:21] [SUCCESS] [HP_MOEA_CLASS] [93.93 segundos] Iteración del algoritmo: 2/50
# [2025-07-23 22:27:21] [INFO] [HP_MOEA_CLASS] [93.94 segundos] Iniciando operador de cruce...
# [2025-07-23 22:27:27] [SUCCESS] [HP_MOEA_CLASS] [100.31 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:27:27] [INFO] [HP_MOEA_CLASS] [100.34 segundos] Iniciando operador de mutación...
# [2025-07-23 22:27:29] [SUCCESS] [HP_MOEA_CLASS] [102.17 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:27:29] [INFO] [HP_MOEA_CLASS] [102.18 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:27:46] [INFO] [HP_MOEA_CLASS] [119.15 segundos] Calculando metricas de la población...
# [2025-07-23 22:27:46] [SUCCESS] [HP_MOEA_CLASS] [119.22 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:27:46] [SUCCESS] [HP_MOEA_CLASS] [119.22 segundos] Termino la evaluación
# [2025-07-23 22:27:46] [INFO] [HP_MOEA_CLASS] [119.22 segundos] Porcentaje de ejecución: 6.0%
# [2025-07-23 22:27:46] [SUCCESS] [HP_MOEA_CLASS] [119.22 segundos] Iteración del algoritmo: 3/50
# [2025-07-23 22:27:46] [INFO] [HP_MOEA_CLASS] [119.22 segundos] Iniciando operador de cruce...
# [2025-07-23 22:27:52] [SUCCESS] [HP_MOEA_CLASS] [125.39 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:27:52] [INFO] [HP_MOEA_CLASS] [125.42 segundos] Iniciando operador de mutación...
# [2025-07-23 22:27:54] [SUCCESS] [HP_MOEA_CLASS] [126.87 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:27:54] [INFO] [HP_MOEA_CLASS] [126.87 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:28:11] [INFO] [HP_MOEA_CLASS] [144.42 segundos] Calculando metricas de la población...
# [2025-07-23 22:28:12] [SUCCESS] [HP_MOEA_CLASS] [144.53 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:28:12] [SUCCESS] [HP_MOEA_CLASS] [144.53 segundos] Termino la evaluación
# [2025-07-23 22:28:12] [INFO] [HP_MOEA_CLASS] [144.53 segundos] Porcentaje de ejecución: 8.0%
# [2025-07-23 22:28:12] [SUCCESS] [HP_MOEA_CLASS] [144.53 segundos] Iteración del algoritmo: 4/50
# [2025-07-23 22:28:12] [INFO] [HP_MOEA_CLASS] [144.54 segundos] Iniciando operador de cruce...
# [2025-07-23 22:28:18] [SUCCESS] [HP_MOEA_CLASS] [150.63 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:28:18] [INFO] [HP_MOEA_CLASS] [150.65 segundos] Iniciando operador de mutación...
# [2025-07-23 22:28:19] [SUCCESS] [HP_MOEA_CLASS] [152.05 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:28:19] [INFO] [HP_MOEA_CLASS] [152.05 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:28:32] [INFO] [HP_MOEA_CLASS] [165.26 segundos] Calculando metricas de la población...
# [2025-07-23 22:28:32] [SUCCESS] [HP_MOEA_CLASS] [165.41 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:28:32] [SUCCESS] [HP_MOEA_CLASS] [165.41 segundos] Termino la evaluación
# [2025-07-23 22:28:32] [INFO] [HP_MOEA_CLASS] [165.41 segundos] Porcentaje de ejecución: 10.0%
# [2025-07-23 22:28:32] [SUCCESS] [HP_MOEA_CLASS] [165.41 segundos] Iteración del algoritmo: 5/50
# [2025-07-23 22:28:32] [INFO] [HP_MOEA_CLASS] [165.42 segundos] Iniciando operador de cruce...
# [2025-07-23 22:28:38] [SUCCESS] [HP_MOEA_CLASS] [171.41 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:28:38] [INFO] [HP_MOEA_CLASS] [171.44 segundos] Iniciando operador de mutación...
# [2025-07-23 22:28:40] [SUCCESS] [HP_MOEA_CLASS] [172.86 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:28:40] [INFO] [HP_MOEA_CLASS] [172.87 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:28:52] [INFO] [HP_MOEA_CLASS] [184.77 segundos] Calculando metricas de la población...
# [2025-07-23 22:28:52] [SUCCESS] [HP_MOEA_CLASS] [184.87 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:28:52] [SUCCESS] [HP_MOEA_CLASS] [184.87 segundos] Termino la evaluación
# [2025-07-23 22:28:52] [INFO] [HP_MOEA_CLASS] [184.87 segundos] Porcentaje de ejecución: 12.0%
# [2025-07-23 22:28:52] [SUCCESS] [HP_MOEA_CLASS] [184.87 segundos] Iteración del algoritmo: 6/50
# [2025-07-23 22:28:52] [INFO] [HP_MOEA_CLASS] [184.88 segundos] Iniciando operador de cruce...
# [2025-07-23 22:28:58] [SUCCESS] [HP_MOEA_CLASS] [190.86 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:28:58] [INFO] [HP_MOEA_CLASS] [190.89 segundos] Iniciando operador de mutación...
# [2025-07-23 22:29:00] [SUCCESS] [HP_MOEA_CLASS] [192.73 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:29:00] [INFO] [HP_MOEA_CLASS] [192.74 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:29:10] [INFO] [HP_MOEA_CLASS] [203.00 segundos] Calculando metricas de la población...
# [2025-07-23 22:29:10] [SUCCESS] [HP_MOEA_CLASS] [203.12 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:29:10] [SUCCESS] [HP_MOEA_CLASS] [203.12 segundos] Termino la evaluación
# [2025-07-23 22:29:10] [INFO] [HP_MOEA_CLASS] [203.12 segundos] Porcentaje de ejecución: 14.0%
# [2025-07-23 22:29:10] [SUCCESS] [HP_MOEA_CLASS] [203.12 segundos] Iteración del algoritmo: 7/50
# [2025-07-23 22:29:10] [INFO] [HP_MOEA_CLASS] [203.13 segundos] Iniciando operador de cruce...
# [2025-07-23 22:29:16] [SUCCESS] [HP_MOEA_CLASS] [209.02 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:29:16] [INFO] [HP_MOEA_CLASS] [209.06 segundos] Iniciando operador de mutación...
# [2025-07-23 22:29:18] [SUCCESS] [HP_MOEA_CLASS] [210.97 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:29:18] [INFO] [HP_MOEA_CLASS] [210.98 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:29:27] [INFO] [HP_MOEA_CLASS] [220.35 segundos] Calculando metricas de la población...
# [2025-07-23 22:29:28] [SUCCESS] [HP_MOEA_CLASS] [220.54 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:29:28] [SUCCESS] [HP_MOEA_CLASS] [220.54 segundos] Termino la evaluación
# [2025-07-23 22:29:28] [INFO] [HP_MOEA_CLASS] [220.54 segundos] Porcentaje de ejecución: 16.0%
# [2025-07-23 22:29:28] [SUCCESS] [HP_MOEA_CLASS] [220.54 segundos] Iteración del algoritmo: 8/50
# [2025-07-23 22:29:28] [INFO] [HP_MOEA_CLASS] [220.55 segundos] Iniciando operador de cruce...
# [2025-07-23 22:29:33] [SUCCESS] [HP_MOEA_CLASS] [226.43 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:29:33] [INFO] [HP_MOEA_CLASS] [226.46 segundos] Iniciando operador de mutación...
# [2025-07-23 22:29:34] [SUCCESS] [HP_MOEA_CLASS] [227.30 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:29:34] [INFO] [HP_MOEA_CLASS] [227.30 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:29:45] [INFO] [HP_MOEA_CLASS] [238.12 segundos] Calculando metricas de la población...
# [2025-07-23 22:29:45] [SUCCESS] [HP_MOEA_CLASS] [238.24 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:29:45] [SUCCESS] [HP_MOEA_CLASS] [238.24 segundos] Termino la evaluación
# [2025-07-23 22:29:45] [INFO] [HP_MOEA_CLASS] [238.24 segundos] Porcentaje de ejecución: 18.0%
# [2025-07-23 22:29:45] [SUCCESS] [HP_MOEA_CLASS] [238.24 segundos] Iteración del algoritmo: 9/50
# [2025-07-23 22:29:45] [INFO] [HP_MOEA_CLASS] [238.25 segundos] Iniciando operador de cruce...
# [2025-07-23 22:29:51] [SUCCESS] [HP_MOEA_CLASS] [244.13 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:29:51] [INFO] [HP_MOEA_CLASS] [244.16 segundos] Iniciando operador de mutación...
# [2025-07-23 22:29:53] [SUCCESS] [HP_MOEA_CLASS] [245.65 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:29:53] [INFO] [HP_MOEA_CLASS] [245.65 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:30:02] [INFO] [HP_MOEA_CLASS] [254.72 segundos] Calculando metricas de la población...
# [2025-07-23 22:30:02] [SUCCESS] [HP_MOEA_CLASS] [254.87 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:30:02] [SUCCESS] [HP_MOEA_CLASS] [254.87 segundos] Termino la evaluación
# [2025-07-23 22:30:02] [INFO] [HP_MOEA_CLASS] [254.87 segundos] Porcentaje de ejecución: 20.0%
# [2025-07-23 22:30:02] [SUCCESS] [HP_MOEA_CLASS] [254.87 segundos] Iteración del algoritmo: 10/50
# [2025-07-23 22:30:02] [INFO] [HP_MOEA_CLASS] [254.88 segundos] Iniciando operador de cruce...
# [2025-07-23 22:30:08] [SUCCESS] [HP_MOEA_CLASS] [260.76 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:30:08] [INFO] [HP_MOEA_CLASS] [260.80 segundos] Iniciando operador de mutación...
# [2025-07-23 22:30:09] [SUCCESS] [HP_MOEA_CLASS] [262.06 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:30:09] [INFO] [HP_MOEA_CLASS] [262.07 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:30:20] [INFO] [HP_MOEA_CLASS] [272.79 segundos] Calculando metricas de la población...
# [2025-07-23 22:30:20] [SUCCESS] [HP_MOEA_CLASS] [272.93 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:30:20] [SUCCESS] [HP_MOEA_CLASS] [272.93 segundos] Termino la evaluación
# [2025-07-23 22:30:20] [INFO] [HP_MOEA_CLASS] [272.93 segundos] Porcentaje de ejecución: 22.0%
# [2025-07-23 22:30:20] [SUCCESS] [HP_MOEA_CLASS] [272.93 segundos] Iteración del algoritmo: 11/50
# [2025-07-23 22:30:20] [INFO] [HP_MOEA_CLASS] [272.94 segundos] Iniciando operador de cruce...
# [2025-07-23 22:30:26] [SUCCESS] [HP_MOEA_CLASS] [278.81 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:30:26] [INFO] [HP_MOEA_CLASS] [278.84 segundos] Iniciando operador de mutación...
# [2025-07-23 22:30:27] [SUCCESS] [HP_MOEA_CLASS] [280.23 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:30:27] [INFO] [HP_MOEA_CLASS] [280.24 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:30:37] [INFO] [HP_MOEA_CLASS] [290.05 segundos] Calculando metricas de la población...
# [2025-07-23 22:30:37] [SUCCESS] [HP_MOEA_CLASS] [290.21 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:30:37] [SUCCESS] [HP_MOEA_CLASS] [290.21 segundos] Termino la evaluación
# [2025-07-23 22:30:37] [INFO] [HP_MOEA_CLASS] [290.21 segundos] Porcentaje de ejecución: 24.0%
# [2025-07-23 22:30:37] [SUCCESS] [HP_MOEA_CLASS] [290.21 segundos] Iteración del algoritmo: 12/50
# [2025-07-23 22:30:37] [INFO] [HP_MOEA_CLASS] [290.22 segundos] Iniciando operador de cruce...
# [2025-07-23 22:30:43] [SUCCESS] [HP_MOEA_CLASS] [296.07 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:30:43] [INFO] [HP_MOEA_CLASS] [296.10 segundos] Iniciando operador de mutación...
# [2025-07-23 22:30:44] [SUCCESS] [HP_MOEA_CLASS] [296.81 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:30:44] [INFO] [HP_MOEA_CLASS] [296.81 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:30:54] [INFO] [HP_MOEA_CLASS] [307.44 segundos] Calculando metricas de la población...
# [2025-07-23 22:30:55] [SUCCESS] [HP_MOEA_CLASS] [307.60 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:30:55] [SUCCESS] [HP_MOEA_CLASS] [307.60 segundos] Termino la evaluación
# [2025-07-23 22:30:55] [INFO] [HP_MOEA_CLASS] [307.60 segundos] Porcentaje de ejecución: 26.0%
# [2025-07-23 22:30:55] [SUCCESS] [HP_MOEA_CLASS] [307.60 segundos] Iteración del algoritmo: 13/50
# [2025-07-23 22:30:55] [INFO] [HP_MOEA_CLASS] [307.60 segundos] Iniciando operador de cruce...
# [2025-07-23 22:31:00] [SUCCESS] [HP_MOEA_CLASS] [313.44 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:31:01] [INFO] [HP_MOEA_CLASS] [313.48 segundos] Iniciando operador de mutación...
# [2025-07-23 22:31:02] [SUCCESS] [HP_MOEA_CLASS] [314.69 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:31:02] [INFO] [HP_MOEA_CLASS] [314.69 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:31:12] [INFO] [HP_MOEA_CLASS] [325.16 segundos] Calculando metricas de la población...
# [2025-07-23 22:31:12] [SUCCESS] [HP_MOEA_CLASS] [325.33 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:31:12] [SUCCESS] [HP_MOEA_CLASS] [325.33 segundos] Termino la evaluación
# [2025-07-23 22:31:12] [INFO] [HP_MOEA_CLASS] [325.33 segundos] Porcentaje de ejecución: 28.0%
# [2025-07-23 22:31:12] [SUCCESS] [HP_MOEA_CLASS] [325.33 segundos] Iteración del algoritmo: 14/50
# [2025-07-23 22:31:12] [INFO] [HP_MOEA_CLASS] [325.34 segundos] Iniciando operador de cruce...
# [2025-07-23 22:31:18] [SUCCESS] [HP_MOEA_CLASS] [331.41 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:31:18] [INFO] [HP_MOEA_CLASS] [331.44 segundos] Iniciando operador de mutación...
# [2025-07-23 22:31:20] [SUCCESS] [HP_MOEA_CLASS] [333.13 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:31:20] [INFO] [HP_MOEA_CLASS] [333.14 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:31:29] [INFO] [HP_MOEA_CLASS] [342.16 segundos] Calculando metricas de la población...
# [2025-07-23 22:31:29] [SUCCESS] [HP_MOEA_CLASS] [342.32 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:31:29] [SUCCESS] [HP_MOEA_CLASS] [342.32 segundos] Termino la evaluación
# [2025-07-23 22:31:29] [INFO] [HP_MOEA_CLASS] [342.32 segundos] Porcentaje de ejecución: 30.0%
# [2025-07-23 22:31:29] [SUCCESS] [HP_MOEA_CLASS] [342.32 segundos] Iteración del algoritmo: 15/50
# [2025-07-23 22:31:29] [INFO] [HP_MOEA_CLASS] [342.33 segundos] Iniciando operador de cruce...
# [2025-07-23 22:31:35] [SUCCESS] [HP_MOEA_CLASS] [348.36 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:31:35] [INFO] [HP_MOEA_CLASS] [348.39 segundos] Iniciando operador de mutación...
# [2025-07-23 22:31:36] [SUCCESS] [HP_MOEA_CLASS] [349.15 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:31:36] [INFO] [HP_MOEA_CLASS] [349.16 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:31:46] [INFO] [HP_MOEA_CLASS] [358.89 segundos] Calculando metricas de la población...
# [2025-07-23 22:31:46] [SUCCESS] [HP_MOEA_CLASS] [359.05 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:31:46] [SUCCESS] [HP_MOEA_CLASS] [359.05 segundos] Termino la evaluación
# [2025-07-23 22:31:46] [INFO] [HP_MOEA_CLASS] [359.05 segundos] Porcentaje de ejecución: 32.0%
# [2025-07-23 22:31:46] [SUCCESS] [HP_MOEA_CLASS] [359.05 segundos] Iteración del algoritmo: 16/50
# [2025-07-23 22:31:46] [INFO] [HP_MOEA_CLASS] [359.05 segundos] Iniciando operador de cruce...
# [2025-07-23 22:31:52] [SUCCESS] [HP_MOEA_CLASS] [365.09 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:31:52] [INFO] [HP_MOEA_CLASS] [365.12 segundos] Iniciando operador de mutación...
# [2025-07-23 22:31:54] [SUCCESS] [HP_MOEA_CLASS] [366.68 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:31:54] [INFO] [HP_MOEA_CLASS] [366.68 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:32:04] [INFO] [HP_MOEA_CLASS] [377.32 segundos] Calculando metricas de la población...
# [2025-07-23 22:32:05] [SUCCESS] [HP_MOEA_CLASS] [377.49 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:32:05] [SUCCESS] [HP_MOEA_CLASS] [377.49 segundos] Termino la evaluación
# [2025-07-23 22:32:05] [INFO] [HP_MOEA_CLASS] [377.49 segundos] Porcentaje de ejecución: 34.0%
# [2025-07-23 22:32:05] [SUCCESS] [HP_MOEA_CLASS] [377.49 segundos] Iteración del algoritmo: 17/50
# [2025-07-23 22:32:05] [INFO] [HP_MOEA_CLASS] [377.50 segundos] Iniciando operador de cruce...
# [2025-07-23 22:32:11] [SUCCESS] [HP_MOEA_CLASS] [383.72 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:32:11] [INFO] [HP_MOEA_CLASS] [383.76 segundos] Iniciando operador de mutación...
# [2025-07-23 22:32:11] [SUCCESS] [HP_MOEA_CLASS] [384.44 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:32:11] [INFO] [HP_MOEA_CLASS] [384.44 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:32:22] [INFO] [HP_MOEA_CLASS] [394.65 segundos] Calculando metricas de la población...
# [2025-07-23 22:32:22] [SUCCESS] [HP_MOEA_CLASS] [394.81 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:32:22] [SUCCESS] [HP_MOEA_CLASS] [394.81 segundos] Termino la evaluación
# [2025-07-23 22:32:22] [INFO] [HP_MOEA_CLASS] [394.81 segundos] Porcentaje de ejecución: 36.0%
# [2025-07-23 22:32:22] [SUCCESS] [HP_MOEA_CLASS] [394.81 segundos] Iteración del algoritmo: 18/50
# [2025-07-23 22:32:22] [INFO] [HP_MOEA_CLASS] [394.82 segundos] Iniciando operador de cruce...
# [2025-07-23 22:32:28] [SUCCESS] [HP_MOEA_CLASS] [400.88 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:32:28] [INFO] [HP_MOEA_CLASS] [400.91 segundos] Iniciando operador de mutación...
# [2025-07-23 22:32:29] [SUCCESS] [HP_MOEA_CLASS] [401.83 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:32:29] [INFO] [HP_MOEA_CLASS] [401.84 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:32:38] [INFO] [HP_MOEA_CLASS] [410.88 segundos] Calculando metricas de la población...
# [2025-07-23 22:32:38] [SUCCESS] [HP_MOEA_CLASS] [411.04 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:32:38] [SUCCESS] [HP_MOEA_CLASS] [411.04 segundos] Termino la evaluación
# [2025-07-23 22:32:38] [INFO] [HP_MOEA_CLASS] [411.04 segundos] Porcentaje de ejecución: 38.0%
# [2025-07-23 22:32:38] [SUCCESS] [HP_MOEA_CLASS] [411.04 segundos] Iteración del algoritmo: 19/50
# [2025-07-23 22:32:38] [INFO] [HP_MOEA_CLASS] [411.05 segundos] Iniciando operador de cruce...
# [2025-07-23 22:32:44] [SUCCESS] [HP_MOEA_CLASS] [416.79 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:32:44] [INFO] [HP_MOEA_CLASS] [416.82 segundos] Iniciando operador de mutación...
# [2025-07-23 22:32:46] [SUCCESS] [HP_MOEA_CLASS] [418.65 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:32:46] [INFO] [HP_MOEA_CLASS] [418.65 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:32:55] [INFO] [HP_MOEA_CLASS] [427.55 segundos] Calculando metricas de la población...
# [2025-07-23 22:32:55] [SUCCESS] [HP_MOEA_CLASS] [427.76 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:32:55] [SUCCESS] [HP_MOEA_CLASS] [427.76 segundos] Termino la evaluación
# [2025-07-23 22:32:55] [INFO] [HP_MOEA_CLASS] [427.76 segundos] Porcentaje de ejecución: 40.0%
# [2025-07-23 22:32:55] [SUCCESS] [HP_MOEA_CLASS] [427.76 segundos] Iteración del algoritmo: 20/50
# [2025-07-23 22:32:55] [INFO] [HP_MOEA_CLASS] [427.77 segundos] Iniciando operador de cruce...
# [2025-07-23 22:33:01] [SUCCESS] [HP_MOEA_CLASS] [433.57 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:33:01] [INFO] [HP_MOEA_CLASS] [433.60 segundos] Iniciando operador de mutación...
# [2025-07-23 22:33:02] [SUCCESS] [HP_MOEA_CLASS] [435.01 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:33:02] [INFO] [HP_MOEA_CLASS] [435.01 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:33:12] [INFO] [HP_MOEA_CLASS] [444.48 segundos] Calculando metricas de la población...
# [2025-07-23 22:33:12] [SUCCESS] [HP_MOEA_CLASS] [444.64 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:33:12] [SUCCESS] [HP_MOEA_CLASS] [444.64 segundos] Termino la evaluación
# [2025-07-23 22:33:12] [INFO] [HP_MOEA_CLASS] [444.64 segundos] Porcentaje de ejecución: 42.0%
# [2025-07-23 22:33:12] [SUCCESS] [HP_MOEA_CLASS] [444.64 segundos] Iteración del algoritmo: 21/50
# [2025-07-23 22:33:12] [INFO] [HP_MOEA_CLASS] [444.65 segundos] Iniciando operador de cruce...
# [2025-07-23 22:33:17] [SUCCESS] [HP_MOEA_CLASS] [450.45 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:33:18] [INFO] [HP_MOEA_CLASS] [450.48 segundos] Iniciando operador de mutación...
# [2025-07-23 22:33:19] [SUCCESS] [HP_MOEA_CLASS] [451.74 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:33:19] [INFO] [HP_MOEA_CLASS] [451.74 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:33:28] [INFO] [HP_MOEA_CLASS] [461.15 segundos] Calculando metricas de la población...
# [2025-07-23 22:33:28] [SUCCESS] [HP_MOEA_CLASS] [461.31 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:33:28] [SUCCESS] [HP_MOEA_CLASS] [461.31 segundos] Termino la evaluación
# [2025-07-23 22:33:28] [INFO] [HP_MOEA_CLASS] [461.31 segundos] Porcentaje de ejecución: 44.0%
# [2025-07-23 22:33:28] [SUCCESS] [HP_MOEA_CLASS] [461.31 segundos] Iteración del algoritmo: 22/50
# [2025-07-23 22:33:28] [INFO] [HP_MOEA_CLASS] [461.31 segundos] Iniciando operador de cruce...
# [2025-07-23 22:33:34] [SUCCESS] [HP_MOEA_CLASS] [467.21 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:33:34] [INFO] [HP_MOEA_CLASS] [467.24 segundos] Iniciando operador de mutación...
# [2025-07-23 22:33:36] [SUCCESS] [HP_MOEA_CLASS] [468.98 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:33:36] [INFO] [HP_MOEA_CLASS] [468.99 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:33:46] [INFO] [HP_MOEA_CLASS] [478.51 segundos] Calculando metricas de la población...
# [2025-07-23 22:33:46] [SUCCESS] [HP_MOEA_CLASS] [478.67 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:33:46] [SUCCESS] [HP_MOEA_CLASS] [478.67 segundos] Termino la evaluación
# [2025-07-23 22:33:46] [INFO] [HP_MOEA_CLASS] [478.67 segundos] Porcentaje de ejecución: 46.0%
# [2025-07-23 22:33:46] [SUCCESS] [HP_MOEA_CLASS] [478.67 segundos] Iteración del algoritmo: 23/50
# [2025-07-23 22:33:46] [INFO] [HP_MOEA_CLASS] [478.68 segundos] Iniciando operador de cruce...
# [2025-07-23 22:33:51] [SUCCESS] [HP_MOEA_CLASS] [484.41 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:33:51] [INFO] [HP_MOEA_CLASS] [484.44 segundos] Iniciando operador de mutación...
# [2025-07-23 22:33:52] [SUCCESS] [HP_MOEA_CLASS] [485.41 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:33:52] [INFO] [HP_MOEA_CLASS] [485.42 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:34:02] [INFO] [HP_MOEA_CLASS] [494.56 segundos] Calculando metricas de la población...
# [2025-07-23 22:34:02] [SUCCESS] [HP_MOEA_CLASS] [494.72 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:34:02] [SUCCESS] [HP_MOEA_CLASS] [494.72 segundos] Termino la evaluación
# [2025-07-23 22:34:02] [INFO] [HP_MOEA_CLASS] [494.72 segundos] Porcentaje de ejecución: 48.0%
# [2025-07-23 22:34:02] [SUCCESS] [HP_MOEA_CLASS] [494.72 segundos] Iteración del algoritmo: 24/50
# [2025-07-23 22:34:02] [INFO] [HP_MOEA_CLASS] [494.73 segundos] Iniciando operador de cruce...
# [2025-07-23 22:34:08] [SUCCESS] [HP_MOEA_CLASS] [500.70 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:34:08] [INFO] [HP_MOEA_CLASS] [500.73 segundos] Iniciando operador de mutación...
# [2025-07-23 22:34:09] [SUCCESS] [HP_MOEA_CLASS] [501.99 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:34:09] [INFO] [HP_MOEA_CLASS] [501.99 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:34:19] [INFO] [HP_MOEA_CLASS] [511.85 segundos] Calculando metricas de la población...
# [2025-07-23 22:34:19] [SUCCESS] [HP_MOEA_CLASS] [512.01 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:34:19] [SUCCESS] [HP_MOEA_CLASS] [512.01 segundos] Termino la evaluación
# [2025-07-23 22:34:19] [INFO] [HP_MOEA_CLASS] [512.01 segundos] Porcentaje de ejecución: 50.0%
# [2025-07-23 22:34:19] [SUCCESS] [HP_MOEA_CLASS] [512.01 segundos] Iteración del algoritmo: 25/50
# [2025-07-23 22:34:19] [INFO] [HP_MOEA_CLASS] [512.02 segundos] Iniciando operador de cruce...
# [2025-07-23 22:34:25] [SUCCESS] [HP_MOEA_CLASS] [518.14 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:34:25] [INFO] [HP_MOEA_CLASS] [518.18 segundos] Iniciando operador de mutación...
# [2025-07-23 22:34:27] [SUCCESS] [HP_MOEA_CLASS] [519.91 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:34:27] [INFO] [HP_MOEA_CLASS] [519.91 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:34:37] [INFO] [HP_MOEA_CLASS] [529.48 segundos] Calculando metricas de la población...
# [2025-07-23 22:34:37] [SUCCESS] [HP_MOEA_CLASS] [529.64 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:34:37] [SUCCESS] [HP_MOEA_CLASS] [529.64 segundos] Termino la evaluación
# [2025-07-23 22:34:37] [INFO] [HP_MOEA_CLASS] [529.64 segundos] Porcentaje de ejecución: 52.0%
# [2025-07-23 22:34:37] [SUCCESS] [HP_MOEA_CLASS] [529.64 segundos] Iteración del algoritmo: 26/50
# [2025-07-23 22:34:37] [INFO] [HP_MOEA_CLASS] [529.65 segundos] Iniciando operador de cruce...
# [2025-07-23 22:34:43] [SUCCESS] [HP_MOEA_CLASS] [535.98 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:34:43] [INFO] [HP_MOEA_CLASS] [536.01 segundos] Iniciando operador de mutación...
# [2025-07-23 22:34:45] [SUCCESS] [HP_MOEA_CLASS] [537.53 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:34:45] [INFO] [HP_MOEA_CLASS] [537.54 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:34:56] [INFO] [HP_MOEA_CLASS] [548.56 segundos] Calculando metricas de la población...
# [2025-07-23 22:34:56] [SUCCESS] [HP_MOEA_CLASS] [548.73 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:34:56] [SUCCESS] [HP_MOEA_CLASS] [548.73 segundos] Termino la evaluación
# [2025-07-23 22:34:56] [INFO] [HP_MOEA_CLASS] [548.73 segundos] Porcentaje de ejecución: 54.0%
# [2025-07-23 22:34:56] [SUCCESS] [HP_MOEA_CLASS] [548.73 segundos] Iteración del algoritmo: 27/50
# [2025-07-23 22:34:56] [INFO] [HP_MOEA_CLASS] [548.74 segundos] Iniciando operador de cruce...
# [2025-07-23 22:35:02] [SUCCESS] [HP_MOEA_CLASS] [555.23 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:35:02] [INFO] [HP_MOEA_CLASS] [555.27 segundos] Iniciando operador de mutación...
# [2025-07-23 22:35:04] [SUCCESS] [HP_MOEA_CLASS] [556.96 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:35:04] [INFO] [HP_MOEA_CLASS] [556.97 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:35:14] [INFO] [HP_MOEA_CLASS] [566.79 segundos] Calculando metricas de la población...
# [2025-07-23 22:35:14] [SUCCESS] [HP_MOEA_CLASS] [566.96 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:35:14] [SUCCESS] [HP_MOEA_CLASS] [566.96 segundos] Termino la evaluación
# [2025-07-23 22:35:14] [INFO] [HP_MOEA_CLASS] [566.96 segundos] Porcentaje de ejecución: 56.0%
# [2025-07-23 22:35:14] [SUCCESS] [HP_MOEA_CLASS] [566.96 segundos] Iteración del algoritmo: 28/50
# [2025-07-23 22:35:14] [INFO] [HP_MOEA_CLASS] [566.97 segundos] Iniciando operador de cruce...
# [2025-07-23 22:35:20] [SUCCESS] [HP_MOEA_CLASS] [573.14 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:35:20] [INFO] [HP_MOEA_CLASS] [573.17 segundos] Iniciando operador de mutación...
# [2025-07-23 22:35:21] [SUCCESS] [HP_MOEA_CLASS] [573.93 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:35:21] [INFO] [HP_MOEA_CLASS] [573.94 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:35:32] [INFO] [HP_MOEA_CLASS] [584.49 segundos] Calculando metricas de la población...
# [2025-07-23 22:35:32] [SUCCESS] [HP_MOEA_CLASS] [584.66 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:35:32] [SUCCESS] [HP_MOEA_CLASS] [584.66 segundos] Termino la evaluación
# [2025-07-23 22:35:32] [INFO] [HP_MOEA_CLASS] [584.66 segundos] Porcentaje de ejecución: 58.0%
# [2025-07-23 22:35:32] [SUCCESS] [HP_MOEA_CLASS] [584.66 segundos] Iteración del algoritmo: 29/50
# [2025-07-23 22:35:32] [INFO] [HP_MOEA_CLASS] [584.67 segundos] Iniciando operador de cruce...
# [2025-07-23 22:35:38] [SUCCESS] [HP_MOEA_CLASS] [590.93 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:35:38] [INFO] [HP_MOEA_CLASS] [590.96 segundos] Iniciando operador de mutación...
# [2025-07-23 22:35:40] [SUCCESS] [HP_MOEA_CLASS] [592.77 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:35:40] [INFO] [HP_MOEA_CLASS] [592.77 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:35:51] [INFO] [HP_MOEA_CLASS] [603.60 segundos] Calculando metricas de la población...
# [2025-07-23 22:35:51] [SUCCESS] [HP_MOEA_CLASS] [603.88 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:35:51] [SUCCESS] [HP_MOEA_CLASS] [603.88 segundos] Termino la evaluación
# [2025-07-23 22:35:51] [INFO] [HP_MOEA_CLASS] [603.88 segundos] Porcentaje de ejecución: 60.0%
# [2025-07-23 22:35:51] [SUCCESS] [HP_MOEA_CLASS] [603.88 segundos] Iteración del algoritmo: 30/50
# [2025-07-23 22:35:51] [INFO] [HP_MOEA_CLASS] [603.89 segundos] Iniciando operador de cruce...
# [2025-07-23 22:35:57] [SUCCESS] [HP_MOEA_CLASS] [610.11 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:35:57] [INFO] [HP_MOEA_CLASS] [610.15 segundos] Iniciando operador de mutación...
# [2025-07-23 22:35:59] [SUCCESS] [HP_MOEA_CLASS] [611.76 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:35:59] [INFO] [HP_MOEA_CLASS] [611.76 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:36:10] [INFO] [HP_MOEA_CLASS] [623.24 segundos] Calculando metricas de la población...
# [2025-07-23 22:36:10] [SUCCESS] [HP_MOEA_CLASS] [623.42 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:36:10] [SUCCESS] [HP_MOEA_CLASS] [623.42 segundos] Termino la evaluación
# [2025-07-23 22:36:10] [INFO] [HP_MOEA_CLASS] [623.42 segundos] Porcentaje de ejecución: 62.0%
# [2025-07-23 22:36:10] [SUCCESS] [HP_MOEA_CLASS] [623.42 segundos] Iteración del algoritmo: 31/50
# [2025-07-23 22:36:10] [INFO] [HP_MOEA_CLASS] [623.43 segundos] Iniciando operador de cruce...
# [2025-07-23 22:36:17] [SUCCESS] [HP_MOEA_CLASS] [630.17 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:36:17] [INFO] [HP_MOEA_CLASS] [630.21 segundos] Iniciando operador de mutación...
# [2025-07-23 22:36:19] [SUCCESS] [HP_MOEA_CLASS] [632.36 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:36:19] [INFO] [HP_MOEA_CLASS] [632.36 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:36:32] [INFO] [HP_MOEA_CLASS] [644.86 segundos] Calculando metricas de la población...
# [2025-07-23 22:36:32] [SUCCESS] [HP_MOEA_CLASS] [645.05 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:36:32] [SUCCESS] [HP_MOEA_CLASS] [645.05 segundos] Termino la evaluación
# [2025-07-23 22:36:32] [INFO] [HP_MOEA_CLASS] [645.05 segundos] Porcentaje de ejecución: 64.0%
# [2025-07-23 22:36:32] [SUCCESS] [HP_MOEA_CLASS] [645.05 segundos] Iteración del algoritmo: 32/50
# [2025-07-23 22:36:32] [INFO] [HP_MOEA_CLASS] [645.06 segundos] Iniciando operador de cruce...
# [2025-07-23 22:36:39] [SUCCESS] [HP_MOEA_CLASS] [651.59 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:36:39] [INFO] [HP_MOEA_CLASS] [651.63 segundos] Iniciando operador de mutación...
# [2025-07-23 22:36:41] [SUCCESS] [HP_MOEA_CLASS] [653.48 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:36:41] [INFO] [HP_MOEA_CLASS] [653.48 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:36:51] [INFO] [HP_MOEA_CLASS] [664.45 segundos] Calculando metricas de la población...
# [2025-07-23 22:36:52] [SUCCESS] [HP_MOEA_CLASS] [664.62 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:36:52] [SUCCESS] [HP_MOEA_CLASS] [664.62 segundos] Termino la evaluación
# [2025-07-23 22:36:52] [INFO] [HP_MOEA_CLASS] [664.62 segundos] Porcentaje de ejecución: 66.0%
# [2025-07-23 22:36:52] [SUCCESS] [HP_MOEA_CLASS] [664.62 segundos] Iteración del algoritmo: 33/50
# [2025-07-23 22:36:52] [INFO] [HP_MOEA_CLASS] [664.63 segundos] Iniciando operador de cruce...
# [2025-07-23 22:36:58] [SUCCESS] [HP_MOEA_CLASS] [671.08 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:36:58] [INFO] [HP_MOEA_CLASS] [671.11 segundos] Iniciando operador de mutación...
# [2025-07-23 22:36:59] [SUCCESS] [HP_MOEA_CLASS] [672.11 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:36:59] [INFO] [HP_MOEA_CLASS] [672.12 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:37:11] [INFO] [HP_MOEA_CLASS] [684.30 segundos] Calculando metricas de la población...
# [2025-07-23 22:37:12] [SUCCESS] [HP_MOEA_CLASS] [684.49 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:37:12] [SUCCESS] [HP_MOEA_CLASS] [684.49 segundos] Termino la evaluación
# [2025-07-23 22:37:12] [INFO] [HP_MOEA_CLASS] [684.49 segundos] Porcentaje de ejecución: 68.0%
# [2025-07-23 22:37:12] [SUCCESS] [HP_MOEA_CLASS] [684.49 segundos] Iteración del algoritmo: 34/50
# [2025-07-23 22:37:12] [INFO] [HP_MOEA_CLASS] [684.50 segundos] Iniciando operador de cruce...
# [2025-07-23 22:37:18] [SUCCESS] [HP_MOEA_CLASS] [690.94 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:37:18] [INFO] [HP_MOEA_CLASS] [690.97 segundos] Iniciando operador de mutación...
# [2025-07-23 22:37:19] [SUCCESS] [HP_MOEA_CLASS] [692.36 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:37:19] [INFO] [HP_MOEA_CLASS] [692.36 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:37:32] [INFO] [HP_MOEA_CLASS] [704.64 segundos] Calculando metricas de la población...
# [2025-07-23 22:37:32] [SUCCESS] [HP_MOEA_CLASS] [704.81 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:37:32] [SUCCESS] [HP_MOEA_CLASS] [704.81 segundos] Termino la evaluación
# [2025-07-23 22:37:32] [INFO] [HP_MOEA_CLASS] [704.81 segundos] Porcentaje de ejecución: 70.0%
# [2025-07-23 22:37:32] [SUCCESS] [HP_MOEA_CLASS] [704.81 segundos] Iteración del algoritmo: 35/50
# [2025-07-23 22:37:32] [INFO] [HP_MOEA_CLASS] [704.82 segundos] Iniciando operador de cruce...
# [2025-07-23 22:37:38] [SUCCESS] [HP_MOEA_CLASS] [711.28 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:37:38] [INFO] [HP_MOEA_CLASS] [711.31 segundos] Iniciando operador de mutación...
# [2025-07-23 22:37:40] [SUCCESS] [HP_MOEA_CLASS] [713.03 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:37:40] [INFO] [HP_MOEA_CLASS] [713.03 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:37:51] [INFO] [HP_MOEA_CLASS] [724.10 segundos] Calculando metricas de la población...
# [2025-07-23 22:37:51] [SUCCESS] [HP_MOEA_CLASS] [724.28 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:37:51] [SUCCESS] [HP_MOEA_CLASS] [724.28 segundos] Termino la evaluación
# [2025-07-23 22:37:51] [INFO] [HP_MOEA_CLASS] [724.28 segundos] Porcentaje de ejecución: 72.0%
# [2025-07-23 22:37:51] [SUCCESS] [HP_MOEA_CLASS] [724.28 segundos] Iteración del algoritmo: 36/50
# [2025-07-23 22:37:51] [INFO] [HP_MOEA_CLASS] [724.29 segundos] Iniciando operador de cruce...
# [2025-07-23 22:37:58] [SUCCESS] [HP_MOEA_CLASS] [731.01 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:37:58] [INFO] [HP_MOEA_CLASS] [731.05 segundos] Iniciando operador de mutación...
# [2025-07-23 22:38:00] [SUCCESS] [HP_MOEA_CLASS] [732.74 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:38:00] [INFO] [HP_MOEA_CLASS] [732.74 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:38:11] [INFO] [HP_MOEA_CLASS] [743.50 segundos] Calculando metricas de la población...
# [2025-07-23 22:38:11] [SUCCESS] [HP_MOEA_CLASS] [743.67 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:38:11] [SUCCESS] [HP_MOEA_CLASS] [743.67 segundos] Termino la evaluación
# [2025-07-23 22:38:11] [INFO] [HP_MOEA_CLASS] [743.67 segundos] Porcentaje de ejecución: 74.0%
# [2025-07-23 22:38:11] [SUCCESS] [HP_MOEA_CLASS] [743.67 segundos] Iteración del algoritmo: 37/50
# [2025-07-23 22:38:11] [INFO] [HP_MOEA_CLASS] [743.68 segundos] Iniciando operador de cruce...
# [2025-07-23 22:38:17] [SUCCESS] [HP_MOEA_CLASS] [750.32 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:38:17] [INFO] [HP_MOEA_CLASS] [750.35 segundos] Iniciando operador de mutación...
# [2025-07-23 22:38:18] [SUCCESS] [HP_MOEA_CLASS] [751.32 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:38:18] [INFO] [HP_MOEA_CLASS] [751.33 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:38:29] [INFO] [HP_MOEA_CLASS] [762.46 segundos] Calculando metricas de la población...
# [2025-07-23 22:38:30] [SUCCESS] [HP_MOEA_CLASS] [762.64 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:38:30] [SUCCESS] [HP_MOEA_CLASS] [762.64 segundos] Termino la evaluación
# [2025-07-23 22:38:30] [INFO] [HP_MOEA_CLASS] [762.64 segundos] Porcentaje de ejecución: 76.0%
# [2025-07-23 22:38:30] [SUCCESS] [HP_MOEA_CLASS] [762.64 segundos] Iteración del algoritmo: 38/50
# [2025-07-23 22:38:30] [INFO] [HP_MOEA_CLASS] [762.65 segundos] Iniciando operador de cruce...
# [2025-07-23 22:38:36] [SUCCESS] [HP_MOEA_CLASS] [769.28 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:38:36] [INFO] [HP_MOEA_CLASS] [769.32 segundos] Iniciando operador de mutación...
# [2025-07-23 22:38:38] [SUCCESS] [HP_MOEA_CLASS] [771.43 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:38:38] [INFO] [HP_MOEA_CLASS] [771.43 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:38:49] [INFO] [HP_MOEA_CLASS] [782.11 segundos] Calculando metricas de la población...
# [2025-07-23 22:38:49] [SUCCESS] [HP_MOEA_CLASS] [782.30 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:38:49] [SUCCESS] [HP_MOEA_CLASS] [782.30 segundos] Termino la evaluación
# [2025-07-23 22:38:49] [INFO] [HP_MOEA_CLASS] [782.30 segundos] Porcentaje de ejecución: 78.0%
# [2025-07-23 22:38:49] [SUCCESS] [HP_MOEA_CLASS] [782.30 segundos] Iteración del algoritmo: 39/50
# [2025-07-23 22:38:49] [INFO] [HP_MOEA_CLASS] [782.30 segundos] Iniciando operador de cruce...
# [2025-07-23 22:38:56] [SUCCESS] [HP_MOEA_CLASS] [788.86 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:38:56] [INFO] [HP_MOEA_CLASS] [788.89 segundos] Iniciando operador de mutación...
# [2025-07-23 22:38:57] [SUCCESS] [HP_MOEA_CLASS] [790.19 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:38:57] [INFO] [HP_MOEA_CLASS] [790.19 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:39:09] [INFO] [HP_MOEA_CLASS] [802.19 segundos] Calculando metricas de la población...
# [2025-07-23 22:39:09] [SUCCESS] [HP_MOEA_CLASS] [802.47 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:39:09] [SUCCESS] [HP_MOEA_CLASS] [802.47 segundos] Termino la evaluación
# [2025-07-23 22:39:09] [INFO] [HP_MOEA_CLASS] [802.47 segundos] Porcentaje de ejecución: 80.0%
# [2025-07-23 22:39:09] [SUCCESS] [HP_MOEA_CLASS] [802.47 segundos] Iteración del algoritmo: 40/50
# [2025-07-23 22:39:10] [INFO] [HP_MOEA_CLASS] [802.47 segundos] Iniciando operador de cruce...
# [2025-07-23 22:39:16] [SUCCESS] [HP_MOEA_CLASS] [809.00 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:39:16] [INFO] [HP_MOEA_CLASS] [809.03 segundos] Iniciando operador de mutación...
# [2025-07-23 22:39:18] [SUCCESS] [HP_MOEA_CLASS] [810.70 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:39:18] [INFO] [HP_MOEA_CLASS] [810.71 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:39:28] [INFO] [HP_MOEA_CLASS] [821.13 segundos] Calculando metricas de la población...
# [2025-07-23 22:39:28] [SUCCESS] [HP_MOEA_CLASS] [821.30 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:39:28] [SUCCESS] [HP_MOEA_CLASS] [821.30 segundos] Termino la evaluación
# [2025-07-23 22:39:28] [INFO] [HP_MOEA_CLASS] [821.30 segundos] Porcentaje de ejecución: 82.0%
# [2025-07-23 22:39:28] [SUCCESS] [HP_MOEA_CLASS] [821.30 segundos] Iteración del algoritmo: 41/50
# [2025-07-23 22:39:28] [INFO] [HP_MOEA_CLASS] [821.31 segundos] Iniciando operador de cruce...
# [2025-07-23 22:39:35] [SUCCESS] [HP_MOEA_CLASS] [827.71 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:39:35] [INFO] [HP_MOEA_CLASS] [827.74 segundos] Iniciando operador de mutación...
# [2025-07-23 22:39:37] [SUCCESS] [HP_MOEA_CLASS] [829.59 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:39:37] [INFO] [HP_MOEA_CLASS] [829.59 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:39:47] [INFO] [HP_MOEA_CLASS] [839.64 segundos] Calculando metricas de la población...
# [2025-07-23 22:39:47] [SUCCESS] [HP_MOEA_CLASS] [839.83 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:39:47] [SUCCESS] [HP_MOEA_CLASS] [839.83 segundos] Termino la evaluación
# [2025-07-23 22:39:47] [INFO] [HP_MOEA_CLASS] [839.83 segundos] Porcentaje de ejecución: 84.0%
# [2025-07-23 22:39:47] [SUCCESS] [HP_MOEA_CLASS] [839.83 segundos] Iteración del algoritmo: 42/50
# [2025-07-23 22:39:47] [INFO] [HP_MOEA_CLASS] [839.83 segundos] Iniciando operador de cruce...
# [2025-07-23 22:39:54] [SUCCESS] [HP_MOEA_CLASS] [846.52 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:39:54] [INFO] [HP_MOEA_CLASS] [846.55 segundos] Iniciando operador de mutación...
# [2025-07-23 22:39:55] [SUCCESS] [HP_MOEA_CLASS] [847.52 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:39:55] [INFO] [HP_MOEA_CLASS] [847.52 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:40:06] [INFO] [HP_MOEA_CLASS] [859.14 segundos] Calculando metricas de la población...
# [2025-07-23 22:40:06] [SUCCESS] [HP_MOEA_CLASS] [859.33 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:40:06] [SUCCESS] [HP_MOEA_CLASS] [859.33 segundos] Termino la evaluación
# [2025-07-23 22:40:06] [INFO] [HP_MOEA_CLASS] [859.33 segundos] Porcentaje de ejecución: 86.0%
# [2025-07-23 22:40:06] [SUCCESS] [HP_MOEA_CLASS] [859.33 segundos] Iteración del algoritmo: 43/50
# [2025-07-23 22:40:06] [INFO] [HP_MOEA_CLASS] [859.33 segundos] Iniciando operador de cruce...
# [2025-07-23 22:40:13] [SUCCESS] [HP_MOEA_CLASS] [866.05 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:40:13] [INFO] [HP_MOEA_CLASS] [866.09 segundos] Iniciando operador de mutación...
# [2025-07-23 22:40:14] [SUCCESS] [HP_MOEA_CLASS] [867.13 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:40:14] [INFO] [HP_MOEA_CLASS] [867.13 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:40:26] [INFO] [HP_MOEA_CLASS] [878.86 segundos] Calculando metricas de la población...
# [2025-07-23 22:40:26] [SUCCESS] [HP_MOEA_CLASS] [879.04 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:40:26] [SUCCESS] [HP_MOEA_CLASS] [879.04 segundos] Termino la evaluación
# [2025-07-23 22:40:26] [INFO] [HP_MOEA_CLASS] [879.04 segundos] Porcentaje de ejecución: 88.0%
# [2025-07-23 22:40:26] [SUCCESS] [HP_MOEA_CLASS] [879.04 segundos] Iteración del algoritmo: 44/50
# [2025-07-23 22:40:26] [INFO] [HP_MOEA_CLASS] [879.05 segundos] Iniciando operador de cruce...
# [2025-07-23 22:40:33] [SUCCESS] [HP_MOEA_CLASS] [885.67 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:40:33] [INFO] [HP_MOEA_CLASS] [885.71 segundos] Iniciando operador de mutación...
# [2025-07-23 22:40:34] [SUCCESS] [HP_MOEA_CLASS] [887.06 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:40:34] [INFO] [HP_MOEA_CLASS] [887.07 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:40:46] [INFO] [HP_MOEA_CLASS] [899.41 segundos] Calculando metricas de la población...
# [2025-07-23 22:40:47] [SUCCESS] [HP_MOEA_CLASS] [899.59 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:40:47] [SUCCESS] [HP_MOEA_CLASS] [899.59 segundos] Termino la evaluación
# [2025-07-23 22:40:47] [INFO] [HP_MOEA_CLASS] [899.59 segundos] Porcentaje de ejecución: 90.0%
# [2025-07-23 22:40:47] [SUCCESS] [HP_MOEA_CLASS] [899.59 segundos] Iteración del algoritmo: 45/50
# [2025-07-23 22:40:47] [INFO] [HP_MOEA_CLASS] [899.60 segundos] Iniciando operador de cruce...
# [2025-07-23 22:40:53] [SUCCESS] [HP_MOEA_CLASS] [906.25 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:40:53] [INFO] [HP_MOEA_CLASS] [906.28 segundos] Iniciando operador de mutación...
# [2025-07-23 22:40:55] [SUCCESS] [HP_MOEA_CLASS] [907.53 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:40:55] [INFO] [HP_MOEA_CLASS] [907.54 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:41:05] [INFO] [HP_MOEA_CLASS] [918.41 segundos] Calculando metricas de la población...
# [2025-07-23 22:41:06] [SUCCESS] [HP_MOEA_CLASS] [918.61 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:41:06] [SUCCESS] [HP_MOEA_CLASS] [918.61 segundos] Termino la evaluación
# [2025-07-23 22:41:06] [INFO] [HP_MOEA_CLASS] [918.61 segundos] Porcentaje de ejecución: 92.0%
# [2025-07-23 22:41:06] [SUCCESS] [HP_MOEA_CLASS] [918.61 segundos] Iteración del algoritmo: 46/50
# [2025-07-23 22:41:06] [INFO] [HP_MOEA_CLASS] [918.62 segundos] Iniciando operador de cruce...
# [2025-07-23 22:41:13] [SUCCESS] [HP_MOEA_CLASS] [925.86 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:41:13] [INFO] [HP_MOEA_CLASS] [925.90 segundos] Iniciando operador de mutación...
# [2025-07-23 22:41:15] [SUCCESS] [HP_MOEA_CLASS] [927.56 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:41:15] [INFO] [HP_MOEA_CLASS] [927.56 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:41:27] [INFO] [HP_MOEA_CLASS] [939.59 segundos] Calculando metricas de la población...
# [2025-07-23 22:41:27] [SUCCESS] [HP_MOEA_CLASS] [939.76 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:41:27] [SUCCESS] [HP_MOEA_CLASS] [939.76 segundos] Termino la evaluación
# [2025-07-23 22:41:27] [INFO] [HP_MOEA_CLASS] [939.76 segundos] Porcentaje de ejecución: 94.0%
# [2025-07-23 22:41:27] [SUCCESS] [HP_MOEA_CLASS] [939.76 segundos] Iteración del algoritmo: 47/50
# [2025-07-23 22:41:27] [INFO] [HP_MOEA_CLASS] [939.77 segundos] Iniciando operador de cruce...
# [2025-07-23 22:41:33] [SUCCESS] [HP_MOEA_CLASS] [945.92 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:41:33] [INFO] [HP_MOEA_CLASS] [945.96 segundos] Iniciando operador de mutación...
# [2025-07-23 22:41:34] [SUCCESS] [HP_MOEA_CLASS] [946.84 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:41:34] [INFO] [HP_MOEA_CLASS] [946.84 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:41:45] [INFO] [HP_MOEA_CLASS] [957.50 segundos] Calculando metricas de la población...
# [2025-07-23 22:41:45] [SUCCESS] [HP_MOEA_CLASS] [957.66 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:41:45] [SUCCESS] [HP_MOEA_CLASS] [957.66 segundos] Termino la evaluación
# [2025-07-23 22:41:45] [INFO] [HP_MOEA_CLASS] [957.66 segundos] Porcentaje de ejecución: 96.0%
# [2025-07-23 22:41:45] [SUCCESS] [HP_MOEA_CLASS] [957.66 segundos] Iteración del algoritmo: 48/50
# [2025-07-23 22:41:45] [INFO] [HP_MOEA_CLASS] [957.67 segundos] Iniciando operador de cruce...
# [2025-07-23 22:41:51] [SUCCESS] [HP_MOEA_CLASS] [963.83 segundos] Operador de cruce finalizado correctamente
# [2025-07-23 22:41:51] [INFO] [HP_MOEA_CLASS] [963.86 segundos] Iniciando operador de mutación...
# [2025-07-23 22:41:52] [SUCCESS] [HP_MOEA_CLASS] [964.81 segundos] Operador de mutación finalizado correctamente
# [2025-07-23 22:41:52] [INFO] [HP_MOEA_CLASS] [964.82 segundos] Iniciando evaluación con los valores del fitness...
# [2025-07-23 22:42:03] [INFO] [HP_MOEA_CLASS] [975.96 segundos] Calculando metricas de la población...
# [2025-07-23 22:42:03] [SUCCESS] [HP_MOEA_CLASS] [976.13 segundos] El calculo de metricas de población ha finalizado correctamente
# [2025-07-23 22:42:03] [SUCCESS] [HP_MOEA_CLASS] [976.13 segundos] Termino la evaluación
# [2025-07-23 22:42:03] [INFO] [HP_MOEA_CLASS] [976.13 segundos] Porcentaje de ejecución: 98.0%
# [2025-07-23 22:42:03] [SUCCESS] [HP_MOEA_CLASS] [976.13 segundos] Iteración del algoritmo: 49/50
# [2025-07-23 22:42:03] [SUCCESS] [HP_MOEA_CLASS] [976.13 segundos] Población con NSGA3 generada correctamente
# [2025-07-23 22:42:03] [SUCCESS] [HP_MOEA_LOOP] [976.20 segundos] Finalizado el algoritmo HP-MOEA correctamente

# %% [markdown]
# ## Análisis de resultados y visualización
# Esta sección presenta los resultados obtenidos y su visualización para facilitar la interpretación del desempeño del algoritmo.

# %%
from pymoo.indicators.hv import Hypervolume
from pymoo.visualization.scatter import Scatter

import matplotlib.pyplot as plt

log = logger.logger_class('RESULTADOS')
ref_point = np.zeros(n_obj)
hv = Hypervolume(ref_point=ref_point)

### POBLACIÓN FINAL
print(f'FINAL:')
fitnessF = poblacion_final.get_fitness_F()
hv_value = hv.do(fitnessF)

print(f'El hipervolumen de la población final es {hv_value}')
print(f'La población final es de {len(poblacion_final.get_poblacion_X())} individuos')

if fitnessF.shape[1] == 2:
    plot_final = Scatter(
        title="Fitness Distribution (Final Population)",
        labels=["Profit", "Novelty"]
    )
    plot_final.add(fitnessF * -1, s=30, facecolors='none', edgecolors='r', label="Final Population")
    plot_final.show()
elif fitnessF.shape[1] == 3:
    plot_final1 = Scatter(
        title="Fitness Distribution (Final Population - Profit vs Novelty)",
        labels=["Profit", "Novelty"]
    )
    plot_final1.add(fitnessF[:, [0, 1]] * -1, s=30, facecolors='none', edgecolors='r', label="Final Population")
    plot_final1.show()

    plot_final2 = Scatter(
        title="Fitness Distribution (Final Population - Profit vs Third objective)",
        labels=["Profit", "Third objective"]
    )
    plot_final2.add(fitnessF[:, [0, 2]] * -1, s=30, facecolors='none', edgecolors='r', label="Final Population")
    plot_final2.show()

    plot_final3 = Scatter(
        title="Fitness Distribution (Final Population - Novelty vs Third objective)",
        labels=["Novelty", "Third objective"]
    )
    plot_final3.add(fitnessF[:, [1, 2]] * -1, s=30, facecolors='none', edgecolors='r', label="Final Population")
    plot_final3.show()

    fig = plt.figure(figsize=(10, 7))
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(fitnessF[:, 0] * -1, fitnessF[:, 1], fitnessF[:, 2]  * -1, c='r', marker='o', label="Final Population")

    ax.set_title("3D Fitness Distribution (Final Population)")
    ax.set_xlabel("Profit")
    ax.set_ylabel("Novelty")
    ax.set_zlabel("Third objective")
    ax.legend()
    plt.show()
# Out:
# FINAL:
# El hipervolumen de la población final es 0.47425868523181736
# La población final es de 40 individuos

# %%
import pickle as pkl
from datetime import datetime

def guardar_archivo():
    fecha_hora = datetime.now().strftime('%Y%m%d_%H%M%S')
    archivo_guardar = {
        "fitnessF": poblacion_final.fitnessF,
        "poblacionX": poblacion_final.poblacionX
    }

    carpeta_path = f'./comparacion_resultados/{carpeta_resultados}'
    if not os.path.exists(carpeta_path):
        os.makedirs(carpeta_path)

    filename = f'{carpeta_path}/poblacion_final_{algorithm_name}_{N_tamano_poblacion}_{T_iteraciones}_{fecha_hora}.pkl'
    with open(filename, 'wb') as f:
        pkl.dump(archivo_guardar, f)

    print(f'Resultados guardados en: {filename}')

guardar_archivo()
# Out:
# Resultados guardados en: ./comparacion_resultados/modificacion2/poblacion_final_NSGA-III_100_50_20250723_224204.pkl

# %%
import matplotlib.pyplot as plt

def calculate_real_total_profit(poblacion):
    real_total_profit = []
    for individuo in poblacion.get_all_individuals():
        matrix = individuo.get_matrix()
        sumatoria = 0
        for user_id, row in enumerate(matrix, start=1):
            for movie in row:
                predict_rating = user_movie_predict_ratings[(user_id, movie)]
                if predict_rating >= 3:
                    sumatoria = sumatoria + movies2profit[movie]
        real_total_profit.append((individuo.get_novelty() / max_novelty, sumatoria))
    # Separate novelty and profit values
    novelty_values, profit_values = zip(*real_total_profit)

    # Plot the real total profit
    plt.figure(figsize=(10, 6))
    plt.scatter(profit_values, novelty_values, color='blue', alpha=0.7)
    plt.title('Novelty vs Real Total Profit')
    plt.xlabel('Real Total Profit')
    plt.ylabel('Novelty')
    plt.grid(True)
    plt.show()
    return real_total_profit

#real_total_profit = calculate_real_total_profit(poblacion_final)

# %% [markdown]
# Para animación

# %%
import os

def animacion():
    if not os.path.exists('./img'):
        os.makedirs('./img')

    for gen, fitness in enumerate(historial_fitness):
        if gen > 2:
            plot_gen = Scatter(
                title=f"Fitness Distribution (Generation {gen})",
                labels=["Profit", "Novelty"]
            )
            plot_gen.add(fitness, s=30, facecolors='none', edgecolors='g', label=f"Generation {gen - 2}")
            plot_gen.save(f'./img/{gen - 2}.png')

#animacion()

# %% [markdown]
# ## Ejemplos

# %%
import pandas as pd

def load_movie_data(latest):
    """
    Carga los datos de las películas desde un archivo CSV.
    """
    csv = '../../datasets/ml-latest-small/ratings.csv' if latest else '../../datasets/ml-100k/u.item.csv'
    movie_data = pd.read_csv(csv, sep=',', header=None, encoding='latin-1', usecols=[0, 1], names=['movieId', 'title'], skiprows=1)
    return dict(zip(movie_data['movieId'], movie_data['title']))

def get_recommendations(individuos, step_individuo, step_usuarios):
    """
    Obtiene las recomendaciones para los usuarios.
    """
    usuario_lista = []
    j_usuario = 1
    for i_individuo, individuo in enumerate(individuos):
        if i_individuo % step_individuo == 0:
            matrix = individuo.get_matrix()
            usuario_lista.append((j_usuario, matrix[j_usuario - 1], i_individuo, individuo.get_fitness()))
            j_usuario += step_usuarios
    return usuario_lista

def process_recommendations(usuario_lista, movie_id_to_name, new_comers_ids, user_movie_predict_ratings, r_max_calificacion_maxima, movies2profit):
    """
    Procesa las recomendaciones y genera datos tabulares.
    """
    table_data = []
    for usuario, lista_recomendacion, individuo, fitness in usuario_lista:
        fitness_str = ', '.join([f'{obj * -N_tamano_poblacion:.2f}' for obj in fitness])
        print(f'\nIndividuo {individuo}:')
        print(f'  Objetivos: {fitness_str}')
        print(f'  Usuario {usuario}: Recomendaciones:')
        for movie_id in lista_recomendacion:
            if movie_id not in new_comers_ids:
                rating = user_movie_predict_ratings[(usuario, movie_id)]
                profit = movies2profit[movie_id]
                profit_usuario = rating / r_max_calificacion_maxima * profit
                print(f'    - {movie_id_to_name[movie_id]}:')
                print(f'      - Posible rating: {rating:.2f}')
                print(f'      - Profit de la película: {profit:.2f}')
                print(f'      - Profit del usuario-pelicula: {profit_usuario:.2f}')
                table_data.append({
                    'Individuo': individuo,
                    **{f'Objetivo {i+1}': abs(obj) * N_tamano_poblacion for i, obj in enumerate(fitness)},
                    'Usuario': usuario,
                    'Movie ID': movie_id,
                    'Movie Title': movie_id_to_name[movie_id],
                    'Predicted Rating': rating,
                    'Movie Profit': profit,
                    'User-Movie Profit': profit_usuario
                })
            else:
                print(f'    - {movie_id_to_name[movie_id]}: New comer')
                table_data.append({
                    'Individuo': individuo,
                    **{f'Objetivo {i+1}': abs(obj) * N_tamano_poblacion for i, obj in enumerate(fitness)},
                    'Usuario': usuario,
                    'Movie ID': movie_id,
                    'Movie Title': movie_id_to_name[movie_id],
                    'Predicted Rating': 'New comer',
                    'Movie Profit': 'New comer',
                    'User-Movie Profit': 'New comer'
                })
    return table_data

def save_to_csv(table_data, output_csv):
    """
    Guarda los datos tabulares en un archivo CSV.
    """
    df = pd.DataFrame(table_data)
    df.to_csv(output_csv, index=False, encoding='utf-8')
    print(f'\nLa información tabular ha sido guardada en el archivo: {output_csv}')

# Main execution
log = logger.logger_class('EJEMPLOS')

# Cargar datos de películas
latest = False
movie_id_to_name = load_movie_data(latest)

# Obtener recomendaciones
individuos = poblacion_final.get_all_individuals()
# Mejor forma de calcular los pasos asegurando que sean al menos 1
step_individuo = max(1, len(individuos) // 10)
step_usuarios = max(1, len(individuos[0].get_matrix()) // 10)
usuario_lista = get_recommendations(individuos, step_individuo, step_usuarios)

# Procesar recomendaciones
table_data = process_recommendations(usuario_lista, movie_id_to_name, new_comers_ids, user_movie_predict_ratings, r_max_calificacion_maxima, movies2profit)

# Guardar resultados en un archivo CSV
output_csv = 'final_recomendations_examples.csv'
save_to_csv(table_data, output_csv)
# Out:
# Individuo 0:
#   Objetivos: 35.13, 69.47, 84.90
#   Usuario 1: Recomendaciones:
#     - Best Men (1997): New comer
#     - Tough and Deadly (1995): New comer
#     - Condition Red (1995): New comer
#     - Hostile Intentions (1994): New comer
#     - Witness (1985): New comer
#     - Nemesis 2: Nebula (1995): New comer
#     - Diva (1981):
#       - Posible rating: 3.95
#       - Profit de la película: 8.91
#       - Profit del usuario-pelicula: 7.03
#     - I Like It Like That (1994): New comer
#     - Madonna: Truth or Dare (1991):
#       - Posible rating: 2.55
#       - Profit de la película: 5.76
#       - Profit del usuario-pelicula: 2.94
#     - Thirty-Two Short Films About Glenn Gould (1993):
#       - Posible rating: 5.00
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 10.00
#
# Individuo 4:
#   Objetivos: 54.99, 37.65, 92.48
#   Usuario 95: Recomendaciones:
#     - Devil's Own, The (1997):
#       - Posible rating: 3.22
#       - Profit de la película: 7.86
#       - Profit del usuario-pelicula: 5.07
#     - Titanic (1997):
#       - Posible rating: 4.43
#       - Profit de la película: 9.41
#       - Profit del usuario-pelicula: 8.34
#     - G.I. Jane (1997):
#       - Posible rating: 3.45
#       - Profit de la película: 7.99
#       - Profit del usuario-pelicula: 5.51
#     - Ben-Hur (1959):
#       - Posible rating: 4.10
#       - Profit de la película: 9.35
#       - Profit del usuario-pelicula: 7.66
#     - Best Men (1997): New comer
#     - Colonel Chabert, Le (1994): New comer
#     - Tough and Deadly (1995): New comer
#     - Condition Red (1995): New comer
#     - Heaven & Earth (1993):
#       - Posible rating: 2.26
#       - Profit de la película: 6.00
#       - Profit del usuario-pelicula: 2.72
#     - Hostile Intentions (1994): New comer
#
# Individuo 8:
#   Objetivos: 41.40, 66.57, 76.05
#   Usuario 189: Recomendaciones:
#     - Best Men (1997): New comer
#     - C'est arrivï¿½ prï¿½s de chez vous (1992): New comer
#     - Gay Divorcee, The (1934):
#       - Posible rating: 5.00
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 10.00
#     - I Like It Like That (1994): New comer
#     - Hana-bi (1997): New comer
#     - Big Squeeze, The (1996): New comer
#     - Lay of the Land, The (1997): New comer
#     - Kid in King Arthur's Court, A (1995):
#       - Posible rating: 2.64
#       - Profit de la película: 7.14
#       - Profit del usuario-pelicula: 3.77
#     - Foreign Correspondent (1940):
#       - Posible rating: 5.00
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 10.00
#     - Walkabout (1971):
#       - Posible rating: 5.00
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 9.99
#
# Individuo 12:
#   Objetivos: 88.28, 6.48, 61.79
#   Usuario 283: Recomendaciones:
#     - Fresh (1994):
#       - Posible rating: 4.90
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 9.79
#     - Walkabout (1971):
#       - Posible rating: 4.83
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 9.66
#     - Mark of Zorro, The (1940):
#       - Posible rating: 4.58
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 9.15
#     - Horseman on the Roof, The (Hussard sur le toit, Le) (1995):
#       - Posible rating: 4.17
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 8.35
#     - True Lies (1994):
#       - Posible rating: 3.83
#       - Profit de la película: 8.70
#       - Profit del usuario-pelicula: 6.67
#     - Kid in King Arthur's Court, A (1995):
#       - Posible rating: 4.17
#       - Profit de la película: 7.14
#       - Profit del usuario-pelicula: 5.96
#     - Hercules (1997):
#       - Posible rating: 3.56
#       - Profit de la película: 8.50
#       - Profit del usuario-pelicula: 6.05
#     - Operation Dumbo Drop (1995):
#       - Posible rating: 4.17
#       - Profit de la película: 5.65
#       - Profit del usuario-pelicula: 4.71
#     - Manon of the Spring (Manon des sources) (1986):
#       - Posible rating: 4.17
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 8.35
#     - Army of Darkness (1993):
#       - Posible rating: 4.12
#       - Profit de la película: 8.37
#       - Profit del usuario-pelicula: 6.91
#
# Individuo 16:
#   Objetivos: 76.23, 22.94, 62.40
#   Usuario 377: Recomendaciones:
#     - From Dusk Till Dawn (1996):
#       - Posible rating: 2.32
#       - Profit de la película: 7.16
#       - Profit del usuario-pelicula: 3.33
#     - Ulee's Gold (1997):
#       - Posible rating: 5.00
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 10.00
#     - Army of Darkness (1993):
#       - Posible rating: 4.69
#       - Profit de la película: 8.37
#       - Profit del usuario-pelicula: 7.86
#     - Waiting for Guffman (1996):
#       - Posible rating: 4.37
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 8.74
#     - Horseman on the Roof, The (Hussard sur le toit, Le) (1995):
#       - Posible rating: 3.91
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 7.82
#     - Manon of the Spring (Manon des sources) (1986):
#       - Posible rating: 3.91
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 7.82
#     - His Girl Friday (1940):
#       - Posible rating: 3.91
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 7.82
#     - Best Men (1997): New comer
#     - Hour of the Pig, The (1993):
#       - Posible rating: 3.91
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 7.82
#     - Evil Dead II (1987):
#       - Posible rating: 4.69
#       - Profit de la película: 8.18
#       - Profit del usuario-pelicula: 7.68
#
# Individuo 20:
#   Objetivos: 15.24, 95.95, 78.28
#   Usuario 471: Recomendaciones:
#     - Turbo: A Power Rangers Movie (1997): New comer
#     - Star Kid (1997): New comer
#     - Buddy (1997): New comer
#     - Secret Adventures of Tom Thumb, The (1993): New comer
#     - Gumby: The Movie (1995): New comer
#     - 3 Ninjas: High Noon At Mega Mountain (1998): New comer
#     - So Dear to My Heart (1949): New comer
#     - Best Men (1997): New comer
#     - Simple Wish, A (1997): New comer
#     - I Like It Like That (1994): New comer
#
# Individuo 24:
#   Objetivos: 84.10, 19.43, 41.88
#   Usuario 565: Recomendaciones:
#     - Wonderful, Horrible Life of Leni Riefenstahl, The (1993):
#       - Posible rating: 5.00
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 10.00
#     - Gay Divorcee, The (1934):
#       - Posible rating: 5.00
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 10.00
#     - Waiting for Guffman (1996):
#       - Posible rating: 5.00
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 10.00
#     - Safe (1995):
#       - Posible rating: 5.00
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 10.00
#     - Fresh (1994):
#       - Posible rating: 5.00
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 10.00
#     - A Chef in Love (1996):
#       - Posible rating: 5.00
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 10.00
#     - SubUrbia (1997):
#       - Posible rating: 5.00
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 10.00
#     - Pather Panchali (1955):
#       - Posible rating: 5.00
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 10.00
#     - I Like It Like That (1994): New comer
#     - Best Men (1997): New comer
#
# Individuo 28:
#   Objetivos: 27.69, 78.99, 84.87
#   Usuario 659: Recomendaciones:
#     - Tough and Deadly (1995): New comer
#     - Condition Red (1995): New comer
#     - Hostile Intentions (1994): New comer
#     - Lashou shentan (1992): New comer
#     - Johnny 100 Pesos (1993): New comer
#     - Men of Means (1998): New comer
#     - Romper Stomper (1992): New comer
#     - Batman (1989):
#       - Posible rating: 3.37
#       - Profit de la película: 8.75
#       - Profit del usuario-pelicula: 5.89
#     - Tokyo Fist (1995): New comer
#     - Apollo 13 (1995):
#       - Posible rating: 3.59
#       - Profit de la película: 9.61
#       - Profit del usuario-pelicula: 6.89
#
# Individuo 32:
#   Objetivos: 79.93, 7.13, 83.61
#   Usuario 753: Recomendaciones:
#     - Whole Wide World, The (1996):
#       - Posible rating: 4.48
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 8.96
#     - Crying Game, The (1992):
#       - Posible rating: 3.96
#       - Profit de la película: 8.64
#       - Profit del usuario-pelicula: 6.84
#     - Fresh (1994):
#       - Posible rating: 4.48
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 8.96
#     - Pather Panchali (1955):
#       - Posible rating: 4.48
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 8.96
#     - Beat the Devil (1954):
#       - Posible rating: 4.48
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 8.96
#     - Diva (1981):
#       - Posible rating: 3.99
#       - Profit de la película: 8.91
#       - Profit del usuario-pelicula: 7.10
#     - Wonderful, Horrible Life of Leni Riefenstahl, The (1993):
#       - Posible rating: 4.27
#       - Profit de la película: 10.00
#       - Profit del usuario-pelicula: 8.54
#     - Devil's Own, The (1997):
#       - Posible rating: 3.50
#       - Profit de la película: 7.86
#       - Profit del usuario-pelicula: 5.51
#     - First Knight (1995):
#       - Posible rating: 3.03
#       - Profit de la película: 7.07
#       - Profit del usuario-pelicula: 4.29
#     - Colonel Chabert, Le (1994): New comer
#
# Individuo 36:
#   Objetivos: 21.26, 87.52, 83.37
#   Usuario 847: Recomendaciones:
#     - Best Men (1997): New comer
#     - I Like It Like That (1994): New comer
#     - C'est arrivï¿½ prï¿½s de chez vous (1992): New comer
#     - Hana-bi (1997): New comer
#     - Big Squeeze, The (1996): New comer
#     - Lay of the Land, The (1997): New comer
#     - Inkwell, The (1994): New comer
#     - Talking About Sex (1994): New comer
#     - Babyfever (1994): New comer
#     - Get Shorty (1995):
#       - Posible rating: 2.75
#       - Profit de la película: 8.71
#       - Profit del usuario-pelicula: 4.79
#
# La información tabular ha sido guardada en el archivo: final_recomendations_examples.csv
